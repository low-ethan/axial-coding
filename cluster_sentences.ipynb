# %%
import numpy as np
import pandas as pd
from sentence_transformers.util import cos_sim
from sentence_transformers import SentenceTransformer
import seaborn as sns
import matplotlib.pyplot as plt
import ast

# %%
og = pd.read_csv('sensitive/health_interview_proc_split.csv')
df2 = pd.read_csv('sensitive/llama_prompt_two_examples_neg_temp.csv')

completed = set(df2['id'])
rows_left = og[~og['id'].isin(completed)]
len(og), len(completed), len(rows_left)

print(rows_left['id'])
# Out:
# 30     28_PRO_M_Q10-2
# 51       43_EAG_F_Q10
# 96       24_PRO_F_Q11
# 100      28_PRO_M_Q11
# 141    59_LEH_M_Q11-4
#             ...
# 537      26_PRO_M_Q17
# 548      34_PRO_F_Q17
# 560      45_PRO_F_Q17
# 561      46_PRO_F_Q17
# 569      54_SPR_F_Q17
# Name: id, Length: 69, dtype: object

# %%
ids_with_minus_one = {row['id'].replace('-1', '') for index, row in df2.iterrows() if row['id'].endswith('-1')}
df2 = df2[~df2['id'].isin(ids_with_minus_one)]

# %% [markdown]
# #### S-bert cut similars

# %%
# df_grouped = df2.groupby(['id', 'prompt']).agg({
#     'label_json': lambda x: '[' + ', '.join(x.str.strip('[]')) + ']',
#     **{col: 'first' for col in df2.columns if col not in ['id', 'prompt', 'label_json']}
# }).reset_index()
# 
# df_grouped.sort_values(by='id').head(20)
#
df_grouped = df2.groupby(['id', 'prompt']).first().reset_index()


def convert_to_dict(x):
    try:
        # Try to safely evaluate the string as a Python dictionary
        output = ast.literal_eval(x)

        return output
    except (ValueError, SyntaxError) as e:
        # Print the exception for debugging
        print(f"Didn't work: {x}")
        print(f"Exception: {e}")
        return None
#     
df_grouped['tmp'] = df_grouped['label_json'].apply(convert_to_dict)

# %%
df_grouped
# Out:
#               id                   prompt  row  \
# 0    0_PAY_M_Q10        Q10_Health Impact    0
# 1    0_PAY_M_Q11  Q11_At-Risk Populations   61
# 2    0_PAY_M_Q12         Q12_Risk Factors  122
# 3    0_PAY_M_Q13           Q13_Root Cause  183
# 4    0_PAY_M_Q14  Q14_Community Strengths  244
# ..           ...                      ...  ...
# 513  9_PRO_M_Q13           Q13_Root Cause  192
# 514  9_PRO_M_Q14  Q14_Community Strengths  253
# 515  9_PRO_M_Q15            Q15_Resources  314
# 516  9_PRO_M_Q16            Q16_Solutions  375
# 517  9_PRO_M_Q17       Q17_Other Thoughts  436
#
#                                                 answer  \
# 0    Impacts some of our poorest residents harder. ...
# 1                                          Black Women
# 2    Childhood trauma, getting food that is addicti...
# 3    Most people struggle to know what foods are be...
# 4    Good friends, finances, outdoor community/comm...
# ..                                                 ...
# 513  Okay, this is easier for people to get food. E...
# 514  Okay, you know, we can have more events.\nkind...
# 515  Probably have more young people because of the...
# 516  I know I'm almost 40. After 40, if you have th...
# 517  You know, for example, for the parks, you know...
#
#                                             label_json  \
# 0    [{'Original_Text': 'Impacts some of our poores...
# 1    [{'Original_Text': 'Black Women', 'Code': 'At-...
# 2    [{'Original_Text': 'Childhood trauma', 'Code':...
# 3    [{'Original_Text': 'Most people struggle to kn...
# 4    [{'Original_Text': 'Good friends', 'Code': 'St...
# ..                                                 ...
# 513  [{'Original_Text': 'Okay, this is easier for p...
# 514  [{'Original_Text': 'Okay, you know, we can hav...
# 515  [{'Original_Text': 'Probably have more young p...
# 516  [{'Original_Text': "I know I'm almost 40. Afte...
# 517  [{'Original_Text': 'You know, for example, for...
#
#                                                    tmp
# 0    [{'Original_Text': 'Impacts some of our poores...
# 1    [{'Original_Text': 'Black Women', 'Code': 'At-...
# 2    [{'Original_Text': 'Childhood trauma', 'Code':...
# 3    [{'Original_Text': 'Most people struggle to kn...
# 4    [{'Original_Text': 'Good friends', 'Code': 'St...
# ..                                                 ...
# 513  [{'Original_Text': 'Okay, this is easier for p...
# 514  [{'Original_Text': 'Okay, you know, we can hav...
# 515  [{'Original_Text': 'Probably have more young p...
# 516  [{'Original_Text': 'I know I'm almost 40. Afte...
# 517  [{'Original_Text': 'You know, for example, for...
#
# [518 rows x 6 columns]

# %% [markdown]
# #### Cutting similar codes, removing affimation tags with SBERT

# %% [markdown]
# Not sure if this is currently needed, so I'm going to cut it for now.

# %%
model_ckpt = 'sentence-transformers/distiluse-base-multilingual-cased-v2'
model = SentenceTransformer(model_ckpt)

def similarity_scores(s1, to_compare):
    embeddings = np.concatenate([[s1], to_compare])
    # print(embeddings)
    sim = np.zeros((len(embeddings), len(embeddings)))
    # print(len(embeddings))
    for i in range(len(embeddings)):
        sim[i] = cos_sim(embeddings[i], embeddings[i:])
        break
    return sim[0][1:]
e1 = model.encode('YEAH')
tc = model.encode(['Acknowledged', 'Consent', 'Yeah', 'Agreed'])
similarity_scores(e1, tc)
# Out:
# array([0.41554677, 0.48822314, 0.87535834, 0.51043856])

# %%
def cut_similars(model, json_list):
    to_drop = set()
    agg_words = model.encode(['Acknowledged', 'Consent', 'Yeah', 'Agreed', 'No Code', "I don't know", 'Conclusion', 'Right'])
    affirmation_list = []
    for i in range(len(json_list)):
        if i in to_drop:
            # print(json_list[i])
            continue
        c_emb = model.encode(json_list[i]['Code'])
        # Drop if answer or topic too close to an affirmation
        if max(similarity_scores(c_emb, agg_words)) > .8:
            to_drop.add(i)
            affirmation_list.append(('Code', json_list[i]['Code'], json_list[i]['Original_Text']))
            continue
        if max(similarity_scores(model.encode(json_list[i]['Topic']), agg_words)) > .8:
            to_drop.add(i)
            affirmation_list.append(('Topic', json_list[i]['Topic'], json_list[i]['Original_Text']))
            continue
        ### Dropping codes that are similar to previous ones
        # for j in range(i+1, len(json_list)):
        #     if cos_sim(c_emb, model.encode(json_list[j]['Code'])) > 0.7:
        #         print(json_list[i]['Code'], ' ::: ', json_list[j]['Code'])
        #         print(json_list[i]['Topic'], ' ::: ', json_list[j]['Topic'])
        #         print(json_list[i]['Original_Text'], ' ::: ', json_list[j]['Original_Text'])
        #         print(json_list[i]['Keywords'], ' ::: ', json_list[j]['Keywords'])
        #         print('#'*50)
        #         to_drop.add(j)
    json_list = [item for idx, item in enumerate(json_list) if idx not in to_drop]
    if len(affirmation_list) > 0:
        print(affirmation_list)
    return json_list


# row = df_grouped['tmp'].head()[2]
# print(row)
# cut_similars(model, row)

# Apply the function to each row in the 'json_list' column
df_grouped['json_list'] = df_grouped['tmp'].apply(lambda x: cut_similars(model, x))
# Out:
# [('Topic', 'Conclusion', "That's it."), ('Topic', 'Conclusion', "I don't really have any other thoughts about it.")]
# [('Topic', 'Recognition', "Yeah. Um,  and let's celebrate those.")]
# [('Topic', 'Acknowledgement', 'Yeah. Yeah it was.')]
# [('Code', 'Conclusion', 'So, yeah.')]
# [('Topic', 'Conclusion', 'But no, no other thoughts.')]
# [('Code', 'Yes', 'Yes.')]
# [('Code', "Don't Know", "I don't know because I've n")]
# [('Code', 'Right', 'Right, that for me.'), ('Code', 'Right', 'Right?')]

# %%
df_grouped.head()
# Out:
#             id                   prompt  row  \
# 0  0_PAY_M_Q10        Q10_Health Impact    0
# 1  0_PAY_M_Q11  Q11_At-Risk Populations   61
# 2  0_PAY_M_Q12         Q12_Risk Factors  122
# 3  0_PAY_M_Q13           Q13_Root Cause  183
# 4  0_PAY_M_Q14  Q14_Community Strengths  244
#
#                                               answer  \
# 0  Impacts some of our poorest residents harder. ...
# 1                                        Black Women
# 2  Childhood trauma, getting food that is addicti...
# 3  Most people struggle to know what foods are be...
# 4  Good friends, finances, outdoor community/comm...
#
#                                           label_json  \
# 0  [{'Original_Text': 'Impacts some of our poores...
# 1  [{'Original_Text': 'Black Women', 'Code': 'At-...
# 2  [{'Original_Text': 'Childhood trauma', 'Code':...
# 3  [{'Original_Text': 'Most people struggle to kn...
# 4  [{'Original_Text': 'Good friends', 'Code': 'St...
#
#                                                  tmp  \
# 0  [{'Original_Text': 'Impacts some of our poores...
# 1  [{'Original_Text': 'Black Women', 'Code': 'At-...
# 2  [{'Original_Text': 'Childhood trauma', 'Code':...
# 3  [{'Original_Text': 'Most people struggle to kn...
# 4  [{'Original_Text': 'Good friends', 'Code': 'St...
#
#                                            json_list
# 0  [{'Original_Text': 'Impacts some of our poores...
# 1  [{'Original_Text': 'Black Women', 'Code': 'At-...
# 2  [{'Original_Text': 'Childhood trauma', 'Code':...
# 3  [{'Original_Text': 'Most people struggle to kn...
# 4  [{'Original_Text': 'Good friends', 'Code': 'St...

# %% [markdown]
# Group, take only the first (negative temp)

# %%
# df_grouped = df2.groupby(['id', 'prompt']).first().reset_index()
# df_grouped['json_list'] = df_grouped['label_json'].apply(convert_to_dict)
# df_grouped.head()

# %%
df_grouped = df_grouped[df_grouped['json_list'].apply(lambda x: x != [])]

# %%
def extract_codes(json_list):
    return [entry['Code'] for entry in json_list]

df_grouped['tmp'] = df_grouped['json_list'].apply(extract_codes)

# %%
df_grouped['tmp'].head()
# Out:
# 0    [Disproportionate Impact on Poor, Limited Food...
# 1                                 [At-Risk Population]
# 2    [Childhood Trauma, Unhealthy Food Addiction, E...
# 3    [Lack of Nutritional Knowledge, Genetic Influe...
# 4    [Strong Social Support, Financial Stability, A...
# Name: tmp, dtype: object

# %%
# df4.drop(['tmp', 'label_json'], axis=1, inplace=True)
# df4.to_csv('health_combined.csv', index=False)

# %% [markdown]
# ### Kmeans Clustering

# %%
df4 = df_grouped.copy()

# %%
# def extract_codes(json_list):
#     return [entry['Code'] for entry in json_list]
# 
# all_codes = sum(df4['json_list'].apply(extract_codes), [])
# 
# print(len(all_codes))

# %%
id_info = pd.read_csv('sensitive/id_info.csv')
q3_mapping = {
    'Obesity': 'Obesity',
    'obesity': 'Obesity',
    'Obesity/Overweight': 'Obesity',
    'Obesity and Overweight': 'Obesity',
    'overweight and obesity': 'Obesity',
    'Obesity/overweight': 'Obesity',
    'Obesity and overweight': 'Obesity',
    'Overweight/Obesity': 'Obesity',
    'overweight/obesity': 'Obesity',
    'Obestiy': 'Obesity',
    'Obesity ': 'Obesity',
    'Depression ': 'Depression'
}
id_info['Q3_Health Problem'] = id_info['Q3_Health Problem'].replace(q3_mapping)
id_info['Q3_Health Problem'].value_counts()
# Out:
# Q3_Health Problem
# Obesity       43
# Depression    18
# Name: count, dtype: int64

# %%
df4['id_l'] = df4['id']
df4['id'] = df4['id'].str[:-4]
df4.head()
# Out:
#         id                   prompt  row  \
# 0  0_PAY_M        Q10_Health Impact    0
# 1  0_PAY_M  Q11_At-Risk Populations   61
# 2  0_PAY_M         Q12_Risk Factors  122
# 3  0_PAY_M           Q13_Root Cause  183
# 4  0_PAY_M  Q14_Community Strengths  244
#
#                                               answer  \
# 0  Impacts some of our poorest residents harder. ...
# 1                                        Black Women
# 2  Childhood trauma, getting food that is addicti...
# 3  Most people struggle to know what foods are be...
# 4  Good friends, finances, outdoor community/comm...
#
#                                           label_json  \
# 0  [{'Original_Text': 'Impacts some of our poores...
# 1  [{'Original_Text': 'Black Women', 'Code': 'At-...
# 2  [{'Original_Text': 'Childhood trauma', 'Code':...
# 3  [{'Original_Text': 'Most people struggle to kn...
# 4  [{'Original_Text': 'Good friends', 'Code': 'St...
#
#                                                  tmp  \
# 0  [Disproportionate Impact on Poor, Limited Food...
# 1                               [At-Risk Population]
# 2  [Childhood Trauma, Unhealthy Food Addiction, E...
# 3  [Lack of Nutritional Knowledge, Genetic Influe...
# 4  [Strong Social Support, Financial Stability, A...
#
#                                            json_list         id_l
# 0  [{'Original_Text': 'Impacts some of our poores...  0_PAY_M_Q10
# 1  [{'Original_Text': 'Black Women', 'Code': 'At-...  0_PAY_M_Q11
# 2  [{'Original_Text': 'Childhood trauma', 'Code':...  0_PAY_M_Q12
# 3  [{'Original_Text': 'Most people struggle to kn...  0_PAY_M_Q13
# 4  [{'Original_Text': 'Good friends', 'Code': 'St...  0_PAY_M_Q14

# %%
df5 = pd.merge(df4, id_info, on='id', how='left')
df5.head()
# Out:
#         id                   prompt  row  \
# 0  0_PAY_M        Q10_Health Impact    0
# 1  0_PAY_M  Q11_At-Risk Populations   61
# 2  0_PAY_M         Q12_Risk Factors  122
# 3  0_PAY_M           Q13_Root Cause  183
# 4  0_PAY_M  Q14_Community Strengths  244
#
#                                               answer  \
# 0  Impacts some of our poorest residents harder. ...
# 1                                        Black Women
# 2  Childhood trauma, getting food that is addicti...
# 3  Most people struggle to know what foods are be...
# 4  Good friends, finances, outdoor community/comm...
#
#                                           label_json  \
# 0  [{'Original_Text': 'Impacts some of our poores...
# 1  [{'Original_Text': 'Black Women', 'Code': 'At-...
# 2  [{'Original_Text': 'Childhood trauma', 'Code':...
# 3  [{'Original_Text': 'Most people struggle to kn...
# 4  [{'Original_Text': 'Good friends', 'Code': 'St...
#
#                                                  tmp  \
# 0  [Disproportionate Impact on Poor, Limited Food...
# 1                               [At-Risk Population]
# 2  [Childhood Trauma, Unhealthy Food Addiction, E...
# 3  [Lack of Nutritional Knowledge, Genetic Influe...
# 4  [Strong Social Support, Financial Stability, A...
#
#                                            json_list         id_l  \
# 0  [{'Original_Text': 'Impacts some of our poores...  0_PAY_M_Q10
# 1  [{'Original_Text': 'Black Women', 'Code': 'At-...  0_PAY_M_Q11
# 2  [{'Original_Text': 'Childhood trauma', 'Code':...  0_PAY_M_Q12
# 3  [{'Original_Text': 'Most people struggle to kn...  0_PAY_M_Q13
# 4  [{'Original_Text': 'Good friends', 'Code': 'St...  0_PAY_M_Q14
#
#   Q2_Utah Small Area Q3_Health Problem Q5_Sex  \
# 0             Payson           Obesity   Male
# 1             Payson           Obesity   Male
# 2             Payson           Obesity   Male
# 3             Payson           Obesity   Male
# 4             Payson           Obesity   Male
#
#   Q6_Race/Ethnicity - Selected Choice Q7_Age Group  \
# 0                     White/Caucasian        45-54
# 1                     White/Caucasian        45-54
# 2                     White/Caucasian        45-54
# 3                     White/Caucasian        45-54
# 4                     White/Caucasian        45-54
#
#                                    Q8_Affiliation
# 0  Resident, Operations Manager for Family Search
# 1  Resident, Operations Manager for Family Search
# 2  Resident, Operations Manager for Family Search
# 3  Resident, Operations Manager for Family Search
# 4  Resident, Operations Manager for Family Search

# %%
from collections import defaultdict

master_map = defaultdict(list)

for json_list in df5['json_list']:
    for item in json_list:
        text = item.get('Original_Text')
        code = item.get('Code')
        if text and code:
            master_map[code].append(text)

# %%
master_map
# Out:
# defaultdict(list,
#             {'Disproportionate Impact on Poor': ['Impacts some of our poorest residents harder.'],
#              'Limited Food Access and Trauma': ['Payson has a really active community, but there are those who are poor and do not have good access to food or are just traumatized (from childhood).'],
#              'At-Risk Population': ['Black Women'],
#              'Childhood Trauma': ['Childhood trauma'],
#              'Unhealthy Food Addiction': ['Getting food that is addicting not healthy food'],
#              'Economic Factors': ['Economic circumstances',
#               'I think economic factors play a big part.'],
#              'Lack of Nutritional Knowledge': ['Most people struggle to know what foods are best for them',
#               "I think part of it is education, not knowing how foods work, which impacts us negatively, and we don't eat healthily.",
#               "Maybe families that they don't know exactly about everything, you know, nutritional based too."],
#              'Genetic Influence': ['Hereditary from parents'],
#              'Parental Lifestyle Impact': ['Lifestyle of parents'],
#              'Strong Social Support': ['Good friends'],
#              'Financial Stability': ['Finances'],
#              'Active Lifestyle': ['Outdoor community/community that supports outdoor activities',
#               'Like people are always walking outside or running or going to the gym.',
#               'I grew up playing sports and was surrounded by athletes.'],
#              'Community Resources for Obesity': ['Community resources at the hospital that have classes that address obesity'],
#              'Financial Support': ['Financial assistance'],
#              'Obesity Classes': ['Classes'],
#              'Awareness Campaigns': ['Getting the word out'],
#              'Bedroom Community': ['It is a real bedroom community'],
#              'Fast Spread of Illness': ['if people are sick it spreads really fast'],
#              'Staying Home Reduces Spread': ['So if people stayed at home it wouldn’t spread as much'],
#              'Late Recognition of Health Issues': ["Unfortunately, I see it as people don't recognize it until it's too late."],
#              "Parental Influence on Children's Health": ['And they do the same thing to their children.'],
#              'Unhealthy Snacking Habits': ['Tell me how school went with these cookies.'],
#              'Childhood Obesity': ['And I see these children getting heavier.',
#               'Young obesity'],
#              'Limited Growth Potential': ["And a lot of them have already grown to their stature as far as size, so there's nowhere for it to go."],
#              'Rural Lifestyle and Physical Activity': ["But the kids who live in more rural areas are following in mom and dad's footsteps and are involved in baling and hauling hay and being in different horse competitions."],
#              'Rural Lifestyle Promotes Physical Activity': ["In a rural lifestyle like that, I think kids are better off because they're more active, than just sitting in the house watching TV with cookies and waiting for dinner."],
#              'Preteens and Early Teens': ['Preteens into early teens.'],
#              'Elderly': ['And also the elderly.'],
#              'Lack of Transportation for Elderly': ["There aren't enough resources or people to pick the elderly up to take them to activities at an elderly center or something."],
#              'Limited Socialization for Elderly': ["And so they're not getting out either."],
#              'Perceived Inadequacy of Services': ["And I think that that's where they've done wrong."],
#              'Limited Access to Activities': ['These people have no ability to and from activities.'],
#              'Lack of Transportation Options': ["Whether it's a community bus service or whether it's individual drivers, we just don't have it out there."],
#              'Senior Citizens Hall in Spanish Fork': ["I do know there's a senior citizens Hall in Spanish Fork, just kind of almost on the Payson line, and they do have lunches and stuff and everyone can come on a Thursday."],
#              'Barriers to Participation': ["But a lot of people don't want to go out in the weather or don't feel like they want to pay that, you know, $2 to have that lunch and socialize."],
#              'Preference for Home Isolation': ['They would rather just stay in their home and be alone.'],
#              'Wasatch Mental Health Bus Service': ['They do have Wasatch mental health that has a bus service.'],
#              'Transportation for Mental Health Patients': ['And when I drove for them, we picked up several patients all the way from Pleasant Grove to Payson to give them a day at a club house to eat and exe'],
#              'Limited Bus Service': ["I don't see those buses run much anymore, either."],
#              'Fast Food Dominance': ["Every time we see a building being built, it's a fast food place."],
#              'Limited Lunch Options': ['So where are the teens going to go for that fast lunch that they have 45 minutes to have?'],
#              'Fast Food Prevalence': ["Every time they put a building up, I'm almost willing to bet every five out of seven are going to be a fast food place.",
#               'I am not sure why fast food places seem to come into a City first, but they always do.'],
#              'Unhealthy Food Choices': ['Not a restaurant fast food. Easy come easy go. Carbs, grease, and no activity after.',
#               'And fast food is cheap, unhealthy food is cheap, and it takes time and effort and money to be active and go to the gym and plan to eat healthy.'],
#              'Fast Food Convenience': ["I think it's faster and cheaper if they build a McDonald's."],
#              'Lack of Healthy Options': ['Where are the high school kids gonna go? Where are the elementary kids gonna go?'],
#              'Accessibility of Fast Food': ['If they can get there, its going to be faster and easier for them.'],
#              'Convenience Over Health': ["It's convenient. It's sad, but it's true."],
#              'Personal Inactivity': ['As far as inactivity,, I see it in myself sometimes, too.'],
#              'TV and Inactivity': ["We tend to become so inactive that we're just docile, our minds are turned off because of watching so much TV."],
#              'TV Habit': ['I found just this weekend I was home and I was exhausted by the end of the day but I found myself sitting down holding the remote going to a show that I know I always watch.'],
#              'TV Watching Despite Exhaustion': ["I can't tell you which ones they work because I was so exhausted. But I did it."],
#              'TV Watching as a Habit': ["And I think kids are just as bad as that. Yeah, we're all just used to it."],
#              'Hiking Trails in Payson Canyon': ['Payson Canyon does have some hiking trails that you have to get up into the canyon to do that.'],
#              'Frequent Hiking Location': ['We always go to Neva loop.'],
#              'Biking and Hiking Activities': ['And very often there are people that are either biking or hiking.'],
#              'Seasonal Activities': ["But that's seasonal."],
#              'Dangerous Conditions': ["I don't think there are any there right now because of the danger of mudslides and rock slides."],
#              'No Community Rec Center': ["I haven't seen a community rec center."],
#              'Total Fitness Costs to Use': ["There's a total fitness. It costs to use."],
#              'New High School with Potential After Hours Gym': ["They're building a brand new high school and they might have like an after hours, gym the kids can go to and play basketball or something."],
#              'Uncertainty': ["I don't know.", "I don't know."],
#              'Park in Downtown and Middle Payson': ['There is a park in downtown and middle Payson.'],
#              'Accessible Sports Facilities': ["A place for kids to go to play a couple of hours or an hour of basketball, inside or outside, it doesn't matter."],
#              'Diverse Sports Options': ["Have a net in there that they can play volleyball or I don't know what other games they play."],
#              'Inclusive Participation': ['But you know, boys and girls need to get involved, not just the boys, for sure.'],
#              'Affordable Recreation': ['And having it be free or affordable, absolutely.'],
#              'Senior Transportation Services': ['And they still need the shuttle services to pick seniors up.'],
#              'Regular Senior Socialization': ['I think they need to have a very affordable van system that they can send out three or four vans once a week or twice a week and get the seniors together and let them chit chat and and whatever they want to do for a couple of hours and go back home, get home safe, lock their doors and wait till the next week.'],
#              'Positive Outlook': ['Yeah, I think that would be really great.',
#               "That's what I think we have going for us."],
#              'Positive Perception of Payson Healthcare': ['I think Payson is set up very well. I really do.'],
#              'High Quality Revere Health and Hospital': ['Revere health and their hospital is pretty top notch.'],
#              'Prompt Problem Resolution': ["I've only had a couple of times that I've gotten there, but they've been right on top of the problem at the time."],
#              'Diverse Specialties and Subspecialties': ["And I think that they're welcoming doctors and administrators to come in from every single specialty and subspecialty to make it more appealing not to drive to Provo or drive to Orem or even Salt Lake."],
#              'Lack of Knowledge on Local Obesity Statistics': ['I am unsure of the statistics on obesity in Eagle Mountain City, but I know the dangers of obesity.'],
#              'Obesity Increases Health Risks': ['Obesity impacts Eagle Mountain community members by increasing our risks of Cardiovascular diseases, Type 2 Diabetes, increased blood pressure, increase Stroke risks, higher Osteo diseases, poor sleep, and far too many other risk factors to list.'],
#              'Universal Risk for Obesity': ['I believe pretty much everyone is at risk for obesity.'],
#              'No Biases in Obesity': ['I do not believe there are any biases when it comes to obesity.'],
#              'Sedentary Lifestyle and Overeating as Risk Factors': ['I think there are people with an increased risk for obesity, for example those that lead a sedentary lifestyle, but I think anyone can become obese if they consume too much food and not move enough.'],
#              'Surgery and Limited Mobility as Risk Factors': ['There are other risk factors with obesity, as well, for example people that have had a surgery and cannot move well.'],
#              'Asthma and Respiratory Disease as Risk Factors': ['People with Asthma or other respiratory disease that cannot exert themselves.'],
#              'Medications as Risk Factors': ['Or those that take certain medications, that lead to weight gain.'],
#              'Obesity Affects Everyone': ['It affects us all.'],
#              'Fast Food Availability': ['Some risk factors we have here are that most of the new Commercial development are fast food places',
#               "Yes. I mean, there are a lot of fast food restaurants in Payson, but I don't think it's really made an impact.",
#               'The behavior of eating out was normal in her life as Payson has fast food readily available.',
#               'But yeah, there are a ton of fast food restaurants like, even just like, you know, from my house you can walk to about 10-15 fast food restaurants.'],
#              'Long Commute Times': ['Most of our residents commute longer to work which causes those to sit longer'],
#              'Limited Exercise Time': ['Get home and leave earlier limiting time to exercise.'],
#              'Food Desert Formation': ['When we have so many fast food businesses here, it tends to create a food desert.'],
#              'Limited Food Options': ['I moved to Eagle Mountain City in 2007, when all we had was a gas station for the most part.',
#               "They don't get to go down there and like a restaurant or, you know, even a cafeteria, like you would see up on the campuses have, you know, 10 different choices of food they can eat today kind of thing.",
#               'So sometimes people eat what they have and know what they think is the best for them.'],
#              'Health Impact Assessment': ['As business started coming in, I thought that we should do a study of our health now with one gas station versus now with all the new fast food places.'],
#              'Convenience and Obesity Risk': ['I knew it would decline some, since convenience seems to always be a risk factor for obesity.'],
#              'Walking Paths and Bike Trails': ['Some of the greatest strengths we have in Eagle Mountain are our miles of walking paths and bike trails.'],
#              'Sports Programs for Children': ['We also partner with recreation league to offer sports to children.'],
#              'Community Resources for Obesity Prevention': ['Some of things we have that address obesity are walking paths, bike trails, sports to children, and we have a dance studio that offers exercise classes.'],
#              'Walking Paths': ['Walking paths'],
#              'Bike Trails': ['Bike trails'],
#              'Youth Sports Programs': ['Sports to children',
#               'I think there are certainly youth sports programs and other like things like that that are helpful.'],
#              'Dance Studio Exercise Classes': ['Dance studio that offers exercise classes'],
#              'More Solutions Needed': ['I definitely feel there are more things we can do to address obesity.'],
#              'Desire for Rec Center': ['Many residents, including myself, would love to see a rec center here offering exercise/nutrition classes, sports, swimming, and work out center.'],
#              'Nutrition Education in Schools': ['Nutrition classes should be offered to children in school, starting at a young age.'],
#              'Early Education for Lifelong Impact': ['If we have an educated foundation, starting young, we can carry that information with us the rest of our lives and disseminate that information.'],
#              'Community Fitness': ['I think for the most part the community was very fit'],
#              'Obesity Not as Prevalent': ["There was a little bit of obesity but I don't think it was as relevant as it was in other places."],
#              'Perceived Risk Factors': ['Oh, I don’t know um, this kind of sounds awful of me but I feel like the people that I saw the most that were most at risk would be kind of more underprivileged.'],
#              'Financial Constraints': ['Maybe their family didn’t have as much money.',
#               'lower income: less time and money to buy foods, no vehicles'],
#              'Limited Access to Resources': ['And maybe it’s just possibly because their family couldn’t afford for them to be on the soccer team, or buy the most nutritious foods.'],
#              'Sedentary Lifestyle': ['I think it could be a lot of like…I mean most of all growing up I just interacted with kids and so I feel like a lot of kids now are sitting inside and ipad kids.',
#               'I would say something that would impact it is maybe just like if someone was living… cause most people where I live. Specifically, in vineyard are working full time and graduated and stuff.',
#               "I think it's very easy to just be very sedentary.",
#               'Sedentary lifestyle',
#               'Like very sedentary.',
#               "And then, you know, if you're just sitting in class all day or working all day",
#               'Lack of exercise',
#               "Kids and pre-teens – stuck to screens all day and aren't going outside to play or go to the park"],
#              'Lack of Physical Activity': ['They’re not going out and being active as much, more sitting inside activities being sedentary.',
#               'And so maybe living just like a more sedentary lifestyle with work just like working a desk job, and then like not balancing that',
#               "I think that a lot of people these days aren't very active.",
#               "Less movement, you know, they don't spend too much time at the gym."],
#              'Online Society and Indoor Lifestyle': ['The kids live in a society where everything is more online and everyone stays indoors.'],
#              'Schools Promote Healthy Eating': ['I know a lot of school systems try to do the MyPlate to help people be healthy'],
#              'Limited Effectiveness of School Programs': ['I don’t think they really achieve that but the thought is there.'],
#              'Accessible Outdoor Recreation': ['There are a lot of trails in the area where people can go on walks or runs'],
#              'Easy Access to Recreation': ['It’s every accessible.'],
#              'Trails and Parks for Physical Activity': ['Basically the same thing, trails and parks that promote people to get out and move.'],
#              'Open Discussion': ["I feel like just having it be an open topic that's not taboo to talk about."],
#              'Non-Shaming Approach': ["Finding a way that's not body shaming to talk about it."],
#              'Encourage Open Discussion': ['I don’t know, um, yeah I guess just talk about it.'],
#              'Reduce Stigma': ['Or have it be less taboo'],
#              'Nutritious School Lunches': ['And making school lunches that’s actually nutritious'],
#              'Promote Physical Activity': ['And talk more about health benefits and ways to get out and move your body.'],
#              'Emphasize Good Nutrition': ['And good nutrition.'],
#              'Involve Medical Professionals': ['And maybe have doctors involved that know about this.'],
#              'Overweight Not a Huge Problem': ["I don't see as a huge problem, just at a glance, I mean, generally speaking, just because you're overweight, or a little overweight, doesn't mean that stops you from, you know, doing things that you like to do, you know, you can still go out shopping or you know, buy groceries or do activities with your family, like go to amusement parks or go to the pool, so it doesn't really impact you that way. So, I would say there's not a huge impact, I guess."],
#              'Middle Aged People More Obese': ['I would say probably that I find more middle aged people are obese than younger people.'],
#              'Higher Risk in Mid 30s - 40s': ["So I would say mid 30s - 40s there's a greater risk of you being obese."],
#              'Obesity and Lifestyle': ["I think the thing about obesity- and I don’t think all people choose to be obese- but it's just, you know, being healthy is a lifestyle."],
#              'Lifestyle Choices': ["And so it's how you choose to live, what you choose to eat, how you spend your time, and so on.",
#               'But yeah, I think just the main thing is how people choose to live.'],
#              'Obesity and Lifestyle Choices': ['I would say the majority of people who are obese are obese because of the way that they choose to live.'],
#              'Fitness Opportunities': ['So as far as, like, fitness activities and things they do have opportunities.'],
#              'Walking Trails': ["I know least in some areas, they've got little walking trails and things which I think is great- that encourages people and gives them a place to walk."],
#              'Fitness Bug': ['And so I mean, those are always a great thing to increase the, you know, fitness bug.'],
#              'Good Environment': ["As far as the environment, it's a good environment."],
#              'Historic Downtown': ["It's got a historic kind of downtown, which is fun for people to walk down."],
#              'Pros and Cons': ['So, it both has pros and cons.'],
#              'Lifestyle and Environment': ["I would say, all over the country of America in general, it's the lifestyle, the way that we live, the places that we live."],
#              'Walking Culture': ["In South America, you have to walk everywhere. In Japan, you're walking pretty much 90% of the time or taking public transportation."],
#              'Car Culture and Sedentary Lifestyle': ["But here, the way that we live, everybody's got a car. Everybody can work an inside job and everybody can take it easy if they want to take it easy."],
#              'Less Physical Activity': ['So because of that, that engenders less physical activity, which therefore makes it a harder time to be fit.'],
#              'Diet and Exercise': ['And so those who are fit are generally that way because they have taken the time and effort necessary to change their diet, to change their physical activity, and to be physically fit.'],
#              'Strong Community': ['In general, the community is pretty strong.',
#               'Lehi has a strong sense of community'],
#              'Community Support': ['They come together when something needs to be done, you know, people are there to support.',
#               "And one of the biggest things that it's hard to duplicate and, um, and why Provo Rec is successful is  It was built in the right location in the right community that voted yes,  this rec center and having recreational facilities and resources are important to us."],
#              'Community Leaders Influence': ['So having that can help influence community leaders, like the count City Council, to started putting on like a yearly Fun Run, or some kind of activity that could engender some fitness.'],
#              'Community Participation': ['People would prepare, they would train for that.'],
#              'More Activities Needed': ["Outside of that, I don't know precisely, but you can always have more activities and things like that."],
#              'Fairs and Events': ['Like if you have lots of fairs, or things like that, that entices people to come spend time walking around and being outside.'],
#              'More Activities and Attractions': ['So I would say do more activities for people and keep up with the walking trails, historic sites, the attractions-I know that they have a museum and Payson Museum of Art, which is super fun.'],
#              'Community Involvement': ['Get the community involved.',
#               'And there are lots of people involved that way.',
#               'And not just to schools like k through twelve, but also have it available to the community.',
#               'people need to get involved',
#               "It's always something to look at and help the community with.",
#               'I think there are lots of things that could be done in the community.',
#               'But I think we need to just have more community involvement.'],
#              'Unified Community Effort': ["If they're involved and they're of one mind, then it's going to have a greater impact."],
#              'Start with Leaders': ['So start with the top dog, whoever that is and spread the word.'],
#              'Engaging Activities': ['Have activities that give people reasons to be out and about versus just doing things from home.'],
#              'Limited Outdoor Activities': ['People don’t do the outside things when they’re unhealthy'],
#              'Elderly and Retired': ['Older people, retired.'],
#              'Recreational Facilities': ['Canyon in close proximity, pool, tracks; 2 gyms'],
#              'Food Assistance Programs': ['SNAP; Free and reduced lunch at schools; food sent home on weekends; food trucks in summers free lunch for 18 and under'],
#              'Weekly Dinner Groups for Healthy Cooking': ['Weekly dinner groups held to help learn how to cook healthy meals and feed family and share recipe'],
#              'Wrestling Fees Waived': ['City and school wrestling, waived fees?'],
#              '4H After School Activities': ['4H after school activities; running class'],
#              'School Sports Fees': ['School sports and extra curriculars: Upfront fee; tournaments and bus fees, food and lodging'],
#              'Proximity to Canyon': ['Living by the canyon.'],
#              'Limited Access to Outdoor Activities': ["If you're not healthy you don't utilize what is available; hiking, recreation."],
#              'Access to Quality Food': ["Food is good: Payson Market, Smith's, Costco"],
#              'Socioeconomic Disadvantage': ['Bad socioeconomic'],
#              'Excessive Screen Time': ['Kids babysat by TV',
#               'Kids on their phones too much, or electronics like video games.',
#               "Teens aren't sleeping, they're spending lots of time on social media, lots of time screen time"],
#              'Suboptimal Health Outcomes': ['Surviving and not thriving'],
#              'Personal Motivation': ['Individual drive.'],
#              'Poor Lighting and Location': ['Safety; not great lighting, right off I-15'],
#              'Socioeconomic Status': ['Lower socioeconomics',
#               'Lower income because of the price of food and eating more unhealthy.'],
#              'Lack of Knowledge and Time': ['Knowledge; time and effort; what is healthy, watching their peers eat; parents can offer it but you don’t want to fight it, bites per age. They learn it isn’t awful.'],
#              'Schools as Accessible Resource': ['Easier to reach in the schools'],
#              'Ignored Health Information': ['Flyers that don’t NEED the attention get trashed'],
#              'Limited Resources for Health': ['Survival mode; no time or resources to learn and know how to be healthy'],
#              'Outdoor Recreation Opportunities': ['Canyon 1.5 miles from home, lots of opportunity; pool and track at high school, creepy underground track'],
#              'Parks': ['Parks', 'We have parks.', 'Parks', 'all the parks'],
#              'Gyms': ['2 gyms – busy all the time'],
#              'Bike Rides': ['Bike rides – half uphill'],
#              'Food Pantry': ['I asked about food specific: Food pantry by city center; mini',
#               'We have the food pantry, which is amazing.'],
#              'Food Assistance Program': ['Tabitha’s way – online application for a food basket every week'],
#              'School Meal Programs': ['Free and reduced lunch at schools; food sent home on weekends; food trucks in summers'],
#              'Free Summer Triathlon': ['Summer triathlon for free'],
#              'Holiday 5K Events': ['Holiday 5K events'],
#              'Opportunity for Targeted Events': ['Nothing targeting, but opportunity'],
#              'Nutrition Education': ['Education -- teaching people how to eat; preparing food; word of mouth for those who cannot attend day of.'],
#              'Cooking Classes': ['Free with food to teach people how to cook it'],
#              'Food Sharing': ['Relief Society food share'],
#              'Exercise Groups': ['Yoga and Zumba groups in the stake center'],
#              'Free Activities': ['More free activities – waived entry fees'],
#              'Youth Sports': ['Wrestling 3 years to 8th grade is the city and then up is high school'],
#              'Payson is a good place to live in Utah County': ['Payson is a good place to live if you live in Utah County'],
#              'People come to Payson because it’s more affordable': ['People come to Payson because it’s more affordable'],
#              'High Prevalence of Depression': ["I would say there's a lot of depression going on."],
#              'Long-Term Therapy Experience': ["I've been doing therapy since 2008 when I graduated."],
#              'Recent Increase in Mental Health Issues': ["I would say there's definitely in the last few years been a big increase, right?"],
#              'Multiple Factors Contributing to Mental Health Issues': ["And you could attribute that to COVID, you could attribute it to social media, like lots of different things, but there's definitely been an increase in mental health issues. in the area."],
#              'Teens Most Affected': ['I would say teens probably the most.'],
#              'Young Adults Also Affected': ["And I mean, I work primarily with teens, but even within our office, I would say like that 13 to 22, like young adult range, there's a big impact there."],
#              'Loneliness and Isolation Lead to Depression': ['A lot of like loneliness, isolation, which leads to depression.'],
#              'More Women Seek Help for Depression': ["So yeah. We see more girls for sure, but also like statistics show like women tend to seek out therapy more so I don't know that that would mean more women are depressed just more women try to get help for it."],
#              'Social Media Influence': ['Social media',
#               'instagram account: kids eat in color'],
#              'Emotional Isolation': ['Loneliness, isolation'],
#              'Highland Area Specific': ["I think it's especially in the Highland area, right?"],
#              'Lone Peak Kids': ['Like if we have kids from Lone Peak'],
#              'Perfectionism and Ideals': ["There's a lot of perfectionism and kind of this ideal of what they should be"],
#              'Parental and Community Pressures': ['Like a lot of shoulds, a lot of pressures coming from their parents or the community'],
#              'Misalignment with Beliefs': ["And maybe they don't necessarily align with those beliefs"],
#              'Overwhelming Feelings': ['However, a lot of like saying that or sharing that feels very overwhelming'],
#              'Isolation as a Major Factor': ['Um, well, I think isolation is big, right?'],
#              'Sense of Belonging as Protective Factor': ["Like if, if people have like a community, whether it's a religious community, a theater community at school, a swim team, you know, like if people have a sense of belonging, that really helps a lot."],
#              'Loss of Belonging Linked to Depression and Loneliness': ["And if they lose that sense of belonging, or if they haven't found that sense of belonging, that can lead to more feelings of depression, loneliness."],
#              'Vicious Cycle of Isolation and Negative Emotions': ['Yeah. Because it becomes a cycle, right? They feel lonely, they feel not good enough, so they isolate, then they feel worse, and it just kind of continues.'],
#              'Schools Implementing Hope Squads': ['Well, it seems like a lot of the schools in the area have implemented like hope squads at the high schools, I think even some middle schools to try to help with kids who feel depressed or alone.',
#               'Well, it seems like a lot of the schools in the area have implemented like hope squads at the high schools, I think even some middle schools to try to help with kids who feel depressed or alone.'],
#              "Utah's High Suicide Rate": ["Like the state of Utah has really done a lot of work because I'm sure you're aware like our suicide rate is very high nationwide.",
#               "Like the state of Utah has really done a lot of work because I'm sure you're aware like our suicide rate is very high nationwide."],
#              'Efforts to Develop Crisis Programs and Make Therapy Accessible': ["So there's been a lot of effort with developing more crisis programs to try to help people and to try to make therapy more accessible.",
#               "So there's been a lot of effort with developing more crisis programs to try to help people and to try to make therapy more accessible."],
#              'Uncertainty About Effectiveness of Efforts': ["Yeah. I don't know how effective those things have been, but I know there's efforts being made.",
#               "Yeah. I don't know how effective those things have been, but I know there's efforts being made."],
#              'Shift in Attitudes Towards Therapy': ["I feel like there has been a good shift in the sense of like, you know, even from when I started being a therapist, like no one wanted to say they had a therapist, right? Whereas now when I like say that to a teen client, I'm like, hey, if I see you at Macy's here in Highland, like I won't say anything to you because of like confidentiality and they're like, oh, I don't care. Like all my friends have therapists. So I do feel like there has been a move towards like more people are in therapy, good thing."],
#              'Difficulty Finding Therapists': ['I think for a lot of people though probably the biggest problem is finding a therapist.'],
#              'Long Wait Lists and Bad Experiences': ["Yeah. Right. They just have a lot of wait lists and so people will often give up or get tired of looking because they can't find a therapist or they have a bad experience and they don't want to go back."],
#              'Insurance Coverage for Therapy': ['And there have been like, you know, like, insurance will cover therapy, like our agency does accept insurance, because I do think therapy should be accessible to most people, or to all people, really.',
#               'A good idea would be to get insurance companies on board with patients attending therapy, whether that be talk therapy or counseling visits.'],
#              'Limited Insurance Acceptance and High Costs': ["But so that does help. But only 20% of clinicians do accept insurance. And so those of us who do accept insurance often have really long wait spending $150 a week for a therapy session is not affordable. Right. Yeah. It's just like, well, okay, they can do that."],
#              'Importance of Variety in Options': ["I think it's important to have a variety of options available to most people, or to all people, really."],
#              'Helpful Options': ['But so that does help.'],
#              'Limited Insurance Acceptance': ['But only 20% of clinicians do accept insurance.'],
#              'Long Wait Lists for Insured Patients': ['And so those of us who do accept insurance often have really long wait lists.'],
#              'Faster Access for Out-of-Pocket Patients': ["And so it's like, well, if you can afford to pay out of pocket, then you can get in sooner."],
#              'Longer Wait for Uninsured Patients': ["But if you can't afford to pay out of pocket, then you're going to have to wait longer."],
#              'Acceptance of Inequity': ["And so it's like, well, okay, they can do that."],
#              'Positive Feedback on Discussion': ["No, I think it's great that you all are talking about this."],
#              'Awareness Normalizes Feelings': ['I think the more awareness, it helps normalize it for people too, right?'],
#              'Shared Experiences of Mental Health Issues': ["They're not the only ones who feel depressed or hot or anxious."],
#              'Information Sharing is Helpful': ['I think just getting information out into the community is really helpful.'],
#              'Obesity as Symptom': ['The interesting thing is obesity is a symptom and not a cause.'],
#              'Mental Health, Stress, Familial Issues': ['Ex mental health issues, stress and familial issues.'],
#              'Community Impact': ['All contribute and is a human condition the community faces',
#               "I don't see that it affects the community, other than what we might do to help service these community members."],
#              'Children and Families Affected': ['Nearly half residents are children so families are experiencing a list of changes'],
#              'Susceptibility to Condition': ['All are susceptible to the condition.'],
#              'Diverse Community with Vulnerable Populations': ['We have such a mix in the community like refugees, and families with special needs members which is a comorbidity for them.'],
#              'Elderly Living Alone': ['Also elderly far from family.'],
#              'Impact on All Community Members': ['It is something that impacts every once in the community.'],
#              'Commuting as Risk Factor': ['One of the things I think that puts us at greater risk is that we have to commute like 60-80% of residents work outside the community.'],
#              'Long Commute Time': ['We are too far out to use public transit, but we also spend more time from point A to point B due to commuting.'],
#              'Stress and Busy Schedules': ['Stressors and families and the busy schedules with that, and competes for their time.'],
#              'Family Stress': ['The overall stress on families and what they are going through.'],
#              'Public Transportation Improvements': ['There also needs to be changes and improvements to public transportation, because it’s very limited.'],
#              'Focus on Outdoor Spaces': ["Eagle mountain doesn't have a rec center, but they do put a huge focus on their trails, open spaces, and parks."],
#              'New Park Opening': ['Ranch park across from ridleys that will be open in the spring.'],
#              'Inclusive Park Design': ['It will be an all abilities for all ages.'],
#              'Skate Park Addition': ['A new skate park will be added as well.'],
#              'Focus on Health and Recreation': ['Obesity as a health issue is a huge focus of the city, so they want to give the Recreation activities for adults like pickleball, and for kids like baseball.'],
#              'Free Outdoor Recreation': ['The outdoors spaces are out there and at no cost'],
#              'Strategic Planning': ['City strategic plan and looked at the issues facing the city.'],
#              'Health and Safety Priority': ['6 focus items of the things that we do as a city and #1 is health and safety.'],
#              'Sustainability Focus': ['#5 sustainability (she will send you the plan)'],
#              'Parks and Recreation Background': ['Melissa started out in parks and recreation before she ran for student council.'],
#              'Parks and Greenspaces': ['The parks and greenspaces, as well as the master plan for outdoor spaces.'],
#              'Strategic Plan': ['The strategic plan.'],
#              'Strategic Plan Implementation': ['Following the strategic plan that was made.'],
#              'Accountability and Goal Achievement': ['Being accountable for those goals and reaching them'],
#              'Improving Member Health and Well-being': ['To improve the overall health and well-being of Eagle Mountain members.'],
#              'Eagle Mountain Awareness and Action': ['Just that eagle mountain is aware of the issue and is taking steps to address it in their own communities.'],
#              'Lack of Awareness in Communities': ["I think it affects everybody and most communities they don't address it or know how."],
#              'Recreational Facilities in Eagle Mountain': ['Eagle mountain has a lot of trails and pickle ball courts.'],
#              'Encouraging Resource Utilization': ['And just having people utilize those resources.'],
#              'Importance of Knowledge': ['Knowledge is power.'],
#              'Genetic Predisposition and Family Trends': ['If they have genetic predisposition or family trend over generation.'],
#              'School-Aged Children': ['Kids, even all school aged kids.'],
#              'Early Exposure to Technology': ['I pads for two year old kids.'],
#              'Parental Neglect': ["The parents give their kids iPad because they don't want to deal with them."],
#              'Lack of Encouragement for Physical Activity': ['Sports and extracurricular the community or families don’t push for that.'],
#              'Lack of Parental Involvement in Sports': ['They don’t push for parents to sign up their kids for sports.'],
#              'Middle Income Families': ['Majority of eagle mountain is middle income families in the area.'],
#              'Education Importance': ['Education is key!'],
#              'Grocery Purchases and Health Education': ['Buying groceries and health education.'],
#              'WIC vs Food Stamps and Obesity': ["For example WIC is very specific on what people can buy but food stamps don't do that which can be a contributing factor to obesity for lower income households."],
#              'Unhealthy Food Choices Due to Cost': ["They buy unhealthy food because it's cheaper."],
#              'Lack of Education on Healthy Eating': ['Needing to be educated on healthy eating.'],
#              'Lack of Access to Resources': ['Families need access to resources.'],
#              'Lack of Resources in Eagle Mountain': ['Eagle Mountain has no resources for meal planning, cooking, or healthy eating.'],
#              'Breaking the Cycle of Obesity': ['How to break the cycle of obesity'],
#              'Inclusion of Events in Schools and Communities': ['Include events in schools to teach schools about healthy eating and community events where they can teach parents about healthy eating.'],
#              'Food Stamps Make Healthy Choices Difficult': ['Also food stamps make it hard to make healthy choices, quantity over quality.'],
#              'Abundance of Recreational Facilities': ['They have lots of parks, like parks with tennis, basketball, and pickleball courts. Baseball fields, skate parks, bike parks.'],
#              'Accessible School Tracks': ['The school tracks are free to the public'],
#              'Failed Attempt at Rec Center': ["Tried to get a rec center in eagle mountain before. It hasn't been passed because it would raise taxes and people don't want to pay more taxes."],
#              'Outdoor Recreation Areas': ['Outdoor parks, green spaces, trails.'],
#              'Education at All Levels': ['Schools and education in general at any level.'],
#              'Promote Health and Nutrition through Newsletters': ["Maybe it's something that they can promote like having a newsletter that has a portion about health and nutrition so that the public can be more educated."],
#              'Doctors Provide Resources for Community Education on Obesity': ['Doctors have more resources for the community to help educate about obesity and diseases related to the cause of obesity.'],
#              'Offer Classes or Dietitians': ['Have a class or dietitian.'],
#              'Refer Patients to Community Classes for Obesity Management': ['Have them refer patients to community classes to address obesity that they have.'],
#              'Virtual Classes or Videos as Alternative Options': ['Or even virtual classes or videos.'],
#              'No Further Comments': ["I can't think of anything else to add.",
#               'Said nothing else came to mind.'],
#              'Impact on Some': ['It does have an impact on some.'],
#              'Depression Less Noticed than Anxiety': ['It seems that the people who suffer from depression are less noticed than those who suffer from anxiety.'],
#              'Lack of Support for Disabled Individuals': ['It seems that people who have a disability and do not have a support group such as family are greatly impacted'],
#              'Depression Affects Everyone': ['but I think that depression can affect all people.'],
#              'Risk Factors for Depression in Schools': ['The risk factors that I see in the schools for children with depression are a traumatic experience, loss or adverse childhood experience, and not a good support system.'],
#              'Lack of Professional Help': ['Often they do not get professional help.'],
#              'Religious Leaders Preferred Over Professionals': ['I believe that in this area too often people use religious leaders instead of professional people for treatment of mental health issues.'],
#              'Religious System for Affordable Professional Help': ['There is a system through the prominent religion where people can get affordable professional help.'],
#              'Medical Doctors Addressing Issue': ['There are several medical doctors who are very good at addressing this'],
#              'Therapists and Counselors Available': ['as well as many therapists and counselors'],
#              'School District Addressing Issue': ['The school district is addressing this in the schools with PBIS and SEL curriculums'],
#              'Affordability': ['It needs to be more affordable',
#               'I don’t think it has to be expensive.',
#               'Even spend less money.'],
#              'Teacher Training': ['School teachers need to be trained'],
#              'Mental Health Awareness': ['To address and recognize mental health issues'],
#              'Limited Extracurricular Activities': ['Not many extracurricular activities outside of school – more for youth, not the older population.'],
#              'High Fast Food Density': ['Has a lot of fast-food restaurants and new ones coming'],
#              'Targeting Addicted Individuals': ['This targets those people who already are addicted and can cause more problems'],
#              'Middle-Aged Adults': ['40-60 year olds'],
#              'Limited Outdoor Activities for Adults': ['Not many outside activities for adults'],
#              'Sedentary Events': ['Lots of sitting events.'],
#              'Free Food at Concerts': ['For example: concerts at parks where they pass free ice cream and popcorn'],
#              'Education Level': ['In rural parts, there are fewer educated people so that can be a factor'],
#              'Lack of Participation in Classes': ['If there are classes, people do not go because people are constantly leaving and going from the city.'],
#              'Church Offers Financial Education but Low Participation': ['Church with finance classes and self-reliance, however, people do not get involved as much.'],
#              'Transient Community Members': ['People come and go.'],
#              'Small Gym with High Utilization': ['Has a small gym that is usually full because of the size.'],
#              'Hospital Provides Many Resources': ['The hospital has a lot of resources'],
#              'Pickleball Court Added for Older Adults': ['Switched one of the tennis courts to be a pickleball court to target older generation'],
#              'Church Resources': ['Church with finance classes and self-reliance, however, people do not get involved as much. People come and go.'],
#              'Small Gym': ['Has a small gym that is usually full because of the size.'],
#              'Hospital Resources': ['The hospital has a lot of resources'],
#              'Pickleball Court': ['Switched one of the tennis courts to be a pickleball court to target older generation'],
#              'Knowledge Availability and Behavior Change': ['Having more availability of knowledge and helping people change their behavior.'],
#              'Promoting Healthy Habits': ['Things that promote healthy living and eating.'],
#              'Fast Food vs. Healthy Options': ['There is a lot of fast food, so putting healthier food places to promote healthier eating.'],
#              'Quick and Easy Healthy Options': ['Options that are quick and easy that promote higher quality of eating'],
#              'General Perception of Healthy Living': ['In general, she believes that people are healthily living, however the minority is excluded.'],
#              'Minority Exclusion from Healthy Living': ["Minority: Poor people and those who aren't educated and do not have a good financial standing."],
#              'Personal Perspective': ['Personally, let’s see. That is a really good question.'],
#              'Uncertainty due to Work Schedule': ['I am not super sure because I work a lot.'],
#              'Perception of Community Health': ['But when I do interact with people in the Lehi community, they seem fine.'],
#              'Limited Interaction with Residents': ['I don’t think that I interact with other residents enough to understand this issue.'],
#              'Students at Risk': ['Probably students. College or high school.'],
#              'Personal Experience with Depression': ['Speaking from my own experience as someone who was depressed in college and also a little bit in high school.'],
#              'Minority Groups at Risk': ['I also feel like minority groups in Lehi might experience depression more, just because of who difficult it might be to form communities.'],
# ...
#              'Nutrition and Macro-Based Meals': ["I, I do, I use the company factor and I get their meal delivery, but I get it because there's this like nutrition and macro-based meals."],
#              'Seeking Out Healthier Meals': ["It's for people who are trying to eat healthy. And that has been very helpful, but it is a little bit harder. To, you have to seek them out. The companies are sown to healthier meals. And they were a little pricey."],
#              'Affordability Concerns': ["in college, there's no way I would be, I would have afforded this."],
#              "Teenage Boys' Lunch Options": ["mean, my, and I've got, um, I've got teenage boys right now that go to Provo High, and One of them said, hey, instead of the 3 that you pay every time I put my code in at lunch to get a lunch  Can you just Venmo me 3 and so I can go with my friends? And he's like I can go to McDonald's so I can get like a spicy I can get two spicy chicken sandwiches, and I was like, whoa McDonald's every day he goes  He goes, what do you think they serve me at high school?"],
#              'Limited Healthy Options': ["I said, well, I don't know, don't you have options? He's like, yeah, it's like pizza, or it's french fries, or it's like a burger. It's a lot of the same stuff. And I said you don't have like a lot of healthy options? He's like, yeah, we can get sandwiches once in a while, but you know, not too many teenagers are getting that. "],
#              'Ubiquitous Unhealthy Food': ["I mean, it's all over and all over the place, so it's just, you have to almost go out of your way to avoid that because even as a parent and my kids,  that's funny because they'll laugh at my husband and I "],
#              "Children's Perception of Normal Snacks": ["because they say, Oh, how come we don't have normal snacks in our house? Like others, like our friends are like, Oh, what do you mean?"],
#              'Cost of Healthy Food': ["We have a lot to be, I mean, He just like, dropped almost a thousand bucks at Costco, like don't tell me we don't have food."],
#              "Children's Desire for Junk Food": ["He's like, yeah, but it's not the good food. I said, well, what's the good food? Well, we want like Cheetos and we want, you know, okay, they want all the junk that we don't buy."],
#              'Occasional Treats vs. Regular Junk Food': ["We just, and not to say that we don't ever buy a bag of. Tortilla chips and salsa that we just don't buy a lot of junk and that's just our normal household"],
#              "Children's Exposure to Processed Foods": ["But when they go a lot of other places They see the abundance of shelves and shelves of processed foods and snacks and stuff Yeah, that's just norm. That's what they see as normal"],
#              "Shaping Children's Food Preferences": ["So, it's kind of like breaking that mold of what is our norm. What are we feeding our kids? So that when they go to college, of course, why would they want to eat healthy things if they've been eating Cheetos and stuff, r"],
#              'Imperfect Parenting': ["I'm no perfect parent."],
#              'Fatigue and Work-Life Balance': ["There are nights I work late, I'm tired, we're all tired"],
#              'Family Outing': ["We're going to Blaze Pizza, you know?"],
#              'Emphasis on Activity and Value': ['I think some of our greatest strengths is our emphasis on activity and our value behind it.'],
#              'Abundance of Resources': ['There are so many resources. We have a ton of gyms. We have inexpensive gyms. We have, you know, rec center, we have a big, huge, beautiful rec center.'],
#              'Free Parks and Walking Trails': ['We have absolutely free parks and walking trails, miles and miles of them. So many of them.'],
#              'Inexpensive or Free Activities': ['Um, We have lots of inexpensive or free, um, you know, five Ks we have, um, I mean, just there is really, truly an abundance of activity in these areas and outdoor things, um, that people can participate in.'],
#              'Food as a Necessity': ["One thing that would be so great, and this is,  I mean, this is  definitely more on the state government level and not just, you know, local Provo level, so this probably doesn't, this portion may not answer your question, but I have always said I wished that we could lobby that, um, that food, like groceries and things, like food is a  necessity for life, right?"],
#              'Food is Not an Option or Privilege': ["We all need it. It's not a, uh, It's not an option or a privilege, l"],
#              'Affordable Fresh Produce': ['making fresh fruits and stuff more affordable.'],
#              'Strong Offerings': ['I would definitely say provost strengths would be Many offerings of very strong.'],
#              'Strong Community Sense': ["So I think provo definitely has a very strong sense of community um there, you know, you you don't have to be a member of the lds church to Participate in resources that they offer but you know Either through church through community."],
#              'Free Community Classes': ["There's so many um free Um, things, and, um, community classes that are even free if you want help on learning how to ELD, like, um, there's, there are classes out there that exist, you know?"],
#              'Proactive Approach Needed': ["I think it's just People being a little bit more proactive. You really have to be proactive. There can be all the resources in the world, but if you sit back and expect everything to just come to you, it doesn't work that way."],
#              'Fight for Health': ['You have to go out there and you have to fight for your health. You have to start with a desire and then start asking for help and the resources really are there.'],
#              'Utah County Health Department Provides Free Resources': ["know that if you, um, reach out to the Utah County Health Department, which is down here in Provo, um, that they, um, are pretty, they're really good about providing, like, here are some free resources."],
#              'Baby Your Baby Program Offers Free Courses and Passes': ['I know that they have the Baby Your Baby program, and they provide free courses. And passes and things to help mothers get back on their feet.'],
#              'Many Organizations Offer Support': ["Um, I know, and I've heard of so many different organizations and things. It'd be hard for me to rattle all of them off."],
#              'Health Department Can Provide Information on Free Programs': ["But that is like a specific place that you can call and they do know of all the free programs. And can kind of, you know, go down the list with someone for what they're looking for."],
#              'Provo Rec Center Offers Reduced Membership Costs for Residents': ['Um, I mean we, at the, the Provo Rec Center does provide, um, for residents. They have, uh, you know, reduced membership costs here because of, um, you know, the taxes that they pay into for living in Provo.'],
#              'Low and Affordable Membership Costs at Provo Rec Center': ["And so, um, I think that we've kept, um, the memberships here extremely low and affordable, um, to provide something great for the community."],
#              'National Recognition': ['We have people from all over the country come out and tour and try to figure out how to duplicate some of our success.'],
#              'Taxpayer Funding': ['And so the voters voted to have tax money go towards a facility like this and have programs like this.'],
#              'Financial Assistance Available': ['I, our sports program is phenomenal and I, I believe that there are scholarships and things that people for low income can apply for to get financial assistance, um, for to enroll their kids in these different programs and sports.'],
#              'Encouragement to Seek Help': ["So, it's one of those things where it can feel daunting, like maybe as a parent or, um, You know, family, or even as an individual, if you are struggling to get on your feet,  I would encourage people to reach out and a"],
#              'Inquiry about Available Programs': ['Hey, are, are there any programs or things I can apply for?'],
#              'Acknowledgment of Available Funds': ["There are, um, you know, there's money that gets set aside to help people that are in need."],
#              'Communication and Information Access': ["It's getting the communication, the information out there to people that so many things and resources exist, but you have to just ask for it."],
#              'Multiple Sources for Guidance': ['You have to, and sometimes You have to ask a few different places to get pointed in the right direction.'],
#              'Connecting People with Resources': ['So, just trying to connect people that have a desire to have, you know, those resources, um, is key.'],
#              'Means for Resource Utilization': ['And then, there are plenty that have the means to do it.'],
#              'Encouraging New Experiences': ['You know, I think that they just have to get out there and try something new, try something fun.'],
#              'Starting with Physical Activity': ["My biggest advice to people when they're trying to get going with, like, a health and a nutrition program, not even just nutrition, but just, just health, like, you know, whether it's exercise, whatever it is, I would say, just start by moving your body."],
#              'Exploring Different Forms of Exercise': ["Go for a walk. Go walking. And then from there, if You know, if you feel like you are someone who exercises torture, there's so many different ways to move your body."],
#              'Experimentation and Discovery': ['Find something. Try a lot of different things. You may be surprised. You'],
#              'Discovering New Interests': ['You might find out that you like some of these random activities.'],
#              'Trying New Things': ['Go sign up and try something new and find that thing that you enjoy.'],
#              'Consistency': ['And stick, and stick with that.'],
#              'Stepping Out of Comfort Zone': ['Um, because there are so many neat things out there if you get out of your comfort zone and just stick to the plan.'],
#              'Waiting for Motivation': ['You know, a lot of people wait for motivation to kick in, to go and start a healthy program, right?'],
#              'Action Precedes Motivation': ["But, the truth of the matter is, in my experience and life, and over the many years that I've coached people, Motivation only comes after you are willing to take action."],
#              'Action Leads to Motivation': ['So action typically has to happen first, and then the motivation comes through.'],
#              'Taking the First Step': ['But you have to take that first step.'],
#              'Discipline and Desire': ['You have to have at least a little bit of that discipline and desire to have something better for yourself to move.'],
#              'Positive Reinforcement': ["And, um, and then it's amazing how much motivation and encouragement Uh, and positive affirmation as to what you're doing comes after that."],
#              'Schools Worked At': ['I work at three schools, elementary, junior and high school.'],
#              'Limited Adult Interaction': ["I can't really speak for the adult population too much other than like maybe some parents I interact with."],
#              'Depression Impacting Junior High and High School': ['But I do see depression impacting, I would say junior high and high school.'],
#              'Decent Amount of Impact': ['Yeah, like at a decent amount.'],
#              'Anxiety at Junior High Level, Depression at High School Level': ['I would say maybe a little bit more anxiety at the junior high level, a little more maybe depression at the high school level.'],
#              'Yearly Variation': ['Every year is a little different though.'],
#              'Seeking Commonalities in Depressed Students': ['I wonder if I could like find a trend about like what.. like the common theme between the students I see with depression.'],
#              'Anxiety as a Comorbidity of Depression': ["Well, I definitely see the kids with anxiety, those comorbidities are like, if they've got anxiety, there is a good chance they also have depression."],
#              'ADHD as a Comorbidity of Depression': ["If they have ADHD, there's also a good chance they have depression."],
#              'Variation in Severity of Depression': ["depression, I do sometimes see some severe clinical type cases of depression, but a lot of the students have just some symptoms that maybe not.  It's a DSM classification."],
#              'Comorbid Disorders as Vulnerable Population': ['So yeah. So you asked, okay, so most vulnerable at risk population. Oh yeah, the comorbid disorders.'],
#              'Lack of Support System as Risk Factor': ['I think the kids without a lot of structure or family or like support system, like something really foundational, you know, like or strong or steady, they kind of need to have a like a foundation, I guess, a support system.'],
#              'Truncated Response': ['Yeah, that totally makes sense. And then, you know, the tr'],
#              'Trauma Background': ['auma kids, of course, like the ones who come from a little bit of a trauma background, they are more at risk.'],
#              'Additional At-Risk Populations': ['What else? Let me see.'],
#              'Majority of At-Risk Populations': ["I think that's probably the majority."],
#              'Stress as a Major Cause': ["Well, when I asked my students about like some of the things that caused some of those feelings, of course, a lot of it's stress."],
#              'Social Stress and Inadequacy': ["A lot of it's like the, it could be social stress, just kind of having this general sense of inadequacy academically or socially."],
#              'Risk Factors for Depression': ['So risk factors causing depression.'],
#              'Struggling in School': ["I guess struggling in school, that's a hard one for kids."],
#              'Social and Academic Struggles': ['Just struggling socially and academically.'],
#              'Importance of School at This Age': ["Cause it's such a big part of their life at this age."],
#              'Social and Fitting In': ["It's kind of all they care so much about like the social and fitting in."],
#              'Lack of Social Support': ["And if they don't kind of have a person or a group, I feel like they're very much, it's one of those at risk factors."],
#              'Internal Struggles': ["Oh, right. That's such a tricky one, because it's like, sometimes it's just so internal, you know, and it's like, they just are really hard on themselves."],
#              'Depressive Mindset': ['They just have a kind of a depressive mindset where they just see the world a little bit through like, Oh, nobody likes me.'],
#              'Internalized Experiences': ["And, you know, even though there's no facts behind it, sometimes I do think they had previous experiences that they internalized really deeply, like some bullying stuff,"],
#              'Fear of Bullying': ["Or they're so worried about potentially getting bullied that they just kind of avoid trying to put themselves out there and belong with a group."],
#              'Mindset Matters': ["So that's part of it. So I think some of it definitely has to do with the mindset though."],
#              'Accurate Perception': ["Like they don't always see it accurately. So that's one of the things I really try to work on with kids."],
#              'Assessing Situations': ['Just to really like accurately try to assess the situation so they can, you know, feel better.'],
#              'Cognitive Behavioral Therapy': ["Like some of the cognitive behavioral therapy, you've probably heard about that."],
#              ...})

# %%
keys_with_multiple_values = {key: values for key, values in master_map.items() if len(set(values)) > 1}
keys_with_multiple_values
# Out:
# {'Economic Factors': ['Economic circumstances',
#   'I think economic factors play a big part.'],
#  'Lack of Nutritional Knowledge': ['Most people struggle to know what foods are best for them',
#   "I think part of it is education, not knowing how foods work, which impacts us negatively, and we don't eat healthily.",
#   "Maybe families that they don't know exactly about everything, you know, nutritional based too."],
#  'Active Lifestyle': ['Outdoor community/community that supports outdoor activities',
#   'Like people are always walking outside or running or going to the gym.',
#   'I grew up playing sports and was surrounded by athletes.'],
#  'Childhood Obesity': ['And I see these children getting heavier.',
#   'Young obesity'],
#  'Fast Food Prevalence': ["Every time they put a building up, I'm almost willing to bet every five out of seven are going to be a fast food place.",
#   'I am not sure why fast food places seem to come into a City first, but they always do.'],
#  'Unhealthy Food Choices': ['Not a restaurant fast food. Easy come easy go. Carbs, grease, and no activity after.',
#   'And fast food is cheap, unhealthy food is cheap, and it takes time and effort and money to be active and go to the gym and plan to eat healthy.'],
#  'Positive Outlook': ['Yeah, I think that would be really great.',
#   "That's what I think we have going for us."],
#  'Fast Food Availability': ['Some risk factors we have here are that most of the new Commercial development are fast food places',
#   "Yes. I mean, there are a lot of fast food restaurants in Payson, but I don't think it's really made an impact.",
#   'The behavior of eating out was normal in her life as Payson has fast food readily available.',
#   'But yeah, there are a ton of fast food restaurants like, even just like, you know, from my house you can walk to about 10-15 fast food restaurants.'],
#  'Limited Food Options': ['I moved to Eagle Mountain City in 2007, when all we had was a gas station for the most part.',
#   "They don't get to go down there and like a restaurant or, you know, even a cafeteria, like you would see up on the campuses have, you know, 10 different choices of food they can eat today kind of thing.",
#   'So sometimes people eat what they have and know what they think is the best for them.'],
#  'Youth Sports Programs': ['Sports to children',
#   'I think there are certainly youth sports programs and other like things like that that are helpful.'],
#  'Financial Constraints': ['Maybe their family didn’t have as much money.',
#   'lower income: less time and money to buy foods, no vehicles'],
#  'Sedentary Lifestyle': ['I think it could be a lot of like…I mean most of all growing up I just interacted with kids and so I feel like a lot of kids now are sitting inside and ipad kids.',
#   'I would say something that would impact it is maybe just like if someone was living… cause most people where I live. Specifically, in vineyard are working full time and graduated and stuff.',
#   "I think it's very easy to just be very sedentary.",
#   'Sedentary lifestyle',
#   'Like very sedentary.',
#   "And then, you know, if you're just sitting in class all day or working all day",
#   'Lack of exercise',
#   "Kids and pre-teens – stuck to screens all day and aren't going outside to play or go to the park"],
#  'Lack of Physical Activity': ['They’re not going out and being active as much, more sitting inside activities being sedentary.',
#   'And so maybe living just like a more sedentary lifestyle with work just like working a desk job, and then like not balancing that',
#   "I think that a lot of people these days aren't very active.",
#   "Less movement, you know, they don't spend too much time at the gym."],
#  'Lifestyle Choices': ["And so it's how you choose to live, what you choose to eat, how you spend your time, and so on.",
#   'But yeah, I think just the main thing is how people choose to live.'],
#  'Strong Community': ['In general, the community is pretty strong.',
#   'Lehi has a strong sense of community'],
#  'Community Support': ['They come together when something needs to be done, you know, people are there to support.',
#   "And one of the biggest things that it's hard to duplicate and, um, and why Provo Rec is successful is  It was built in the right location in the right community that voted yes,  this rec center and having recreational facilities and resources are important to us."],
#  'Community Involvement': ['Get the community involved.',
#   'And there are lots of people involved that way.',
#   'And not just to schools like k through twelve, but also have it available to the community.',
#   'people need to get involved',
#   "It's always something to look at and help the community with.",
#   'I think there are lots of things that could be done in the community.',
#   'But I think we need to just have more community involvement.'],
#  'Excessive Screen Time': ['Kids babysat by TV',
#   'Kids on their phones too much, or electronics like video games.',
#   "Teens aren't sleeping, they're spending lots of time on social media, lots of time screen time"],
#  'Socioeconomic Status': ['Lower socioeconomics',
#   'Lower income because of the price of food and eating more unhealthy.'],
#  'Parks': ['Parks', 'We have parks.', 'Parks', 'all the parks'],
#  'Food Pantry': ['I asked about food specific: Food pantry by city center; mini',
#   'We have the food pantry, which is amazing.'],
#  'Social Media Influence': ['Social media',
#   'instagram account: kids eat in color'],
#  'Insurance Coverage for Therapy': ['And there have been like, you know, like, insurance will cover therapy, like our agency does accept insurance, because I do think therapy should be accessible to most people, or to all people, really.',
#   'A good idea would be to get insurance companies on board with patients attending therapy, whether that be talk therapy or counseling visits.'],
#  'Community Impact': ['All contribute and is a human condition the community faces',
#   "I don't see that it affects the community, other than what we might do to help service these community members."],
#  'No Further Comments': ["I can't think of anything else to add.",
#   'Said nothing else came to mind.'],
#  'Affordability': ['It needs to be more affordable',
#   'I don’t think it has to be expensive.',
#   'Even spend less money.'],
#  'Lack of Awareness': ['I actually am not aware of any other ones.',
#   "We're, we're not seeing those connections of how we celebrate and how we are treating food and stuff",
#   "I'm not aware of anything.",
#   "They don't know what they don't know.",
#   "Don't see obesity around me",
#   "My neighborhood was mostly old people, so I couldn't really tell obesity was a problem."],
#  'Talking Helps Reduce Stigma': ["That's a good question. I feel like this can apply to Lehi, but just talking about it more, I feel like could help, you know, reduce the stigma.",
#   'I feel like this can apply to Lehi, but just talking about it more, I feel like could help, you know, reduce the stigma.'],
#  'Community Gathering Spaces': ['We will be gathering spaces where people can host classes in the community.',
#   'Gathering locations.'],
#  'Lack of Community': ['There is a lack of a sense of community',
#   "There are families in our area but like sound like a lot of houses are full roommates or you know things like that like we're not really like a super community, like I lived in a house for 3 years and talked to people across the street like twice.",
#   "And so I feel like there's not like a really big sense of community."],
#  'Low Obesity Perception': ["I don't see a lot of obese people here.",
#   'Doesn’t perceive super high rates of obesity in his area',
#   'more often than not, like I would say… obesity is just not something we see very much of.If I were to put a number and this is just me spitballing a number right. So there’s no research or anything behind it. It’s probably like maybe ….20% at most would fall under that category.'],
#  'Active Community': ['I feel like vineyard/orem is a very active area.',
#   'She sees this a more active community'],
#  'No Specific Resources': ['I do not see anything specific to that...',
#   'Not aware of any specifically.'],
#  'Lack of Knowledge': ["I can't think of anything.",
#   "I honestly don't know",
#   "I don't know enough about the problem and the severity of the problem to give an opinion on that.",
#   "So I don't know enough to give it a minute.",
#   "I think they don't know how to deal with it and how to take care of themselves.",
#   'Said she doesn’t know of any'],
#  'No Additional Resources': ['Only the things stated above',
#   "I'm not aware of anything else in particular."],
#  'Community Events': ["I don't know how regular things like five ks or races and stuff like that happen in orem, but maybe they could push for more of those, maybe give more opportunities at a community level",
#   "Spanish Fork is really good at like the Harvest Moon Festival and Fiesta Days and like they do events, but it's family events, not kids or teenager events and it's great I'm not sure how you would do that, but if you could, I think that's a good place to start."],
#  'Limited Access to Healthy Food': ['Less access to healthy nutritious food, people are in a rush (college kids) so they are less likely to prepare a meal.',
#   'Not a ton of healthy food (closest place to get fresh produce is more than a mile away)'],
#  'Bike Lanes': ['Bike lanes', 'Oh, and there are bike lanes.'],
#  'Resistance to Change': ['He thinks that people have already made their mind up and just don’t want to change habits.',
#   'A lot of people are hesitant to change.'],
#  'Encouraging Healthy Eating': ['So to encourage, you know, uh, more, you know, more consumption of those items.',
#   'But you know, try to eat healthy food'],
#  'Educational Attainment as a Factor': ['Since my students are like less at risk, I would have to say probably educational attainment is probably a factor in there.',
#   'Educational attainment for sure is a factor.'],
#  'College Students': ['the one thing I could think of would be, so with college students.',
#   'College students'],
#  'Personal Observation': ['I think that’s what - what i’ve been seeing.',
#   "At least from what I've seen"],
#  'Uncertainty about Resources': ["Whatever they are we don't know what they are",
#   "I'm not 100% sure."],
#  'Social Media Usage': ['I don’t know if their big social media users',
#   'social media'],
#  'Low-Income Patients': ["With the care clinic, you have to be below the poverty line to even go there because they can't afford health care.",
#   "This could be stretching, but I think part of the reason we get such a high obese population in the people who come is because they're all so low income."],
#  'Limited Treatment Options': ["But then there's only so much we can do at that point.",
#   "And then it's like, we can't really do very much about it."],
#  'Low Income': ['And these people are pretty much working and living paycheck to paycheck.',
#   'Low income'],
#  'Limited Resources': ["So that's not a luxury they really have.",
#   'But I understand that some homes are just barely getting by.'],
#  'Lack of Time for Cooking': ["But it's like not the best choice in terms of your health, and then, you know, we don't have time to cook as students, so a lot of kids do eat out a lot.",
#   'Most people who live here are busy and don’t have time to make food, so they go out to eat',
#   'Mom and dad work all day jobs and have to keep going but have zero time to make dinner, so its easier to go through the drive thru and pick up something quick'],
#  'Education as Key': ['I think education is key.',
#   'It’s almost from an education standpoint and it could be from a county level teaching in schools the basics.'],
#  'Long-term Resident': ['I grew up here too.',
#   'I have lived in Lehi for much of my childhood and continue living here'],
#  'Environmental Factors': ['I also think environmental issues could be a real problem.',
#   'Environmental factors such as neighborhood safety and access to parks and recreational facilities'],
#  'Existing Programs': ["I think my best answer to that is something I've already said and that is what programs we have in place.",
#   'What program we already have in place.'],
#  'Convenience of Fast Food': ["Why would I drive 15 minutes to the grocery store, when I can walk one minutes to In and Out Burger and it's way easier and more convenient.",
#   'Okay, this is easier for people to get food.'],
#  'Car Dependency': ["to go outside without the car. Because if not, it's like, okay, you need a car pretty much for everything.",
#   'Rely heavily on cars/buses to get you places'],
#  'Cultural Norms': ["And that's just the culture, you know.",
#   'Cultural norms around food and exercise',
#   "I think it's also just the nature of our culture."],
#  'Low-Income Families at Risk': ['Low-income families are a risk because of lack of resources.',
#   'Children from low-income families are often more vulnerable to obesity due to limited access to healthy food options and opportunities for physical activity.'],
#  'Social Isolation': ['social isolation',
#   'primary reason for social isolation',
#   'Social isolation is very prevalent.'],
#  'Community Connection': ['when she was a new mom at Y-view she was connected to her ward and would go on walks with other moms.',
#   'being connected to the community is protective'],
#  'Community Strengths': ["For kids, swim team that's year round and huge summer swim team, more rec based program (good community outreach) almost 400 swimmers in summer, fitness classes outreach for moms, seniors fitness programs active aging, water classes and others focused on seniors, grown and grown.",
#   'Springville has several strengths that can be leveraged to address obesity'],
#  'Time Constraints': ["Time - people don't make time for healthier foods",
#   "Yeah, they don't have time to make food."],
#  'Collaborative Efforts': ['Collaborative efforts involving healthcare providers, schools, local government, and community organizations are essential for making meaningful progress',
#   'Collaboration between healthcare providers, schools, local government, and community organizations is crucial for implementing effective interventions'],
#  'Positive Perception of Lehi': ['Overall, I feel like Lehi is doing a great job.',
#   "I know it's generally pretty good"],
#  'Conjecture': ['That is a little bit of conjecture on my part,',
#   'Again, all this is with conjecture.',
#   "So those are the best I can answer, but it's just conjecture."],
#  'Affluence as a Factor': ['So affluence is a factor.',
#   'I think a lot of it has to do with affluence.'],
#  'Comparison to Others': ['People feel like everybody else is happy but me.',
#   'Well, I would go with, I would actually say, I think we see it a lot in like comparison, comparing ourselves to others.'],
#  'Teenage Mental Health Challenges': ['We see it a ton in teenagers in the community trying to balance comparing and then dealing with family issues.',
#   "And also in teenagers a ton, because I think in American Fork specifically, when I work with teenagers that live here, they're dealing with their like regular teenage issues. But they're also, I work with a lot of LGBTQIA plus teenagers and oft"],
#  'Perfectionism and Social Media Comparison': ['I think in the American Fork, we probably see the perfectionism we see, um, social media creates comparison, um, often leaves us comparing ourselves to others.',
#   'I think in the American Fork, we probably see the perfectionism we see, um, social media creates comparison, often leaves us comparing ourselves to others.'],
#  'Weight Control': ['But I explored, but now I need to control my weight.',
#   'I need to control my weight.']}

# %%
def create_master_map(group):
    master_map = defaultdict(list)
    for json_list in group['json_list']:
        for item in json_list:
            text = item.get('Original_Text')
            code = item.get('Code')
            if text and code:
                master_map[code].append(text)
    return master_map

map_df = df5.groupby(['prompt', 'Q3_Health Problem']).apply(create_master_map).reset_index(name='master_map')
# Out:
# /var/folders/fk/rsz_slmj7wj_dw8gjqj0qvsc0000gn/T/ipykernel_21856/948372455.py:11: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   map_df = df5.groupby(['prompt', 'Q3_Health Problem']).apply(create_master_map).reset_index(name='master_map')

# %%
def extract_codes_by_prompt(df):
    grouped = df.groupby(['prompt', 'Q3_Health Problem'])['json_list'].apply(
        lambda json_lists: [entry['Code'] for json_list in json_lists for entry in json_list]
    )
    return grouped



# Apply the function to df4 and get a list of lists
all_codes = extract_codes_by_prompt(df5).reset_index()

all_codes.head()
# Out:
#                     prompt Q3_Health Problem  \
# 0        Q10_Health Impact        Depression
# 1        Q10_Health Impact           Obesity
# 2  Q11_At-Risk Populations        Depression
# 3  Q11_At-Risk Populations           Obesity
# 4         Q12_Risk Factors        Depression
#
#                                            json_list
# 0  [High Prevalence of Depression, Long-Term Ther...
# 1  [Disproportionate Impact on Poor, Limited Food...
# 2  [Teens Most Affected, Young Adults Also Affect...
# 3  [At-Risk Population, Universal Risk for Obesit...
# 4  [Social Media Influence, Emotional Isolation, ...

# %%
myL = np.array([1,2,3,4,5])
labels = np.array([0,0,1,1,1])

np.where(myL == (max(myL[labels==1])))
# Out:
# (array([4]),)

# %%
import numpy as np
from sklearn.preprocessing import normalize

class KMeansCosine:
    def __init__(self, n_clusters=3, max_iter=300, tol=1e-4, random_state=None):
        self.n_clusters = n_clusters
        self.max_iter = max_iter
        self.tol = tol
        self.random_state = random_state
        self.centroids = None
        self.labels_ = None
        self.centers = None

    def _cosine_similarity(self, X, Y):
        # Cosine similarity = dot product of normalized vectors
        return np.dot(X, Y.T)

    def _initialize_centroids(self, X):
        if self.random_state:
            np.random.seed(self.random_state)
        random_idxs = np.random.permutation(X.shape[0])
        centroids = X[random_idxs[:self.n_clusters]]
        return centroids

    def fit(self, X):
        X_normalized = normalize(X)
        self.centroids = self._initialize_centroids(X_normalized)

        for _ in range(self.max_iter):
            # Compute similarity between all points and centroids
            similarity = self._cosine_similarity(X_normalized, self.centroids)
            self.labels_ = np.argmax(similarity, axis=1)

            new_centroids = np.array([
                X_normalized[self.labels_ == i].mean(axis=0) 
                for i in range(self.n_clusters)
            ])
            
            # Normalize new centroids
            # new_centroids = normalize(new_centroids)

            if np.all(np.abs(self.centroids - new_centroids) < self.tol):
                break
            
            self.centroids = new_centroids


        self.centers = np.array([
            np.argmax(self._cosine_similarity(X_normalized, centroid))
            for centroid in self.centroids
        ])



    def predict(self, X):
        X_normalized = normalize(X)
        similarity = self._cosine_similarity(X_normalized, self.centroids)
        return np.argmax(similarity, axis=1)

    def fit_predict(self, X):
        self.fit(X)
        return self.labels_



    
    
num_clusters = 3
all_codes['clusters'] = None
new_rows = []

for index, row in all_codes.iterrows():    
    X = model.encode(row['json_list'])
    
    kmeans_cosine = KMeansCosine(n_clusters=num_clusters, random_state=42)
    kmeans_cosine.fit(X)
    labels = kmeans_cosine.labels_
    centers = kmeans_cosine.centers
    print(centers)
    for center in centers:
        print(center)
        print(row['json_list'][center])
    
    ret_arr = [[] for _ in range(num_clusters)]
    
    for sect, sent in zip(labels, row['json_list']):
        ret_arr[sect].append(sent)
           
    i=0
    for sect in ret_arr:
        print(i, sect)
        i+=1
    # all_codes.at[index, 'clusters'] = ret_arr

    for i, sect in enumerate(ret_arr):
        new_row = row.copy()  # Copy the original row
        new_row['clusters'] = sect  # Assign the cluster to the 'clusters' column
        new_row['cluster_id'] = i  # Add a cluster identifier
        new_rows.append(new_row)  # Append the new row to the list
        new_row['center'] = row['json_list'][centers[i]]

# Convert the list of new rows into a DataFrame
clustered_df = pd.DataFrame(new_rows)

# Reset the index for the new DataFrame
clustered_df.reset_index(drop=True, inplace=True)

# Display the new DataFrame
# clustered_df
# Out:
# [33 17 12]
# 33
# Decent Amount of Impact
# 17
# Depression Exacerbates Health Issues
# 12
# Youth Work in Community
# 0 ['Impact on Some', 'Personal Perspective', 'Limited Experience as Bishop', 'Life Decisions', 'Peer Competition', 'Decent Amount of Impact', 'Yearly Variation', 'Limited Visibility', 'Difficulty Identifying', 'Personal Observation', 'Not Personally Known', 'Sudden Departure', 'Importance of Identifying Underlying Issues', 'Drug Use Rates', 'Substance Use', 'Pandemic Effects', 'Comparison to Others', 'Church Attendance Patterns', 'Parenting Challenges']
# 1 ['High Prevalence of Depression', 'Long-Term Therapy Experience', 'Recent Increase in Mental Health Issues', 'Multiple Factors Contributing to Mental Health Issues', 'Depression Less Noticed than Anxiety', 'Perception of Community Health', 'Social Withdrawal Post-Covid', 'Compelled Social Withdrawal', 'Higher Instances of Depression, Anxiety, and Suicide', 'Depression Exacerbates Health Issues', 'Societal Pressures', 'High Expectations and Burnout', 'Multiple Pressures of Teaching', 'Low Prevalence of Depression', 'Pressure and Expectations', 'Depression Linked to Relationship Issues', 'Depression Impacting Junior High and High School', 'Anxiety at Junior High Level, Depression at High School Level', 'Assumption of Depression as Cause', 'Men Over 65 Commit Suicide More Often', "Wife's Health Care Knowledge", 'Less Aware of Men Over 65 Suicide', 'Lack of Communication', 'Suicides at School', 'Unexpected Suicides', 'Teen Suicide Problem', 'Depression in Youth', 'Depression Not Explicitly Discussed', 'Depression as a Problem', 'Observation of Depression', 'Higher Depression Rates in Younger Population', 'Varied Impact of Depression', 'Increasing Prevalence of Depression', 'Awareness of Depression', 'Awareness of Mental Health Issues', 'Exposure to Mental Health Issues through Social Networks', "Limited Knowledge about Lehi's Mental Health Issues", 'Perception of Widespread Depression and Anxiety', 'Impact of Mental Health Issues on Work Performance', 'Perceived Link between Mental Health and Physical Health', 'Vaping as First Tobacco Product', 'Mental Health Crisis', 'Depressive Symptoms', 'Social Isolation', 'Lack of Motivation', 'Parental Mental Health Struggles', 'Teenage Mental Health Challenges', 'Societal Lack of Focus on Mental Health']
# 2 ['Uncertainty due to Work Schedule', 'Limited Interaction with Residents', 'Youth Work in Community', 'Substantial Problem for Community', 'Lehi Cares Coalition Programs', 'City Council Liaison for High Youth Council', 'Student Behavior and Class Size Issues', 'Improved Behavior Management in Arizona', 'Anxiety More Common Among Youth', 'Schools Worked At', 'Limited Adult Interaction', 'Uncertain about Community Impact', 'Tragedy Circulates in Community', 'Age Range of Youth', 'Transitioning from Elementary to Junior High', 'Weekly Meetings with Youth', 'Low School Commitment']
# [20 34 86]
# 20
# Community Impact
# 34
# Limited Impact Perception
# 86
# Obesity Prevalence
# 0 ['Disproportionate Impact on Poor', "Parental Influence on Children's Health", 'Rural Lifestyle and Physical Activity', 'Rural Lifestyle Promotes Physical Activity', 'Community Fitness', 'Community Impact', 'Children and Families Affected', 'Genetic Predisposition and Family Trends', 'Active Community', 'Active Lifestyle', 'Potential Impact on Children', 'Experience at UVU in Orem', 'Personal and Professional Experience', 'Negative Impact on Self-Image and Progress', 'Positive Impact on Some', 'Community Impact', 'Hospital Experiences Impact Daily Life', 'Uncertain of Additional Impacts', 'Active Community', 'Proximity to Campus and Activity Opportunities', 'Walking as an Activity', 'Encouraging Physical Activity', 'Adult Sports Programs', 'Significant Impact on Pediatric Population', 'Impact on Self-Esteem and Social Interactions', 'No Unusual Impact', 'Consistent Impact', 'Active Lifestyle', 'Parental Role']
# 1 ['Limited Food Access and Trauma', 'Limited Growth Potential', 'Limited Outdoor Activities', 'Proximity to Canyon', 'Limited Access to Outdoor Activities', 'Access to Quality Food', 'Susceptibility to Condition', 'Recreational Facilities in Eagle Mountain', 'Encouraging Resource Utilization', 'Limited Extracurricular Activities', 'Limited Impact Perception', 'Ostracization', 'Legislation Controversy', 'Limited Community Involvement', 'Limited Mobility and Exercise', 'Limited Observations', 'Limited Perspective', 'Close to National Average', 'Privileged Neighborhood', 'Recreation Program Improvement', 'Rec Center as Improvement Opportunity', 'Parental Control', 'Limited Junk Food Offerings']
# 2 ['Late Recognition of Health Issues', 'Unhealthy Snacking Habits', 'Childhood Obesity', 'Lack of Knowledge on Local Obesity Statistics', 'Obesity Increases Health Risks', 'Obesity Not as Prevalent', 'Overweight Not a Huge Problem', 'Obesity as Symptom', 'Mental Health, Stress, Familial Issues', 'Lack of Awareness in Communities', 'Importance of Knowledge', 'High Fast Food Density', 'Targeting Addicted Individuals', 'Low Obesity Perception', 'Flu is Prevalent', 'Flu is an Issue', 'Flu is Present at UVU', 'Low Obesity Perception', 'Obesity Affects Quality of Life', 'Obesity Reduces Physical Activity', 'Obesity Prevalence in Older Adults', 'Obesity Affects Middle-Aged and Older Adults', 'Busy Lifestyles Contribute to Obesity', 'Lack of Exercise Due to Busy Lifestyles', 'UVU Population Healthy', 'Low Obesity Perception', 'Lower Obesity Rate', 'Obesity leads to Unhealthiness', 'Obesity Impacts Work Ability', 'Public Transportation Accommodates Obesity', 'Accommodating Obesity is a New Need', 'Mental Health Legislation', 'Health Issues', 'Age and Weight Factors', 'Obesity Struggle', 'Medical Problems Associated with Obesity', 'Difficult to Break Cycle', 'Perceived as a Community Problem', 'Mobility Issues', 'Unhealthy Transportation Methods', 'Decreased Walking Comfort', 'No Excessive Overweight', 'Limited Interaction with Obese Individuals', 'Lack of Awareness', 'Ignorance of Obesity', 'Obesity Prevalence', 'Parental Obesity Hinders Health Education', 'Obesity Has Widespread Consequences', 'Awareness of Obesity Issue', 'Limited Exposure to Obesity', 'Awareness of Efforts to Reduce Obesity', 'Obesity-Related Medication Use', 'Negative Health Outcomes', 'Health Issues Associated with Obesity', 'Lack of Awareness', 'Obesity Prevalence in Hospitalized Children and Families', 'Obesity Impacts Movement and Function', 'Obesity Limits Hospital Visits', 'Obesity Causes or Complicates Medical Problems', 'Obesity is a Common Issue in Professional Experience', 'Junk Food Consumption', 'Encouraging Healthy Eating', 'Balanced Diet', 'Minimal Junk Food Intake', 'Weekly Junk Food Limit']
# [43 17 33]
# 43
# Youth at Higher Risk
# 17
# Anxiety Leading to Depression
# 33
# Females More Likely to Discuss Mental Health
# 0 ['Teens Most Affected', 'Young Adults Also Affected', 'Students at Risk', 'Minority Groups at Risk', 'Teenagers and Young Adults', 'Most Impacted Age Group', 'Future Leaders', 'Age-Based Impact', 'Limited Experience', 'Elderly Population Strongly Impacted', 'Young Adults Lack Life Experience', 'Missionaries at Higher Risk', 'Two Missionaries Left During First Month', 'Teenagers and Elderly Men at Higher Risk', 'Young Adults with Unstable Environments', 'Teenagers in High School', 'Older and Younger Populations at Risk', 'Youth at Higher Risk', 'Younger Generation Affected', 'Both Young and Old Affected', 'Multiple Factors Contributing to Disparity', 'Sharp Data on 10th Graders', 'Survey Taken by 10th Graders in April 2023', 'Current Demographic of 11th Graders']
# 1 ['Loneliness and Isolation Lead to Depression', 'Lack of Support for Disabled Individuals', 'Depression Affects Everyone', 'Personal Experience with Depression', 'Increased Loneliness', 'Student Anxiety', 'Anxiety Leading to Depression', 'Prevalence of Anxiety in Children', 'Depression Among Teachers', 'Teenage Depression', 'Awareness of Depression in Middle-Aged Adults', 'Personal Acquaintances with Depression', 'Functioning Despite Depression', 'No Cultural Bias in Depression', 'Lack of Cultural Awareness', 'Relief Society Presidency', 'Isolated Individuals Not Attending Activities', 'Problem-Solution Cycle', 'Cycle of Isolation', 'Depression Limiting Attendance', 'Uncertainty about Attendance', 'Depression Affects All Ages', 'No Clear Patterns', 'No Clear Reason']
# 2 ['More Women Seek Help for Depression', 'Missionaries Returning with Mental Health Issues', 'Lack of Expertise in Mental Health', 'Females More Likely to Discuss Mental Health', 'Women Feeling Isolated', 'Higher Female Population in Wellness Rooms', 'Males Less Likely to Seek Help', 'Observation of Gender Disparity in Wellness Rooms']
# [ 28  84 120]
# 28
# Middle-Aged Adults
# 84
# Convenience Foods
# 120
# Higher Obesity Rates in Certain Populations
# 0 ['Middle Aged People More Obese', 'Elderly and Retired', 'Childhood Obesity', 'Excessive Screen Time', 'Elderly Living Alone', 'School-Aged Children', 'Excessive Screen Time', 'Parental Neglect', 'Middle-Aged Adults', 'Older Working Class', 'Married Individuals', 'Middle Aged to Older Individuals', 'Age Group', 'Multiple Jobs and Working Parents', 'Americans in mid thirties to sixties', 'Younger generation more interested in health', 'Young people at Vasa', 'Young people at AutoZone more in shape', 'Youth 12-18', 'Junior High and High School', 'Personal Experience', 'Older People Vulnerable to Obesity', 'Older Residents', 'Pacific Islander Group', 'Busy Lifestyle', 'Parent Education', 'Older Population and Distance from Campus', 'Younger People More Active', 'Sedentary Lifestyle', 'College Students', 'Children of Poor Eaters', 'Screen Time as a Replacement for Outdoor Play', 'Lunch People Lack Time', 'Time Constraints', 'Older People Lack Cooking Time', 'Asian People Spend Time Cooking', 'Gender, Race, and Age Factors', 'Age Range', 'Health Awareness with Age', 'Younger Age and Health Neglect']
# 1 ['No Biases in Obesity', 'Financial Constraints', 'Limited Access to Resources', 'Socioeconomic Disadvantage', 'Suboptimal Health Outcomes', 'Early Exposure to Technology', 'Ethnicity and Cultural Food Practices', 'Socioeconomic Status', 'Ethnicity', 'Economic Disadvantage', 'Affordable Athletics in Provo', 'Cost of Athletics', 'No gender difference', 'Lack of Knowledge', 'Gender and Ethnicity', 'Observation vs Scientific Evidence', 'Cultural Impact on Eating Habits', 'Lack of Nutritional Knowledge', 'Affordability vs. Healthiness', 'Limited Food Options', 'Target Audience', 'Observation', 'Picky Eating Habits', 'Convenience Foods', 'Support Needed', 'Unhealthy Food Preferences', 'Normalcy', 'Food Exposure', 'Financial Constraints', 'Walkability of the Area', 'Financially Disadvantaged', 'Not Gender Specific', 'Limited Access to Healthy Food and Weight Management Services', 'Limited Access to Fresh Food', 'Processed Foods More Affordable', 'Preference for Processed Foods', 'Lack of Fresh Foods', 'Socioeconomic Disparities', 'Fast Food Consumption', 'Drive-Thru Convenience', 'Lack of Cooking Time', 'Healthy Cooking Efforts', 'Weight Control']
# 2 ['At-Risk Population', 'Universal Risk for Obesity', 'Sedentary Lifestyle and Overeating as Risk Factors', 'Surgery and Limited Mobility as Risk Factors', 'Asthma and Respiratory Disease as Risk Factors', 'Medications as Risk Factors', 'Obesity Affects Everyone', 'Perceived Risk Factors', 'Higher Risk in Mid 30s - 40s', 'Diverse Community with Vulnerable Populations', 'Impact on All Community Members', 'Lack of Encouragement for Physical Activity', 'Lack of Parental Involvement in Sports', 'Middle Income Families', 'Severe Mental Health Struggles', 'Gender as Potential Risk Factor', 'Latinos and Hispanics Prioritize Taste Over Health', 'Orem Less Prevalent Than Other Areas', 'Women Less Likely to Walk at Night', 'Educational Attainment as a Factor', 'Education and Motivation as Protective Factors', 'Educational Attainment as a Factor', 'Poverty and Low Income', 'College Students at Risk for Unhealthy Habits', 'Most College Students are Low Income', 'Immigrants Face Language Barriers in Healthcare', 'Hispanic Population Affected', 'Less Intense PE in Schools', 'Limited Opportunities for Disadvantaged Families', 'Hispanics with physical jobs healthier than Americans', 'Lower Income and College Students Vulnerable to Obesity', 'People with Diabetes Vulnerable to Obesity', 'Low-Income Families', 'Senior Citizens as Most At-Risk Group', 'Children from Low-Income Homes at Risk', 'Individuals from Low-Income Families at Risk', 'Social Media Influence', 'Campus Community Protected from Obesity Due to Walking', 'Low Income', 'Lower Income Brackets Most Affected', 'Low-Income Neighborhoods with Neglected Sidewalks', 'Lack of Regular Ambulatory Exercise', 'Low-Income Individuals', 'Co-workers in Poverty', 'Vulnerable Populations', 'Racial and Ethnic Disparities', 'Low-Income Families at Risk', 'Cultural and Ethnic Factors', 'Lack of Physical Activity in Children', 'High School Hispanics Overweight', 'Higher Obesity Rates in Certain Populations', 'Polynesian Population with Higher Obesity Rates', 'Other Ethnic Groups with Higher Obesity Rates', 'Lower Socioeconomic Classes Associated with Higher Obesity Rates', 'Poor Nutrition as a Factor in Higher Obesity Rates', 'Limited Resources as a Barrier to Managing Obesity']
# [ 7 57 44]
# 7
# Overwhelming Feelings
# 57
# Lack of Family Mealtime
# 44
# Social Influences
# 0 ['Emotional Isolation', 'Highland Area Specific', 'Lone Peak Kids', 'Perfectionism and Ideals', 'Misalignment with Beliefs', 'Overwhelming Feelings', 'Lack of Professional Help', 'Economic Disparity', 'LDS Challenges', 'Personal Resilience', 'Arrogance and Competition', 'Comparing Yourself', 'Awareness of Negative Home Environment', 'Uncertain Recovery', 'Perfectionism', 'Financial Status', 'Wealth and Depression', 'Financial Strain']
# 1 ['Homesickness for Out-of-State College Students', 'COVID-19 Pandemic as a Major Factor', 'Supply Chain Disruption', 'Increased Costs and Delays', 'Family Issues Impact Youth Anxiety', 'Stress as a Major Cause', 'Genetics as a Major Factor', 'Family History of Depression', 'Lack of Family Quality Time', 'Students Not Eating with Family', 'Lack of Family Mealtime', 'Importance of Family Mealtime', 'Family Week Initiative', 'Cookbooks, Meal Planners, and Aprons Provided', 'Encouraging Family Mealtime for Bonding', 'Lack of Family Connectiveness as a Risk Factor']
# 2 ['Social Media Influence', 'Parental and Community Pressures', 'Risk Factors for Depression in Schools', 'Weather and Health Factors', 'Limited Socialization', 'Diverse Community', 'Judgmental Environment', 'School Split', 'Impact of Age', 'Social Stress and Inadequacy', 'Risk Factors for Depression', 'Struggling in School', 'Social and Academic Struggles', 'Importance of School at This Age', 'Social and Fitting In', 'Lack of Social Support', 'Environment as Risk Factor', 'Social Circles as Risk Factor', 'Social Circle Presence as Risk Factor', 'Drug and Alcohol Environments as Risk Factor', 'COVID Impact', 'Social Media Usage', 'Teenage Social Life', 'Social Life Disruption', 'Social Influences', 'Online Influences', 'Religious Culture', 'Social Media', 'Multiple Risk Factors', 'Conversation Cards Provided', 'Social Isolation as a Risk Factor', 'Increased Risk for Social Isolation']
# [ 18  11 104]
# 18
# Education Importance
# 11
# Lack of Physical Activity
# 104
# Unhealthy Dietary Habits
# 0 ['Economic Factors', 'Education Importance', 'Grocery Purchases and Health Education', 'Walking on Campus', 'Sitting on Bus or Car', 'Academic Priorities', 'Lack of Education', 'College Students', 'Education as a Lacking Resource', 'Rec Center Requires Fee', 'Cultural Factors']
# 1 ['Childhood Trauma', 'Limited Exercise Time', 'Lack of Physical Activity', 'Personal Motivation', 'Socioeconomic Status', 'Commuting as Risk Factor', 'Stress and Busy Schedules', 'Limited Outdoor Activities for Adults', 'Sedentary Events', 'Lack of Physical Activity', 'Assumption', "Orem's Business Environment", 'Common Behavior', 'Predicted Behavior', 'Mobility Issues and Weight Gain', 'Economics and Access to Exercise', 'Uncertainty about Relationship', 'Interplay of Factors', 'Uncertainty about Access', "Society's Preference for Convenience", 'Convenience as a Contributing Factor', 'Negative Self Image and Unhealthy Behaviors', 'Caloric Intake and Physical Activity', 'Financial Barriers to Exercise', 'Social Isolation', 'Community Connection', 'Physical Inactivity', 'Social Isolation and Physical Activity', 'Community Connection', 'Insufficient Exercise', 'Chronic Stress', 'Access to Parks and Trails', 'Weather Impact on Activity', 'Lack of Walkability', 'Car Dependency', 'Portion Control Issues', 'Low Income Individuals Face Barriers to Exercise', 'Multiple Contributing Factors', 'Unhealthy Behaviors', 'Social and Environmental Influences', 'Sedentary Behaviors', 'Environmental Factors', 'Parking Availability', 'Financial Barriers to Athletic Programs', 'Lack of Physical Activity', 'Time Constraints Limiting Physical Activity', 'Lack of Physical Activity']
# 2 ['Unhealthy Food Addiction', 'Fast Food Dominance', 'Limited Lunch Options', 'Fast Food Prevalence', 'Unhealthy Food Choices', 'Fast Food Availability', 'Long Commute Times', 'Sedentary Lifestyle', 'Poor Lighting and Location', 'Long Commute Time', 'WIC vs Food Stamps and Obesity', 'Unhealthy Food Choices Due to Cost', 'Free Food at Concerts', 'Sedentary Lifestyle', 'Mental Health Issues', 'Fast Food Availability and Lack of Walking', 'Lack of Streetlights', 'Sedentary Lifestyle', 'Personal Lifestyle Change', "UVU's Nutritional Options and Gym", 'Snowy Weather', 'Limited Access to Healthy Food', 'Sedentary Lifestyle', 'Eating Out', 'Cheap Fast Food', 'Unhealthy Lifestyle', 'Sedentary Lifestyle', 'Family Lifestyles', "Parental Influence on Child's Health", 'Genetic and Dietary Factors', 'Cultural Diets as a Factor', 'Overuse of Fast Food', 'Preference for Restaurant Meals over Home Cooking', 'Obesity Not Inherent', 'Lack of Nutritional Knowledge', 'Health Issues as Risk Factor', 'Health Issues as Additional Risk', 'Lack of Resources as Risk', 'Poor Diet and Lack of Exercise', 'Low-Income Families at Risk', 'Unhealthy Eating Habits', 'Balanced Nutrition', 'Sedentary Lifestyle', 'Sleep Deprivation', 'High Cost of Fresh Food', 'Unhealthy Food', 'Fast Food Accessibility', 'Drug Issues Impacting Food Choices', 'Prioritizing Drugs over Healthier Foods', 'Food Quality', 'Lack of Time for Cooking', 'Sugar Intake', 'Income Affects Access to Healthy Foods', 'Limited Access to Healthy Options', 'Unhealthy Dietary Habits', 'Grocery Store Accessibility', 'Job Type Impact on Eating Habits', 'Food Chain Availability', 'Early Onset of Sedentary Lifestyle', 'Societal Norms Encouraging Sedentary Lifestyle', 'Excessive Soda Consumption', 'Junk Food Availability', 'Limited Healthy Food Options', 'Healthy Restaurant Closure', 'Positive Perception of Healthy Restaurant']
# [27 35 21]
# 27
# Negative Social Influence
# 35
# Affluence as a Factor
# 21
# Mental Health Disorders
# 0 ['Change in Environment', 'Socialization with New People', 'Lack of Community', 'Decreased Social Support', 'Unstable Home Environment', 'Environmental Factors', 'Socioeconomic Stressors', 'Positive Social Influence', 'Negative Social Influence', 'Tech Industry and Income Inequality', 'Social Environment Influences Depression', 'Cultural Norms', 'Digital Connectivity', 'Comparison and Bullying', 'Insufficient Sleep', 'Fatigue During School Hours', 'Low Commitment to School', 'Financial Responsibilities Impacting Sleep', 'Perfectionism and Social Media Comparison']
# 1 ['Isolation as a Major Factor', 'Uncertainty about Root Cause', 'Parental Conflict', 'Internal Struggles', 'Internalized Experiences', 'Fear of Bullying', 'Mindset Matters', 'Accurate Perception', 'Assessing Situations', 'Hereditary Factors', 'Early Phone Access', 'Unlimited Internet Access', 'Affluence as a Factor', 'Contributing Factors', 'Amplification of Issues', 'Majority of 10th Graders Sleep Deprived', 'Excessive Screen Time']
# 2 ['Sense of Belonging as Protective Factor', 'Loss of Belonging Linked to Depression and Loneliness', 'Vicious Cycle of Isolation and Negative Emotions', 'Religious Leaders Preferred Over Professionals', 'Depressive Mindset', 'Cognitive Behavioral Therapy', 'Mental Health Disorders', 'Exacerbation of Mental Health Issues', 'Positive Impact on Mental Health', 'LDS Culture and Perfectionism', "Younger LDS Members' Feelings of Inadequacy", 'Positive Social Support Improves Mental Health']
# [125  48  29]
# 125
# Complacency in Habits
# 48
# Parental Influence on Habits
# 29
# Lack of Education on Healthy Eating
# 0 ['Fast Food Convenience', 'Accessibility of Fast Food', 'Personal Inactivity', 'TV and Inactivity', 'TV Habit', 'TV Watching Despite Exhaustion', 'TV Watching as a Habit', 'Fast Food Prevalence', 'Lifestyle and Environment', 'Walking Culture', 'Car Culture and Sedentary Lifestyle', 'Public Transportation Improvements', 'Fast Food Availability', 'Distance as a Barrier', 'Class Requirement', 'Car Centric Environment', 'Resistance to Change', 'Culture as a Factor', 'Independence', 'Older People', 'Cookie Cutter Approach', 'Conversations about Body Image', 'Opportunities for Facilities', 'Mountainview Track Usage', 'Common Observation', 'Demand and Culture', 'Community Involvement', 'Bike Route Knowledge', 'Perceptions of Safety', 'Social Isolation', 'Generalized Sports and Phone Usage', "Country's State", 'Complacency in Habits', 'Reliance on Cars/Buses for Transportation', 'Personal Responsibility', 'Ease of Access', 'Cultural Norms', 'Supporting Local Businesses', 'Societal Expectations', 'Nutrition', 'Convenience of Fast Food', 'Affordability', 'Time Saving', 'Personal Preference', 'Convenience on the Go', 'Immediate Gratification']
# 1 ['Genetic Influence', 'Parental Lifestyle Impact', 'Convenience Over Health', 'Limited Food Options', 'Health Impact Assessment', 'Convenience and Obesity Risk', 'Online Society and Indoor Lifestyle', 'Less Physical Activity', 'Diet and Exercise', 'Limited Resources for Health', 'Family Stress', 'Cost vs Health', 'Limited Exposure to Class Content', 'Limited Exposure Outside of Nutrition Field', 'Influence of Social Environment on Habits', 'Parental Influence on Habits', 'Limited Access to Healthy Food', 'Attitudes as a Risk Factor', 'Disabilities as a Barrier', 'Injury Impact on Exercise', 'Average Work Hours of 30-40 per Week', 'Balancing Work, School, Social Life, and Relationships', 'Limited Time for Other Activities', 'Poverty as Root Cause', 'Financial Strain Hinders Medical Treatment', 'Limited Access to Health Services', 'Cost as Barrier to Health', 'Home Economics as a Dummy Class', 'Weight Gain in Mid 30s and Regret', 'Information Availability vs Utilization', 'Socioeconomic Factors and Unsupervised Children', 'Junk Food Availability and Inactive Habits', 'Parental Influence', 'Differences in Families', 'Genetics and Obesity', 'Money as a Barrier', 'Family Priorities Over Exercise', 'Classes Available but Family Comes First', 'Motivation as a Factor', 'Time Constraints in Low-Income Households', 'Lack of Parental Involvement Due to Time Constraints', 'Limited Access to Healthy Food Options', 'Transportation Budget Funding', 'Zoning Restrictions', 'Neighborhood and Social Connections', 'Involvement and Financial Considerations', 'Inflation Impact on Goods and Services', 'Economic System', 'Time Constraints', 'Cost Disparity', 'Limited Employment Opportunities', 'Socioeconomic Barriers', 'Social Norms and Marketing', 'Parental Knowledge and Attitudes', 'Socioeconomic Factors', 'Cultural Beliefs and Family Dynamics', 'Economic Factors']
# 2 ['Lack of Nutritional Knowledge', 'Lack of Healthy Options', 'Food Desert Formation', 'Lack of Knowledge and Time', 'Schools as Accessible Resource', 'Ignored Health Information', 'Lack of Education on Healthy Eating', 'Lack of Access to Resources', 'Lack of Resources in Eagle Mountain', 'Breaking the Cycle of Obesity', 'Inclusion of Events in Schools and Communities', 'Food Stamps Make Healthy Choices Difficult', 'Education Level', 'Lack of Participation in Classes', 'Lack of Nearby Grocery Stores', 'Taking Fit for Life Class', 'Limited Time Spent on Health Education', 'Need for Better Promotion of Health Education', 'Lack of Heated Sidewalks', 'Lack of Discussion on Obesity', 'Education and Finance as Root Causes', 'Cheap Fast Food Due to Busyness', 'Students Working Long Hours', 'Fatigue and Lack of Sleep Among Students', 'Prioritizing Work and School Over Sleep and Food', 'Overweight Students Cutting Out Sleep and Exercise', 'Observations of Student Health Habits', 'Lack of Financial Ability for Healthy Lifestyle', 'Demographics, Religion, Poverty, Multiple Jobs, Lack of Time for Childcare and Education', 'Lack of Home Economics Education', 'Need for Useful Home Economics Education', 'Busy Culture and Lack of Cooking Skills', 'Attitude and Lack of Awareness', 'School Curriculum on Healthy Lifestyles', 'Lack of Adult Guidance at Home', 'College Student Access', 'College Eating Habits', 'Roommate Type College Experience', 'Teaching Cooking and Exercise', 'New Rec Center with Increased Membership', 'Rec Centers Attract New Exercisers', 'Benches Added to Community Park', 'Walking Trails Need Rest Spots', 'Rest Spots Encourage Exercise', 'Rest Spots Reduce Fatigue Concerns', 'Lack of Effort', 'Cold Weather Discourages Walking', 'Unhealthy Food Choices at Walmart', 'High Sugar Diet Due to Cultural Influence', 'Lack of Education and Training', 'Insufficient Education for Job Advancement', 'Commute for Jobs', 'Lack of Corporate Jobs', 'Lack of Knowledge on Healthy Choices and Budgeting', 'Low Health Literacy', 'Lack of Time for Cooking', 'Health Education in Junior High', 'Insufficient Emphasis on Content', "McDonald's is Affordable"]
# [66 63 29]
# 66
# Family Therapy Clinic
# 63
# Student Desire for Community Involvement
# 29
# Lack of Awareness about Resources
# 0 ['Efforts to Develop Crisis Programs and Make Therapy Accessible', 'Hospital with Emergency Room', 'Emergency Care Availability', 'Potential Therapist Availability', 'PHQ-9 Screening in Family Medicine Clinic', 'Specialized Mental Health Services', 'Stable Families', 'Medical Professionals as Key Players', 'Training for Mental Health Awareness', 'Personal Connection to Mental Health Initiatives', 'Mental Health Forums', 'Alternative Therapies', 'Accessible for All', 'Highly Accessible', 'Affordable Cost', 'Virtual Appointments Available', 'Increased Counseling Services', 'More Counseling Centers', 'Facility Improvement Needed', 'Emergency Room Usage', 'Statewide Mental Health Hotline', 'Family Therapy Clinic', 'Other Therapy Clinics', 'Utah Family Therapy', 'Other Therapy Clinic', 'Several Therapy Clinics', 'Private Practice Therapists', 'Intensive Outpatient Groups', 'Intensive Outpatient for Teenagers', 'Individual and Family Therapy']
# 1 ['Schools Implementing Hope Squads', 'Religious System for Affordable Professional Help', 'Community Gathering Spaces', 'Positive Work Environment', 'Engaging in Enjoyable Activities', 'Safe Community', 'Married Parents as Support System', 'Schools Promoting Inclusion', 'Diverse Range of Support Personnel', 'School Programs for Mental Health', '4H Program as a Community Strength', 'Promoting 4H Program as a Positive Influence', '4H Program is a Significant Community Resource', 'Community Activities and Events', 'Schools as a Resource for Children', 'School Assemblies', 'Strong Community', 'Religious Community', 'Religion as a Support System', 'Wellness Room Access for Students', 'At-Risk Student Population', 'Support for At-Risk Students', 'Teaching Self-Regulation Skills', 'Encouraging Family Involvement', 'Student Desire for Pro-Social Involvement', 'Student Desire for Community Involvement', 'Student Desire for Rewards for Pro-Social Involvement', 'Providing Opportunities for Student Participation', 'Program for Teenagers', 'Group Work']
# 2 ["Utah's High Suicide Rate", 'Uncertainty About Effectiveness of Efforts', 'Uncertain about Resources', 'Lack of Resource Awareness', 'Perceived Lack of Depression Resource Advertising', 'Sunshine as a Mood Booster', 'Increasing Awareness and Support', 'Uncertainty about Resources', 'Lack of Awareness about Resources', 'Sliding Scale Pricing', 'Less Invasive than Massage', 'Addressing Depression', 'Increasing Knowledge and Awareness', 'Helps Combat Depression', 'Caring People Make a Difference', 'Wellness Rooms as Top Priority', 'Wellness Rooms as Protective Factor', 'Depression and Suicidal Ideation']
# [ 40 126  10]
# 40
# Abundance of Recreational Facilities
# 126
# Abundance of Parks
# 10
# Schools Promote Healthy Eating
# 0 ['Strong Social Support', 'Active Lifestyle', 'Biking and Hiking Activities', 'Seasonal Activities', 'Dangerous Conditions', 'Accessible Outdoor Recreation', 'Easy Access to Recreation', 'Strong Community', 'Community Support', 'Community Leaders Influence', 'Community Participation', 'More Activities Needed', 'Fairs and Events', 'More Activities and Attractions', 'Recreational Facilities', 'Outdoor Recreation Opportunities', 'Free Outdoor Recreation', 'Sustainability Focus', 'Abundance of Recreational Facilities', 'Accessible School Tracks', 'Transient Community Members', 'Small Gym with High Utilization', 'Vineyard has good outdoor communities', 'Vineyard has a good outdoor community', 'Active age group in Vineyard', 'Community Garden', 'Gyms Available', 'Opportunities for Change', 'Great Outdoors Encourages Activities', 'Awareness and Access', "Provo's Unique Young Culture", 'Active Lifestyle Opportunities', 'Engaging Middle Aged People in Active Lifestyle', 'Lack of Active Opportunities for Elderly', 'Limited Opportunities for Immigrants', 'Tight Knit Communities', 'Population Differences', 'Sister Communities', 'Recreation Center Access', 'Aquatic Center Availability', 'USU Extension and Community Outreach', 'Invitation-Based Attendance', 'Exercise Facilities', 'Community Offers Many Opportunities for Physical Activity', 'Trails and Parks Provide Opportunities for Physical Activity', "Community's Trail System and Walking Paths are Unique", 'Lack of Knowledge', 'Underutilization of Resources', 'Barriers to Access', 'Community Strengths', 'Diverse Recreation Programs', 'Accessibility', 'Gym Availability', 'Church Activities for Children', 'Encouraging Sports Participation', 'Inclusive Recreational Programs', 'Community Engagement through Health and Exercise', 'Community Strengths', 'Strong Sense of Community', 'Dedicated Individuals and Organizations', 'Community Sports and Parks', 'Desire for Better Recreation Centers and Gyms', 'Recreational Activities Valued', 'Provo Shares Recreational Values', 'Low Cost Recreational Opportunities', 'Low Substance Abuse Rates', 'Low Substance Abuse as Strength', 'Limited Knowledge of Social Services', 'More Community Events', 'Marathon Participation', 'More Healthy Events']
# 1 ['Hiking Trails in Payson Canyon', 'Frequent Hiking Location', 'Walking Paths and Bike Trails', 'Parks', 'Gyms', 'Bike Rides', 'Focus on Outdoor Spaces', 'New Park Opening', 'Inclusive Park Design', 'Skate Park Addition', 'Parks and Recreation Background', 'Failed Attempt at Rec Center', 'Pickleball Court Added for Older Adults', 'Lots of parks in Vineyard', 'Big sidewalks and walking areas in Vineyard', 'Bike Walk Provo', 'Hiking Trails', 'Bike Lanes', 'Pleasant Grove is Lucky', 'Murdock Trail is Great for Public Use', 'UVX and Walking to Bus Stops', 'Bike Lanes', 'Court-Ordered Attendance', 'Sidewalks', 'Lack of Sidewalks in New Builds', 'Parks', 'Kiwanis Park Usage', 'Senior Hour Discount', 'High-Quality Rec Center and Parks', 'Decent REC Center', 'Abundance of Parks', 'Pickleball Courts in Springville', 'Pickleball Popularity', 'New Rec Center Excitement', 'Parks Usage Limited in Winter', 'Rec Center Visits', 'VASA Locations', 'Trails for Running', 'Preparation for Marathon', 'Weight Control']
# 2 ['Financial Stability', 'Sports Programs for Children', 'Schools Promote Healthy Eating', 'Limited Effectiveness of School Programs', 'Food Assistance Programs', 'Food Pantry', 'Food Assistance Program', 'School Meal Programs', 'Focus on Health and Recreation', 'Strategic Planning', 'Health and Safety Priority', 'Church Offers Financial Education but Low Participation', 'Hospital Provides Many Resources', 'Young families and young adults dominate the age group in Vineyard', 'UVU Food Pantry', 'Free Health Services for Obesity', 'Managing Symptoms vs Prevention', 'Outreach Programs for Spanish Speakers', 'Unhealthy Eating Options', 'Good Support for Individuals and Families', 'Lindon Cares and PG Cares Programs', 'Proactive Approach to Youth Programs', 'Wellness Clinics and Dietitian Access', 'PTA Involvement in Parenting Classes', 'Food Preparation and Sharing', 'Food Insecurity and Variety', 'Education on Healthy Meals', 'Importance of Education', 'Unhealthy Meals and Obesity', 'Preventing Obesity', 'Cooking for Large Groups', 'Lack of Knowledge and Intergenerational Problems', 'Program Name and Status', 'Zumba Classes', 'Morning and Evening Zumba Classes', 'Evening Classes for Working Parents', 'Zumba and Afro Fitness Classes', 'Summer Dance Class for Kids', 'Basketball, Soccer, and Tai Chi Classes', 'Schools as Potential Resource', 'School Resources', 'Nutritious Meals', 'Mobile Food Bank', 'Free Food During COVID', 'Schools Educate on Healthy Eating Portions', 'Existing Healthcare Infrastructure', 'Resources for Healthy Lifestyles', 'Supportive Community and Pediatric Healthcare Services', 'School-Based Wellness Programs and Community Organizations Promoting Healthy Lifestyles for Children', 'Health Awareness']
# [55 61 28]
# 55
# Family Therapy Clinic
# 61
# Intensive Outpatient for Teenagers
# 28
# Addressing Depression in Community
# 0 ['Medical Doctors Addressing Issue', 'Therapists and Counselors Available', 'Talking Helps Reduce Stigma', 'Importance of Talking with Friends, Family, and Local Government', 'Mental Health Professionals', 'Limited Knowledge of Resources', 'NAMI National and Local Resources', 'Personal Connections to Mental Health Professionals', 'Family Support and Education', 'PG Cares and Family Classes', 'School Support', 'Counseling and Group Support', 'Improving Medical Clinic Support', 'No Additional Resources', 'Students Feel Better by Helping Others', 'Creating Opportunities for Students to Help Others', 'Students Appreciate Helping Others', 'Family Therapy Clinic', 'Other Therapy Clinics', 'Utah Family Therapy', 'Several Resources in Area', 'Private Practice Therapists', 'Individual and Family Therapy']
# 1 ['Efforts to Develop Crisis Programs and Make Therapy Accessible', 'Uncertainty About Effectiveness of Efforts', 'Lack of Awareness', 'Limited Experience with Telehealth', 'No Specific Ideas', 'Opportunities for Outsiders', 'Emotional Resilience Class for Teens', 'Lack of Fortitude and Ability to Deal with Life Challenges', 'Concerns about Program Effectiveness', 'Service Organization Visits', 'Making Sleeping Mats for Homeless', 'Tying Blankets for Refugees', 'Writing Positive Notes to Veterans', 'Knitting Hats for Refugees and Homeless', 'Intensive Outpatient for Teenagers', 'Program for Teenagers']
# 2 ['Schools Implementing Hope Squads', "Utah's High Suicide Rate", 'School District Addressing Issue', 'Rapid Growth and Polarization', 'Diverse Community Needs', 'Meeting Community Needs', 'Cooperation between Schools and City', 'Community Involvement', 'Long Wait for Services', 'Strong Families Class', 'Lack of Participation', 'Addressing Depression in Community', 'Suicide Education', "Parental Intervention Hinders Child's Growth", 'Consequences for Poor Decisions', 'Parental Intervention to Alleviate Consequences', "Parental Intervention in All Aspects of Child's Life", 'Parental Intervention Removes Opportunity for Growth', 'Parental Intervention Not Beneficial', 'Parental Intervention Leads to Depression and Anxiety', 'Organizations Addressing Depression', 'Increasing Interventions', 'Social Groups Address Depression', 'Social Groups Reduce Social Isolation', 'Intensive Outpatient Groups', 'Depression and Suicidal Ideation', 'Group Work']
# [ 9  0 37]
# 9
# Youth Sports Programs
# 0
# Community Resources for Obesity
# 37
# Congestion and Proximity Encourage Walking
# 0 ['New High School with Potential After Hours Gym', 'Park in Downtown and Middle Payson', 'Walking Paths', 'Bike Trails', 'Youth Sports Programs', 'Dance Studio Exercise Classes', 'Trails and Parks for Physical Activity', 'Free Summer Triathlon', 'Parks and Greenspaces', 'Outdoor Recreation Areas', 'Small Gym', 'Pickleball Court', 'Outdoor Programs and Companies', 'Public Transportation Perk', 'High Pedestrian Traffic', 'Rec Centers, Programs, and Lindon Cares', 'Senior Center Offers Exercise Classes', 'Physical Education Program', 'Recreation Department', 'Sports Offerings', 'Outdoor Program', 'Parks', 'New Bike Park', 'Diverse Sports Options in Junior High', 'Pediatrician Guidance', 'Small Farming Town']
# 1 ['Community Resources for Obesity', 'No Community Rec Center', 'Total Fitness Costs to Use', 'Community Resources for Obesity Prevention', 'Weekly Dinner Groups for Healthy Cooking', 'Church Resources', 'Hospital Resources', 'No Specific Resources', 'No Additional Resources', 'Nutrition Meal Prep Classes', 'Healthy Food Options at Stores', 'Similar Resource Usage', 'Resource Availability', 'Uncertainty about Resources', "Provo's Good Public Transit System", 'Resources are Available', 'No Additional Resources Needed', 'Unaware of Specific Resources', 'Health Department Offers Classes', 'Senior Center Offers Educational Resources', 'No Specific Resources', 'Reformed High School PE Not Mandatory', 'Need for Improved PE Programs to Promote Health', 'Community Health Education Programs', 'School Nutrition Programs', 'Community Recreation Opportunities', 'No Knowledge of Local Resources', 'Young Population Due to BYU']
# 2 ['Uncertainty', 'Holiday 5K Events', 'Opportunity for Targeted Events', 'Strategic Plan', 'Lack of Knowledge', 'Lack of Knowledge', 'Walking as a Positive Factor', 'Walking has Pros and Cons', 'Congestion and Proximity Encourage Walking', 'Weather Influences Walking Habits', 'Walking may not be sufficient exercise', 'Misconception about walking as exercise', 'Walking may not raise heart rate enough', 'Walking can be beneficial if done correctly', 'Existing Trails and Encouragement', 'Proximity and Availability', 'Lack of Awareness', 'Classes on Prevention and Awareness', 'Unclear Statement', 'Community Offers Recreation Activities and Events Emphasizing Exercise and Physical Activity', 'No Awareness of Local Efforts', 'Sidewalk Quality Concerns', 'Lack of Engagement and Motivation in High School PE', 'Existing Initiatives', 'School-Based Interventions', 'Partnerships', 'Promoting Healthy Behaviors', 'Limited Public Awareness', 'Lack of Athletic Facilities', 'Active Lifestyle Among Young People', 'Influence of Active Lifestyle on Others', 'Desire to Join Active Lifestyle']
# [30  1 48]
# 30
# City-Sponsored Mental Health Programs
# 1
# Difficulty Finding Therapists
# 48
# Family Training Needed
# 0 ['Mental Health Awareness', 'No Specific Ideas', 'Difficulty Accessing Mental Health Services', 'Shortage of Mental Health Professionals', 'High Demand for Mental Health Services', 'Awareness of YMCA Programs', 'Suggestion for Free Community Gatherings', 'City-Sponsored Programs', 'City-Sponsored Mental Health Programs', 'Community Support Groups', 'Non-SSRI Medications for Depression', 'Long-term Resident', 'Promote Mental Health', 'Safe UT App', 'Safe UT Data', 'Westlake Population', 'Cedar Valley Population', 'City Resource', 'Food Pantry', 'Fantastic Organization', 'Community Involvement']
# 1 ['Shift in Attitudes Towards Therapy', 'Difficulty Finding Therapists', 'Long Wait Lists and Bad Experiences', 'Insurance Coverage for Therapy', 'Limited Insurance Acceptance and High Costs', 'Affordability', 'Question Acknowledgement', 'Talking Helps Reduce Stigma', 'Lack of Awareness in Older Population', 'Limited Treatment Availability for Lower-Income Individuals', 'Difficulty Finding Medicaid Providers', 'Personal Struggle in Finding Treatment for Clients', 'Lack of Support and Resources for Clients', 'Concern about Exclusivity and Cost', 'Importance of Inclusivity and Affordability', "Lehi's Brochure", 'Efforts to Reach Everyone', 'Challenges in Reaching Everyone', 'Lack of Knowledge', 'Data Collection and Policy Development', 'Importance of Data Collection', 'Lack of Knowledge', 'Suicide Prevention Hotline', 'Therapy and Support Options', 'Insurance Coverage for Therapy', 'Alternative Treatments for Severe Cases', 'Openness to New Treatments', 'Awareness as Key Improvement', 'Perceived Improvement', 'Difficulty Finding Resources', 'Difficulty Finding Doctors', 'Difficulty in Determining Fit', 'Personality Compatibility', 'Uncertainty with Counselors', 'Challenging Fit Problem', 'Awareness', 'Bury Our Heads in the Sand', 'It Does Happen in American Fork', "Don't Know How to Help"]
# 2 ['Teacher Training', 'Talking with Friends, Family, and Local Government', 'Need for Resources for Lower-Income Individuals', 'Need for Availability, Education, and Accessibility', 'Need for Improved Mental Health Communication in Schools', "Schools' Suicide Prevention Efforts", 'Education as Key', 'Continued Education for Students and Families', 'Reaching Disinterested Families', 'Desire to Reach Disinterested Families', 'Desire for Greater Audience', 'Agreement on Greater Audience', 'Improved Communication', 'More Communication and Resources', 'Family Training Needed', 'Room for Further Improvement', 'American Fork Junior High Population', 'Great Kids', 'Better Resources', "Community Doesn't Want to Be Involved"]
# [101 104  50]
# 101
# Improve Walkability
# 104
# Provide Education on Healthy Eating
# 50
# Community Activities
# 0 ['Awareness Campaigns', 'Positive Outlook', 'More Solutions Needed', 'Desire for Rec Center', 'Open Discussion', 'Non-Shaming Approach', 'Start with Leaders', 'Strategic Plan Implementation', 'Accountability and Goal Achievement', 'Knowledge Availability and Behavior Change', 'Increase Green Spaces', 'Utilize Existing Facilities', 'Room for Improvement', 'Increased Discussion Needed', 'Discussion as a Precursor to Policy', 'Awareness is Key', 'Magazine Received', 'Advertising Concerns', 'Waste Concerns', 'Personal Experience with Magazine', 'Limited Visibility Concerns', 'Opportunity Availability', 'Desire for Improvement', 'Belief in Possibility', 'Lack of Specific Knowledge', "Confidence in Others' Abilities", 'Uncertainty about Specific Solutions', 'Ask Questions', "Don't Assume", 'Continuous Improvement', 'Limited Options', 'Inclusive Approach', 'Sidewalk Improvements', 'Improve Walkability', 'Need for Additional Efforts', 'Policy Implementation', 'Lack of Specific Solutions', 'Walkability as a Solution', 'City Design as a Barrier', 'Attention to Infrastructure', 'More Comprehensive Check at 40', 'Paying Attention to Results for Three Months', 'Positive Response to Suggestion']
# 1 ['Obesity Classes', 'Nutrition Education in Schools', 'Early Education for Lifelong Impact', 'Nutrition Education', 'Improving Member Health and Well-being', 'Education at All Levels', 'Promote Health and Nutrition through Newsletters', 'Doctors Provide Resources for Community Education on Obesity', 'Offer Classes or Dietitians', 'Refer Patients to Community Classes for Obesity Management', 'Virtual Classes or Videos as Alternative Options', 'Promoting Healthy Habits', 'Fast Food vs. Healthy Options', 'Quick and Easy Healthy Options', 'Lack of Access to Healthy Food Options', 'Limited Availability of Healthy Food Options', 'Funding for Education', 'Promoting Healthy Lifestyles', 'Targeted Education for At-Risk Groups', 'Identify and Educate At-Risk Groups', 'Affordable Healthy Food Access', 'Education is Key', 'Lack of Understanding Leads to Unhealthy Choices', 'Teaching Adults is Important but Not Enough', 'WIC Money Spent on Healthy Foods but Cash on Unhealthy Choices', 'Government Assistance is Not Enough to Overcome Other Factors', "Don't Blame Obesity", 'Obesity and Healthy Food Preparation', 'Daycare Healthy Eating Programs', 'Schools as Resource for Health Education', 'More Physical Education in Schools', 'Nutrition Programs', 'Reduce Preservatives in Foods', 'Replace Junk Food with Healthy Options', 'Increase Fruit and Vegetable Intake at Parties', 'Provide Education on Healthy Eating', 'Obesity as a Generational Issue', 'School System Reforms for Healthier Kids', 'Breaking the Obesity Cycle', 'BMI Limitations in Assessing Obesity', 'Lack of Education on Healthy Weight', 'Complexity of Defining Obesity', 'Education and Awareness', 'Addressing Childhood Obesity', 'Affordable Nutritious Foods', 'Parent Education and Support', 'Improving Lifestyle and Dieting Style', 'Access to Food and Time for Cooking', 'Obesity as a Complex Issue', 'Support for Trails and Sidewalks', 'Nutrition Programs and Education', 'Suggestion to Lower Age for Comprehensive Check', 'Difficulty Maintaining Healthy Habits']
# 2 ['Financial Support', 'Accessible Sports Facilities', 'Diverse Sports Options', 'Inclusive Participation', 'Affordable Recreation', 'Senior Transportation Services', 'Regular Senior Socialization', 'Community Involvement', 'Unified Community Effort', 'Engaging Activities', 'Wrestling Fees Waived', '4H After School Activities', 'School Sports Fees', 'Cooking Classes', 'Food Sharing', 'Exercise Groups', 'Free Activities', 'Youth Sports', 'Enhance Community Safety', 'Community Involvement', 'Community Activities', 'Community Events', 'Cooking Classes Mentioned', 'Appreciation for Collective Effort', 'Community Health Classes', 'Education', 'Social Engagement', 'Kids Camp Activities', 'Community Gardens', 'Gardening Opportunities', 'Composting', 'Sidewalks and Parks', 'Walkable Programs', 'Fitness Goals', 'Physical Activity Groups', 'Physical Activity Spaces', 'Collaborative Efforts', 'Physical Activity Promotion', 'Collaborative Efforts', 'Community Involvement', 'Youth Sports Programs']
# [33 14 22]
# 33
# Addressing Mental Health Issues
# 14
# Positive Community Perception
# 22
# Spanish Fork is a Happy City
# 0 ['Awareness Normalizes Feelings', 'Shared Experiences of Mental Health Issues', 'Unhealthy', 'Adolescents Affected', 'Teenagers in Family Medicine Clinic', 'Witnessed Growth', 'Concerned about Rapid Growth', 'Retired, Concerned about Fast-paced Life and Big Changes', 'Prevalence of Topic', 'Silence Around Topic', 'Need for Awareness and Support', 'Importance of Mental Health Awareness', 'Improvement Needed in Education', 'Updating Teacher Training', 'Addressing Mental Health Issues']
# 1 ['Positive Feedback on Discussion', 'Information Sharing is Helpful', 'Long-time Resident', 'Positive Community Perception', 'Personal Affinity for Community', 'Long-term Resident', 'Community Growth', 'Positive Community Atmosphere', 'Positive Community Members', 'Community Events', 'Inclusive Community', 'Neighborhood Identity', 'Positive Perception of Lehi', "Positive Perception of Lehi's Performance", 'Investment in Recreation Programs', 'Affordable Access to Recreational Facilities', 'Price Increase for Non-Residents', 'Promoting Active Lifestyles']
# 2 ['Fewer Crumble Cookie Shops', 'Unexpected from Hawaiian', 'Traffic is Awful', 'Spanish Fork Population Generally Happy', 'Spanish Fork Happiness Not Worse Than National or Utah Average', 'Spanish Fork is a Happy City']
# [59 65 78]
# 59
# No Further Thoughts
# 65
# Community Involvement
# 78
# Outdoor Gyms Encourage Exercise
# 0 ['Staying Home Reduces Spread', 'Prompt Problem Resolution', 'Diverse Specialties and Subspecialties', 'Encourage Open Discussion', 'Reduce Stigma', 'No Further Comments', 'Uncertainty', 'Air Pollution Concern', 'Desire for Access to Amenities', 'Limited Resources', 'Chaos Hinders Focus', 'Limited Awareness', 'Language Barriers', 'Information Access', 'Missed Opportunities', 'No Additional Thoughts', 'Straightforward Process', 'Existing Programs', 'Existing Programs', 'Programs Not Enough', 'Positive Outlook', 'Building on Existing Efforts', 'Need for More Outreach Programs', 'Availability of Classes', 'Ongoing Need for Outreach', 'No Further Comments', 'Positive Perception of City', 'No Further Thoughts', "Springville's Efforts", 'More Government Action Needed', 'Open Minds to Change', 'No Further Thoughts', 'Resistance to Change', 'Delivery Systems for Walmart and Smiths', 'Easier Directions for Use']
# 1 ['Bedroom Community', 'Nutritious School Lunches', 'Library Programs', 'Collaborative Effort', 'Dog Park Initiative', 'Dog Walking Location', 'Close Community Bonds', 'Community Centers as Gathering Places', 'Supportive Community Environment', 'Strong Community Feel', 'Community Events Foster Small Town Atmosphere', 'Community Library as a Resource', "Government's Role", 'Community Involvement', 'Athletic Families']
# 2 ['Fast Spread of Illness', 'Positive Perception of Payson Healthcare', 'High Quality Revere Health and Hospital', 'Promote Physical Activity', 'Emphasize Good Nutrition', 'Involve Medical Professionals', 'Payson is a good place to live in Utah County', 'People come to Payson because it’s more affordable', 'Eagle Mountain Awareness and Action', 'General Perception of Healthy Living', 'Minority Exclusion from Healthy Living', 'Outdoor Activity Discouragement', 'Personal Discomfort', "Orem's Emphasis on Safe Parks", 'Importance of Parks for Diverse Neighborhoods', 'Benefits of Outdoor Spaces for Socialization, Exercise, and Mental Health', 'Limited Outdoor Resources in Winter', 'Need for Year-Round Activities for Seniors', 'Concerns about Water Quality', 'Positive Feelings Towards Springville', 'Holistic Approach to Health', 'Interconnected Health Factors', 'Athletics Motivated Fitness', 'Suggestion for More Outdoor Gyms', 'Outdoor Gyms for Adults', 'Current Outdoor Gyms for Kids', 'Personal Experience in China', 'Outdoor Gyms for Adults in China', 'Outdoor Gyms Encourage Exercise']

# %%
clustered_df = clustered_df.merge(map_df, on=['prompt', 'Q3_Health Problem'], how='left')

def map_texts_to_codes(texts, master_map):
    return [master_map[text] for text in texts if text in master_map]

clustered_df['cluster_orig_texts'] = clustered_df.apply(
    lambda x: map_texts_to_codes(x['clusters'], x['master_map']), axis=1
)

# %%
def generate_id(q_num, problem, clusterId):
    return f"{q_num[:3].upper()}_{problem[:3]}_{str(clusterId).upper()}"

clustered_df['id'] = clustered_df.apply(lambda row: generate_id(row['prompt'], row['Q3_Health Problem'], row['cluster_id']), axis=1)

# %%
def DeList(top_list):
    ret = []
    for x in top_list:
        ret.extend(x)
    return ret

clustered_df['cluster_orig_texts'] = clustered_df.apply(lambda row: DeList(row['cluster_orig_texts']), axis=1)

# %%
clustered_df.head()
# Out:
#               prompt Q3_Health Problem  \
# 0  Q10_Health Impact        Depression
# 1  Q10_Health Impact        Depression
# 2  Q10_Health Impact        Depression
# 3  Q10_Health Impact           Obesity
# 4  Q10_Health Impact           Obesity
#
#                                            json_list  \
# 0  [High Prevalence of Depression, Long-Term Ther...
# 1  [High Prevalence of Depression, Long-Term Ther...
# 2  [High Prevalence of Depression, Long-Term Ther...
# 3  [Disproportionate Impact on Poor, Limited Food...
# 4  [Disproportionate Impact on Poor, Limited Food...
#
#                                             clusters  cluster_id  \
# 0  [Impact on Some, Personal Perspective, Limited...           0
# 1  [High Prevalence of Depression, Long-Term Ther...           1
# 2  [Uncertainty due to Work Schedule, Limited Int...           2
# 3  [Disproportionate Impact on Poor, Parental Inf...           0
# 4  [Limited Food Access and Trauma, Limited Growt...           1
#
#                                  center  \
# 0               Decent Amount of Impact
# 1  Depression Exacerbates Health Issues
# 2               Youth Work in Community
# 3                      Community Impact
# 4             Limited Impact Perception
#
#                                           master_map  \
# 0  {'High Prevalence of Depression': ['I would sa...
# 1  {'High Prevalence of Depression': ['I would sa...
# 2  {'High Prevalence of Depression': ['I would sa...
# 3  {'Disproportionate Impact on Poor': ['Impacts ...
# 4  {'Disproportionate Impact on Poor': ['Impacts ...
#
#                                   cluster_orig_texts         id
# 0  [It does have an impact on some., Personally, ...  Q10_Dep_0
# 1  [I would say there's a lot of depression going...  Q10_Dep_1
# 2  [I am not super sure because I work a lot., I ...  Q10_Dep_2
# 3  [Impacts some of our poorest residents harder....  Q10_Obe_0
# 4  [Payson has a really active community, but the...  Q10_Obe_1

# %%
def find_center_text(text_list):
    texts = model.encode(text_list)
    centroid = texts.mean(axis=0)
    max_loc = np.argmax(np.dot(texts, centroid.T))
    return text_list[max_loc]

clustered_df['cluster_orig_texts_center'] = clustered_df.apply(lambda row: find_center_text(row['cluster_orig_texts']), axis=1)

# %%
clustered_df.head()
# Out:
#               prompt Q3_Health Problem  \
# 0  Q10_Health Impact        Depression
# 1  Q10_Health Impact        Depression
# 2  Q10_Health Impact        Depression
# 3  Q10_Health Impact           Obesity
# 4  Q10_Health Impact           Obesity
#
#                                            json_list  \
# 0  [High Prevalence of Depression, Long-Term Ther...
# 1  [High Prevalence of Depression, Long-Term Ther...
# 2  [High Prevalence of Depression, Long-Term Ther...
# 3  [Disproportionate Impact on Poor, Limited Food...
# 4  [Disproportionate Impact on Poor, Limited Food...
#
#                                             clusters  cluster_id  \
# 0  [Impact on Some, Personal Perspective, Limited...           0
# 1  [High Prevalence of Depression, Long-Term Ther...           1
# 2  [Uncertainty due to Work Schedule, Limited Int...           2
# 3  [Disproportionate Impact on Poor, Parental Inf...           0
# 4  [Limited Food Access and Trauma, Limited Growt...           1
#
#                                  center  \
# 0               Decent Amount of Impact
# 1  Depression Exacerbates Health Issues
# 2               Youth Work in Community
# 3                      Community Impact
# 4             Limited Impact Perception
#
#                                           master_map  \
# 0  {'High Prevalence of Depression': ['I would sa...
# 1  {'High Prevalence of Depression': ['I would sa...
# 2  {'High Prevalence of Depression': ['I would sa...
# 3  {'Disproportionate Impact on Poor': ['Impacts ...
# 4  {'Disproportionate Impact on Poor': ['Impacts ...
#
#                                   cluster_orig_texts         id  \
# 0  [It does have an impact on some., Personally, ...  Q10_Dep_0
# 1  [I would say there's a lot of depression going...  Q10_Dep_1
# 2  [I am not super sure because I work a lot., I ...  Q10_Dep_2
# 3  [Impacts some of our poorest residents harder....  Q10_Obe_0
# 4  [Payson has a really active community, but the...  Q10_Obe_1
#
#                            cluster_orig_texts_center
# 0                       At least from what I've seen
# 1  It seems like there's some amount of depressio...
# 2  For from my perspective, I do a lot of work wi...
# 3  Feels like it could affect the children becaus...
# 4  People don’t do the outside things when they’r...

# %%
clustered_df.to_csv('sensitive/clustered_by_codes_with_og_text.csv', index=False)

# %% [markdown]
# ##### Json Experiments

# %%
# import re
# import json
# 
# json_pattern = r'\{\s*"Axial_Category":\s*".*?"\s*\}'
# matches = re.findall(json_pattern, 'blah blah {"Axial_Category: "your mom"} blah blah', re.DOTALL)
# results = []
# for match in matches:
#     try:
#         x = json.loads(match)
#         print(x)
#     except json.JSONDecodeError as e:
#         print(e)
#

# %%
# import json
# import re
# txt = '''
#  [{"Original_Text": "With the care clinic, you have to be below the poverty line to even go there because they can't afford health care.", "Code": "Low-Income Patients", "Topic": "Patient Demographics", "Keywords": ["Poverty", "Healthcare Access"]},
#                  {"Original_Text": "So, you see there is a lot of overweight and obese people who come in with health complications that have developed to the point where now they're like, 'okay, I need to go get this seen'", "Code": "Overweight/Obese Patients with Health Complications", "Topic": "Patient Health Status", "Keywords": ["Obesity", "Health Complications"]},
#                  {"Original_Text": "But then there's only so much we can do at that point. Because it's gotten so far and they didn't get any early treatment, there's diabetes issues and just complications from all of the stuff that can come with being obese and overweight", "Code": "Limited Treatment Options for Late-Stage Health Issues", "Topic": "Treatment Limitations", "Keywords": ["Late-Stage Health Issues", "Treatment Limitations"]},
#                  {"Original_Text": "And then it's like, we can't really do very much about it. At that point, it's just managing rather than treating because we can't really undo the damage that's been done.", "Code": "Managing vs. Treating Late-Stage Health Issues", "Topic": "Treatment Approach", "Keywords": ["Managing", "Treating"]},
#                  {"Original_Text": "This could be stretching, but I think part of the reason we get such a high obese population in the people who come is because they're all so low income.", "Code": "Low-Income Patients and Obesity", "Topic": "Patient Demographics", "Keywords": ["Low-Income", "Obesity"]},
#                  {"Original_Text": "And fast food is cheap, unhealthy food is cheap, and it takes time and effort and money to be active and go to the gym and plan to eat healthy.", "Code": "Unhealthy Food Choices and Lack of Physical Activity", "Topic": "Lifestyle Factors", "Keywords": ["Unhealthy Food", "Lack of Physical Activity"]},
#                  {"Original_Text": "And these people are pretty much working and living paycheck to paycheck. So that's not a luxury they really have.", "Code": "Financial Constraints and Health Behaviors", "Topic": "Financial Constraints", "Keywords": ["Financial Constraints", "Health Behaviors"]}]
#                  '''
# 
# def parse_result(result):
#     # match = re.search(r'\[{\s\S*\}]', result)
#     # if match:
#     #     json_str = match.group(0)
#     #     try:
#     #         return json.loads(json_str)
#     #     except json.JSONDecodeError:
#     #         return None
#     # return None
#     try:
#         # Attempt to parse the text as JSON
#         json_data = json.loads(result)
#         return json_data
#     except json.JSONDecodeError as e:
#         # Handle JSON decoding errors
#         print(f"JSON decoding error: {e}")
#         return None
#     except Exception as e:
#         # Handle any other exceptions
#         print(f"An unexpected error occurred: {e}")
#         return None
# parse_result(txt)
