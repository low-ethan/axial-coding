# %%
import pandas as pd
import json

# %%
df = pd.read_csv('sensitive/health_interviews_proc.csv')

# Function to split long answers
def split_long_answers(row, max_length=1000):
    answer = row['answer']
    # print(answer)
    if type(answer) == float:
        return [row]
    if len(answer) <= max_length:
        return [row]
    
    split_rows = []
    base_id = row['id']
    parts = [answer[i:i+max_length] for i in range(0, len(answer), max_length)]
    
    for i, part in enumerate(parts):
        new_row = row.copy()
        new_row['id'] = f"{base_id}-{i+1}"
        new_row['answer'] = part
        split_rows.append(new_row)
    
    return split_rows

# Apply the splitting function
split_df = pd.DataFrame(
    [split_row for _, row in df.iterrows() for split_row in split_long_answers(row)]
)

# Save the modified DataFrame to a new CSV file
split_df.to_csv('llama/health_interview_proc_split.csv', index=False)

# %%
ret_text = '''[
  {
    "Original_Text": "I have faith in vaccination and in medical professionals.",
    "Code": "Trust in Vaccination and Medical Professionals",
    "Topic": "Belief System",
    "Keywords": ["Trust", "Vaccination", "Medical Professionals"]
  },
  {
    "Original_Text": "That faith kind of motivates you to seek out that protection, whenever possible, is that, does that sound accurate to you?",
    "Code": "Motivation for Seeking Protection",
    "Topic": "Motivation",
    "Keywords": ["Faith", "Protection"]
  },
  {
    "Original_Text": "Yeah, yeah.",
    "Code": "Agreement with Statement",
    "Topic": "Confirmation",
    "Keywords": ["Agreement", "Confirmation"]
  },
  {
    "Original_Text": "For me it wasn't really a decision I needed to make.",
    "Code": "No Decision Required",
    "Topic": "Decision-Making",
    "Keywords": ["Decision", "Automatic"]
  },
  {
    "Original_Text": "It was a foregone conclusion.",
    "Code": "Foregone Conclusion",
    "Topic": "Certainty",
    "Keywords": ["Conclusion", "Certainty"]
  },
  {
    "Original_Text": "I did check in with what his dad thought, and he was on the same page.",
    "Code": "Parental Agreement",
    "Topic": "Family Dynamics",
    "Keywords": ["Agreement", "Family"]
  },
  {
    "Original_Text": "That was just not really a decision.",
    "Code": "No Real Decision",
    "Topic": "Decision-Making",
    "Keywords": ["Decision", "Conclusion"]
  }
]'''

# %%
def convert_to_json(text):
    try:
        # Attempt to parse the text as JSON
        json_data = json.loads(text)
        return json_data
    except json.JSONDecodeError as e:
        # Handle JSON decoding errors
        print(f"JSON decoding error: {e}")
        return None
    except Exception as e:
        # Handle any other exceptions
        print(f"An unexpected error occurred: {e}")
        return None

# %%
ret = convert_to_json(ret_text)

# %%
ret
# Out:
# [{'Original_Text': 'I have faith in vaccination and in medical professionals.',
#   'Code': 'Trust in Vaccination and Medical Professionals',
#   'Topic': 'Belief System',
#   'Keywords': ['Trust', 'Vaccination', 'Medical Professionals']},
#  {'Original_Text': 'That faith kind of motivates you to seek out that protection, whenever possible, is that, does that sound accurate to you?',
#   'Code': 'Motivation for Seeking Protection',
#   'Topic': 'Motivation',
#   'Keywords': ['Faith', 'Protection']},
#  {'Original_Text': 'Yeah, yeah.',
#   'Code': 'Agreement with Statement',
#   'Topic': 'Confirmation',
#   'Keywords': ['Agreement', 'Confirmation']},
#  {'Original_Text': "For me it wasn't really a decision I needed to make.",
#   'Code': 'No Decision Required',
#   'Topic': 'Decision-Making',
#   'Keywords': ['Decision', 'Automatic']},
#  {'Original_Text': 'It was a foregone conclusion.',
#   'Code': 'Foregone Conclusion',
#   'Topic': 'Certainty',
#   'Keywords': ['Conclusion', 'Certainty']},
#  {'Original_Text': 'I did check in with what his dad thought, and he was on the same page.',
#   'Code': 'Parental Agreement',
#   'Topic': 'Family Dynamics',
#   'Keywords': ['Agreement', 'Family']},
#  {'Original_Text': 'That was just not really a decision.',
#   'Code': 'No Real Decision',
#   'Topic': 'Decision-Making',
#   'Keywords': ['Decision', 'Conclusion']}]

# %%
import re
import json
import csv

# Example output text containing the JSON list
output_text = '''
Example 1:
       [{"Original_Text": "Do you know anyone whose child has gotten sick with the flu or has [CHILD] gotten the flu before that you know of?", "Code": "Flu Experience", "Topic": "Child's Health", "Keywords": ["Child's", "Flu", "Illness History"]}]
       
                Input:
                Interviewer: Yeah. So when you want to learn more about something like the flu. Where do you go to find that information?
                Answer: I would just Google it. I would look on the...the NHS website. So I would basically always Google it. And I would look at the NHS website. And then...
                JSON Output:
                [{"Original_Text": "Yeah. So when you want to learn more about something like the flu. Where do you go to find that information?", "Code": "Health Information Source", "Topic": "Health Education", "Keywords": ["Flu", "Information Source", "Health"]}]
'''

# %%
def validate_json_objects(json_objects):
    # Define the required keys
    required_keys = {"Original_Text", "Code", "Topic", "Keywords"}
    
    # Iterate over each JSON object and validate
    for obj in json_objects:
        # Check if all required keys are present
        if not required_keys.issubset(obj.keys()):
            return None
        
        # Check if 'Keywords' is a list of strings
        if not isinstance(obj['Keywords'], list) or not all(isinstance(keyword, str) for keyword in obj['Keywords']):
            return None
    
    # If all objects pass the validation, return the parsed JSON objects
    return json_objects

# %%
def json_match(output_text):
    json_list_pattern = r'\[\{.*?\}\]'
    list_matches = re.findall(json_list_pattern, output_text, re.DOTALL)
    if list_matches:
        json_pattern = r'\{"Original_Text":\s*".+?",\s*"Code":\s*".+?",\s*"Topic":\s*".+?",\s*"Keywords":\s*\[\s*(?:"[^"]*"\s*(?:,\s*)?)*\]\s*\}'
        json_matches = re.findall(json_pattern, list_matches[0], re.DOTALL)
        rets = []
        for match in json_matches:
            try:
                x = json.loads(match)
                rets.append(x)
            except json.JSONDecodeError as e:
                print(f"JSON decoding error: {e}")
        return rets
    return []

# %%
import pandas as pd
df = pd.read_csv('Depreciated-interview/all_txt_output.csv')

# %%
df.head()
# Out:
#                                               Result
# 0       [{"Original_Text": "Alright, Okay.", "Cod...
# 1       [{"Original_Text": "I agree", "Code": "Co...
# 2       [{"Original_Text": "I agree.", "Code": "I...
# 3       [\n                    {"Original_Text":"...
# 4       [{"Consent": "Yes"}]\n                Inp...

# %%
for i, obj in enumerate(df['Result']):
    res = json_match(obj)
    print(res)
    print('ORIG::::', obj)
    if i > 5:
        break
# Out:
# [{'Original_Text': 'Alright, Okay.', 'Code': 'Read: Agree Process', 'Topic': 'Consent', 'Keywords': ['Consent']}]
# ORIG::::      [{"Original_Text": "Alright, Okay.", "Code": "Read: Agree Process","Topic": "Consent","Keywords": ["Consent"]}]
#
#                 Input:
#                 Interviewer: So could you please tell me your name and the region where you live?
#                 Answer: Yes, my name is [NAME]and we live in England.
#                 JSON Output:
#                 [{"Original_Text": "My name is [NAME] and we live in England.", "Code": "Provides Name and Country","Topic": "Demographic", "Keywords": ["Name", "Country", "England"]}]
#
#                 Input:
#                 Interviewer: And we're going to start by asking some questions about any child illness history or exposure events.
#                 Answer: And um, is it about children or is it about adults?
#                 JSON Output:
#
# []
# ORIG::::      [{"Original_Text": "I agree", "Code": "Confirmed Comprehension", "Topic": "Confirmation","Keyword": ""}]
#
#
#                 Input:
#                 Interviewer: Do you consent to take part in this study? Yes.
#                 Answer: Yes
#                 Json Output:
#                 [{"Original_Text": "Yes", "Code": "Confirmed Consent", "Topic": "Confirmation", "Keywords": ["Yes", "Confirmed"]}]<eos>
# [{'Original_Text': 'I agree.', 'Code': 'Informed Consent', 'Topic': 'Interviews', 'Keywords': ['Participation', 'Voluntary', 'Withdrawal']}]
# ORIG::::      [{"Original_Text": "I agree.", "Code": "Informed Consent", "Topic": "Interviews", "Keywords": ["Participation", "Voluntary", "Withdrawal"]
#                 }]
# <eos>
# []
# ORIG::::      [
#                     {"Original_Text":"I agree","Code":"Permission Given","Topic":"Permissions","Keywords":["Permission","Agree"]}
#                 ]<eos>
# []
# ORIG::::      [{"Consent": "Yes"}]
#                 Input
#                 Interviewer: Have you any questions, ideas, or additions to your interview?
#                 Answer: It’s good that you’re doing stuff in the home.
#                 JSON Output:
#                 [{"Question": “How?”}, {"Question": "Any suggestions/ideas"}, {"Question": "Any additions"}]<eos>
# [{'Original_Text': 'I agree', 'Code': 'Informed Consent: Agree', 'Topic': 'Consent', 'Keywords': ['Consent', 'Agree']}]
# ORIG::::      [{"Audio Transcript": "I agree"},
#                 {"Original_Text": "I agree", "Code": "Informed Consent: Agree", "Topic": "Consent", "Keywords": ["Consent", "Agree"]}]<eos>
# [{'Original_Text': 'I agree.', 'Code': 'Information Sharing Agreement Accepted', 'Topic': 'Consent', 'Keywords': ['Consent', 'Consent Text']}]
# ORIG::::      [{"Original_Text": "I agree.", "Code": "Information Sharing Agreement Accepted",  "Topic": "Consent", "Keywords": ["Consent", "Consent Text" ]}]
# <eos>

# %%
df2 = pd.read_csv('gemma_7B_prompt_two_examples.csv')

# %%
df2.head()
# Out:
#    row     id                                             prompt  \
# 0    3  ts9_3  I understand the information collected during ...
# 1    4  ts9_4  Understand that information collected during t...
# 2    7  ts9_7            And I agree to take part in this study.
# 3    8  ts9_8  Excellent. And there's just two last things. S...
# 4    9  ts9_9  Excellent. Yep. I can do that. So that'll be i...
#
#                                               answer  \
# 0                                            I agree
# 1                                            I agree
# 2                                     Yeah, I agree.
# 3  Yeah, that's fine. I know my wife is involved ...
# 4                                      Email is fine
#
#                                           label_json
# 0  [{'Original_Text': 'I agree.', 'Code': 'Agreed...
# 1  [{'Original_Text': 'Agreed', 'Code': 'Agreed',...
# 2  [{'Original_Text': 'And I agree to take part i...
# 3  [{'Original_Text': "So if you'd like to receiv...
# 4  [{'Original_Text': 'Email is fine', 'Code': 'E...

# %%
df_grouped = df2.groupby('id').agg({
    'label_json': lambda x: '[' + ', '.join(x.str.strip('[]')) + ']',
    **{col: 'first' for col in df2.columns if col not in ['id', 'label_json']}
}).reset_index()
df_grouped.sort_values(by='id').head(20)
# Out:
#          id                                         label_json  row  \
# 0    ts10_0  [{'Original_Text': "So it's basically just mak...  281
# 1    ts10_1  [{'Original_Text': 'Yes.', 'Code': 'Agreed- In...  282
# 2   ts10_10  [{'Original_Text': "Oh that's great. Two kiddo...  291
# 3   ts10_11  [{'Original_Text': 'They are two and five.', '...  292
# 4   ts10_12  [{'Original_Text': 'She has yeah she started l...  293
# 5   ts10_13  [{'Original_Text': 'Um yeah, it took her a few...  294
# 6   ts10_14  [{'Original_Text': "Um okay. It's just been an...  295
# 7   ts10_15  [{'Original_Text': "Yeah, it's nice to have so...  296
# 8   ts10_16  [{'Original_Text': "She's five and [Younger ch...  297
# 9   ts10_17  [{'Original_Text': 'With the kids and they do ...  298
# 10  ts10_18  [{'Original_Text': 'She did yeah, at school, s...  299
# 11  ts10_19  [{'Original_Text': "I think it's hard to remem...  300
# 12   ts10_2  [{'Original_Text': 'I understand my participat...  283
# 13  ts10_20  [{'Original_Text': 'So that was my negligence ...  301
# 14  ts10_21  [{'Original_Text': 'Yeah.', 'Code': 'No Reply'...  302
# 15  ts10_23  [{'Original_Text': 'Well, I know that the adul...  304
# 16  ts10_25  [{'Original_Text': 'Yeah', 'Code': 'No Problem...  306
# 17  ts10_26  [{'Original_Text': 'I know. In fact, the other...  307
# 18  ts10_27  [{'Original_Text': "I think because she couldn...  308
# 19  ts10_28  [{'Original_Text': "Well, I'm glad that that h...  309
#
#                                                prompt  \
# 0   Alright so what we'll start with is I'm going ...
# 1   Okay, yeah. Alright, so the first one I confir...
# 2   Alright, so that's all that out of the way so ...
# 3                         Yeah. And how old are they?
# 4   Yeah. Um, so the five year old has started sch...
# 5                Yeah, how was how was she liking it?
# 6   Yeah. And how are, how are things going with h...
# 7   Yeah, it's nice to have some outdoor access, b...
# 8   So can you tell me a little bit about your chi...
# 9   Yeah, very cool. So can you tell me what you k...
# 10  Yeah, so has, your older daughter that's [Olde...
# 11  And [Younger child] did not have it. Is that r...
# 12  All right, I understand my participation is vo...
# 13                                              Sure.
# 14  Yeah, so it was rather than like making an app...
# 15  Yeah sure. No, that that makes sense to me. I ...
# 16  Yeah. You've done it all once before, you're b...
# 17  Yeah. So it sounds like from what you're sayin...
# 18  Wow, yeah. I'm glad she was okay. That sounds ...
# 19   Well, I'm glad that that had an easy resolution.
#
#                                                answer
# 0                                          All right.
# 1                                                Yes.
# 2                                         I do. Yeah.
# 3                              They are two and five.
# 4            She has yeah she started last September.
# 5   Um yeah, it took her a few weeks to um, before...
# 6   Um okay. It's just been an adjustment because ...
# 7                                         Yeah, yeah.
# 8   [Older child] is the elder, she's five and [Yo...
# 9   Well, I always think, you always, sometimes pe...
# 10  She did yeah, at school, she had this spray up...
# 11  She didn't. I think it's hard to remember that...
# 12                                               Yes.
# 13  So that was my negligence really. But this yea...
# 14                                              Yeah.
# 15  Um, well, I know that the adults experience an...
# 16                                               Yeah
# 17  Yeah, there's been a few times when Violent wa...
# 18  I think because she couldn't tell us what was ...
# 19                                   Yeah absolutely.

# %%
df_grouped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 385 entries, 0 to 384
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          385 non-null    object
#  1   label_json  385 non-null    object
#  2   row         385 non-null    int64
#  3   prompt      385 non-null    object
#  4   answer      385 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 15.2+ KB

# %%
import ast
def convert_to_dict(x):
    try:
        # Try to safely evaluate the string as a Python dictionary
        output = ast.literal_eval(x)

        return output
    except (ValueError, SyntaxError) as e:
        # Print the exception for debugging
        print(f"Didn't work: {x}")
        print(f"Exception: {e}")
        return None
    
df_grouped['tmp'] = df_grouped['label_json'].apply(convert_to_dict)

# %%
df_grouped['tmp'].head()[0]
# Out:
# [{'Original_Text': "So it's basically just making sure that you understand what we're doing and that we have your permission for you to take part in the study.",
#   'Code': 'Understanding and Permission',
#   'Topic': 'Context',
#   'Keywords': ['Permission', 'Contact']},
#  {'Original_Text': "So I'm going to read you each of these statements and I'll just ask that you say either yes or I agree, or no, I don't agree to each one.",
#   'Code': "Yes or I Agree or No I  Don't Agree Option",
#   'Topic': 'Context',
#   'Keywords': ['Yes', 'No', 'Options']},
#  {'Original_Text': 'OK.',
#   'Code': 'OK',
#   'Topic': 'General',
#   'Keywords': ['OK']}]

# %%
import numpy as np
from sentence_transformers.util import cos_sim
from sentence_transformers import SentenceTransformer
import seaborn as sns
import matplotlib.pyplot as plt

model_ckpt = 'sentence-transformers/distiluse-base-multilingual-cased-v2'

model = SentenceTransformer(model_ckpt)
# Out:
# /Users/ethanlow/PycharmProjects/axialcoding/.venv/lib/python3.9/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
# def similarity_scores(model, s1, to_compare):
#     sentences = [s1]+to_compare
#     embeddings = model.encode(sentences)
#     print(embeddings)
#     sim = np.zeros((len(sentences), len(sentences)))
#     print(len(sentences))
#     for i in range(len(embeddings)):
#         sim[i] = cos_sim(embeddings[i], embeddings[i:])
#         break
#     return sim[0][1:]

# %%
# similarity_scores(model, 'YEAH', ['Acknowledged', 'Consent', 'Yeah', 'Agreed'])

# %%
def similarity_scores(s1, to_compare):
    embeddings = np.concatenate([[s1], to_compare])
    # print(embeddings)
    sim = np.zeros((len(embeddings), len(embeddings)))
    # print(len(embeddings))
    for i in range(len(embeddings)):
        sim[i] = cos_sim(embeddings[i], embeddings[i:])
        break
    return sim[0][1:]

# %%
e1 = model.encode('YEAH')
tc = model.encode(['Acknowledged', 'Consent', 'Yeah', 'Agreed'])
similarity_scores(e1, tc)
# Out:
# array([0.41554683, 0.4882232 , 0.87535828, 0.51043856])

# %%
from sentence_transformers.util import cos_sim

def similarity_score(model, in_sentence, mod_sentence):
  in_em = model.encode(in_sentence)
  mod_em = model.encode(mod_sentence)
  return cos_sim(in_em, mod_em)

# %%
df_grouped['tmp'].head()[0]
# Out:
# [{'Original_Text': "So it's basically just making sure that you understand what we're doing and that we have your permission for you to take part in the study.",
#   'Code': 'Understanding and Permission',
#   'Topic': 'Context',
#   'Keywords': ['Permission', 'Contact']},
#  {'Original_Text': "So I'm going to read you each of these statements and I'll just ask that you say either yes or I agree, or no, I don't agree to each one.",
#   'Code': "Yes or I Agree or No I  Don't Agree Option",
#   'Topic': 'Context',
#   'Keywords': ['Yes', 'No', 'Options']},
#  {'Original_Text': 'OK.',
#   'Code': 'OK',
#   'Topic': 'General',
#   'Keywords': ['OK']}]

# %%
s1 = df_grouped['tmp'].head()[2][3]['Code']
s2 = df_grouped['tmp'].head()[2][4]['Code']
print(s1, s2)
similarity_score(model, s1, s2)
# Out:
# Number of Children Confirmed Parent with 2 Children
# tensor([[0.4361]])

# %%
# for json_list in df_grouped['tmp'].head(2):
#     for i in range(len(json_list)):
#         # if similarity_score(model, json_list[i]['Code'], 'yeah') > .5:
#         if max(similarity_scores(model, json_list[i]['Topic'], ['Acknowledged', 'Consent', 'Yeah', 'Agreed'])) > .5:
#             print(json_list[i]['Code'], ':::' ,json_list[i]['Original_Text'])

# %%
df_grouped.head()
# Out:
#         id                                         label_json  row  \
# 0   ts10_0  [{'Original_Text': "So it's basically just mak...  281
# 1   ts10_1  [{'Original_Text': 'Yes.', 'Code': 'Agreed- In...  282
# 2  ts10_10  [{'Original_Text': "Oh that's great. Two kiddo...  291
# 3  ts10_11  [{'Original_Text': 'They are two and five.', '...  292
# 4  ts10_12  [{'Original_Text': 'She has yeah she started l...  293
#
#                                               prompt  \
# 0  Alright so what we'll start with is I'm going ...
# 1  Okay, yeah. Alright, so the first one I confir...
# 2  Alright, so that's all that out of the way so ...
# 3                        Yeah. And how old are they?
# 4  Yeah. Um, so the five year old has started sch...
#
#                                      answer  \
# 0                                All right.
# 1                                      Yes.
# 2                               I do. Yeah.
# 3                    They are two and five.
# 4  She has yeah she started last September.
#
#                                                  tmp
# 0  [{'Original_Text': 'So it's basically just mak...
# 1  [{'Original_Text': 'Yes.', 'Code': 'Agreed- In...
# 2  [{'Original_Text': 'Oh that's great. Two kiddo...
# 3  [{'Original_Text': 'They are two and five.', '...
# 4  [{'Original_Text': 'She has yeah she started l...

# %%
def cut_similars(model, json_list):
    to_drop = set()
    for i in range(len(json_list)):
        if i in to_drop:
            continue
        agg_words = model.encode(['Acknowledged', 'Consent', 'Yeah', 'Agreed', 'No Code'])
        c_emb = model.encode(json_list[i]['Code'])
        if max(similarity_scores(c_emb, agg_words)) > .5:
            to_drop.add(i)
            continue
        if max(similarity_scores(model.encode(json_list[i]['Topic']), agg_words)) > .5:
            to_drop.add(i)
            continue
        for j in range(i+1, len(json_list)):
            if cos_sim(c_emb, model.encode(json_list[j]['Code'])) > 0.6:
                # print(json_list[i]['Code'], json_list[j]['Code'])
                to_drop.add(j)
    json_list = [item for idx, item in enumerate(json_list) if idx not in to_drop]
    return json_list

# row = df_grouped['tmp'].head()[2]
# print(row)
# cut_similars(model, row)

# Apply the function to each row in the 'json_list' column
df_grouped['json_list'] = df_grouped['tmp'].apply(lambda x: cut_similars(model, x))

# %%
df_grouped.head()
# Out:
#         id                                         label_json  row  \
# 0   ts10_0  [{'Original_Text': "So it's basically just mak...  281
# 1   ts10_1  [{'Original_Text': 'Yes.', 'Code': 'Agreed- In...  282
# 2  ts10_10  [{'Original_Text': "Oh that's great. Two kiddo...  291
# 3  ts10_11  [{'Original_Text': 'They are two and five.', '...  292
# 4  ts10_12  [{'Original_Text': 'She has yeah she started l...  293
#
#                                               prompt  \
# 0  Alright so what we'll start with is I'm going ...
# 1  Okay, yeah. Alright, so the first one I confir...
# 2  Alright, so that's all that out of the way so ...
# 3                        Yeah. And how old are they?
# 4  Yeah. Um, so the five year old has started sch...
#
#                                      answer  \
# 0                                All right.
# 1                                      Yes.
# 2                               I do. Yeah.
# 3                    They are two and five.
# 4  She has yeah she started last September.
#
#                                                  tmp  \
# 0  [{'Original_Text': 'So it's basically just mak...
# 1  [{'Original_Text': 'Yes.', 'Code': 'Agreed- In...
# 2  [{'Original_Text': 'Oh that's great. Two kiddo...
# 3  [{'Original_Text': 'They are two and five.', '...
# 4  [{'Original_Text': 'She has yeah she started l...
#
#                                            json_list
# 0                                                 []
# 1                                                 []
# 2  [{'Original_Text': 'Oh that's great. Two kiddo...
# 3  [{'Original_Text': 'They are two and five.', '...
# 4  [{'Original_Text': 'She has yeah she started l...

# %%
df4 = df_grouped[df_grouped['json_list'].apply(lambda x: x != [])]

# %%
df4.head()
# Out:
#         id                                         label_json  row  \
# 2  ts10_10  [{'Original_Text': "Oh that's great. Two kiddo...  291
# 3  ts10_11  [{'Original_Text': 'They are two and five.', '...  292
# 4  ts10_12  [{'Original_Text': 'She has yeah she started l...  293
# 5  ts10_13  [{'Original_Text': 'Um yeah, it took her a few...  294
# 6  ts10_14  [{'Original_Text': "Um okay. It's just been an...  295
#
#                                               prompt  \
# 2  Alright, so that's all that out of the way so ...
# 3                        Yeah. And how old are they?
# 4  Yeah. Um, so the five year old has started sch...
# 5               Yeah, how was how was she liking it?
# 6  Yeah. And how are, how are things going with h...
#
#                                               answer  \
# 2                                        I do. Yeah.
# 3                             They are two and five.
# 4           She has yeah she started last September.
# 5  Um yeah, it took her a few weeks to um, before...
# 6  Um okay. It's just been an adjustment because ...
#
#                                                  tmp  \
# 2  [{'Original_Text': 'Oh that's great. Two kiddo...
# 3  [{'Original_Text': 'They are two and five.', '...
# 4  [{'Original_Text': 'She has yeah she started l...
# 5  [{'Original_Text': 'Um yeah, it took her a few...
# 6  [{'Original_Text': 'Um okay. It's just been an...
#
#                                            json_list
# 2  [{'Original_Text': 'Oh that's great. Two kiddo...
# 3  [{'Original_Text': 'They are two and five.', '...
# 4  [{'Original_Text': 'She has yeah she started l...
# 5  [{'Original_Text': 'Um yeah, it took her a few...
# 6  [{'Original_Text': 'Um okay. It's just been an...

# %%
def extract_codes(json_list):
    return [entry['Code'] for entry in json_list]

all_codes = sum(df4['json_list'].apply(extract_codes), [])

print(len(all_codes))
# Out:
# 1088

# %%
all_codes[100:150]
# Out:
# ['No Availability: Time',
#  'Limited by Staff and Premises',
#  'Clinic Schedule',
#  'Service Limitations',
#  'Service is Good',
#  'Yes Vaccines Given',
#  'Standard Childhood Vaccines',
#  'Purpose of Questions',
#  'Nurses and Doctors Give Flu Shots',
#  'Nurse Acknowledgement of Apprehension',
#  'Doctor Sitting with You',
#  'Positive Regarding Communication',
#  'Transparency',
#  'Willingness to Talk',
#  'Potential Benefit of Disclosure',
#  'Last Year Question',
#  'Does Not Prioritize Vaccination',
#  'Possible to get in future',
#  'Consent to Record',
#  'No Flu Experience',
#  'Consent to Audio-Video Record Interview',
#  'Knowledge mostly in Adults',
#  'Flu Not Top of Mind',
#  'Flu as Just Something to Face',
#  'Complications due to Others',
#  'Encourages Thoughts on Flu',
#  'Want someone to say I have a flu',
#  'Stop Recording',
#  'No Further Information Provided',
#  'First Answer',
#  'Request for Findings',
#  'Interested in Findings',
#  'Study End Date',
#  'Hard Copy Required',
#  'Email only',
#  'Contact for Additional Information',
#  'Mailing Address Requested',
#  'Same Email?',
#  'Complete Now',
#  'Email Preferred',
#  'Same Study Document Format as Email?',
#  'Concensus Statement Read',
#  'Opportunity to Ask Questions',
#  'Apologized for Repetitive Process',
#  'Consented for Interview',
#  'Informed Consent Interviewer',
#  'Answering Questions',
#  'Child 1 Age',
#  'Parents with Two Children',
#  "Second Child of 3 Year's Old"]

# %%
pd.DataFrame(all_codes).to_csv('Depreciated-interview/all_codes.csv', index=False)

# %%
code_len = [len(code) for code in all_codes]
print(sum(code_len))
# Out:
# 24926

# %%
# def json_match(output_text):
#     json_list_pattern = r'\[\{.*?\}\]'
#     list_matches = re.findall(json_list_pattern, output_text, re.DOTALL)
#     if list_matches:
#         json_pattern = r'\{"Original_Text":\s*".+?",\s*"Code":\s*".+?",\s*"Topic":\s*".+?",\s*"Keywords":\s*\[\s*(?:"[^"]*"\s*(?:,\s*)?)*\]\s*\}'
#         json_matches = re.findall(json_pattern, list_matches[0], re.DOTALL)
#         rets = []
#         for match in json_matches:
#             try:
#                 x = json.loads(match)
#                 rets.append(x)
#             except json.JSONDecodeError as e:
#                 print(f"JSON decoding error: {e}")
#         return rets
#     return []

def parse_result(result):
    json_pattern = r'\{\s*"Code":\s*".*?",\s*"Axial_Category":\s*".*?"\s*\}'

    # match = re.search(, result)
    matches = re.findall(json_pattern, result, re.DOTALL)
    results = []
    for match in matches:
        try:
            x = json.loads(match)
            print(x['Axial_Category'])
            results.append(x)
        except json.JSONDecodeError as e:
            print(e)
    return results

# %%
mystr = '''
    Certainly! your code is
    {"Code": "Email Preference",
	"Axial_Category": "NA"}
    {"Code":"Would Like a Copy of Report",
	"Axial_Category": "NA"}
'''
print(parse_result(mystr))
# Out:
# NA
# NA
# [{'Code': 'Email Preference', 'Axial_Category': 'NA'}, {'Code': 'Would Like a Copy of Report', 'Axial_Category': 'NA'}]

# %%
ax_set = set()
ax_set.add('NA')
ax_set.add('Email Preference')

# %%
pd.DataFrame(ax_set)
# Out:
#                   0
# 0                NA
# 1  Email Preference

# %%
# import ast
# 
# 
# def process_csv(filename):
#     df = pd.read_csv(f'{filename}.csv')
#     df = df.drop_duplicates(subset=['id'])
# 
#     label_col = 'label_json'
#     
#     def convert_to_dict(x):
#         try:
#             # Try to safely evaluate the string as a Python dictionary
#             output = ast.literal_eval(x)
# 
#             return output
#         except (ValueError, SyntaxError) as e:
#             # Print the exception for debugging
#             print(f"Didn't work: {x}")
#             print(f"Exception: {e}")
#             return None
# 
#     df['label_json'] = df[label_col].apply(convert_to_dict)
#     df = df.dropna(subset=['label_json'])
#     expanded_df = df['label_json'].apply(pd.Series)
#     df_expanded = pd.concat([df.drop('label_json', axis=1), expanded_df], axis=1)
#     
#     return df_expanded
# 
# filename = 'gemma_7B_prompt_two_examples'
# process_csv(filename)

# %%
import numpy as np
from sentence_transformers.util import cos_sim
from sentence_transformers import SentenceTransformer
import seaborn as sns
import matplotlib.pyplot as plt

model_ckpt = 'sentence-transformers/distiluse-base-multilingual-cased-v2'

model = SentenceTransformer(model_ckpt)
# Out:
# /Users/ethanlow/PycharmProjects/axialcoding/.venv/lib/python3.9/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
sentences = ['Wanting experiential learning', 'constantly learning', 'working in a good environment', 
             'pioneering social media and easily adapting to change', 'feeling entitled due to unique qualifications, as compared to previous generations',
             'possessing the personal skills and characteristics needed', 'being groomed',
             'Craving immediate feedback and being motivated by feeling appreciated', 'detesting getting called out', 'receiving verbal encouragement and making observations', 'Mind reading and expectations for a miracle worker', 'getting called out', 'not being heard', 'Advocating a work-life balance', 'being cared for as a whole person', 'accommodating interests and preferences']
embeddings = model.encode(sentences)
# embeddings[0]

# %%
embeddings = model.encode(all_codes)

# %%
from sklearn.cluster import KMeans
import numpy as np

kmeans = KMeans(n_clusters=10, random_state=0, n_init="auto").fit(np.array(embeddings))
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# /Users/ethanlow/PycharmProjects/axialcoding/.venv/lib/python3.9/site-packages/threadpoolctl.py:1214: RuntimeWarning:
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#   warnings.warn(msg, RuntimeWarning)

# %%
kmeans.labels_
# Out:
# array([0, 4, 6, ..., 9, 9, 5], dtype=int32)

# %%
[(sect, sent) for sect, sent in zip(kmeans.labels_, all_codes)]
# Out:
# [(0, 'Current Residence since 1997'),
#  (4, "Dad's Flu Symptoms More Tolerable"),
#  (6, 'Number of Children in Household'),
#  (6, 'Parent with 2 Children'),
#  (4, 'Tried to get Flu Vaccine'),
#  (6, '4-yr-old, 7-yr-old'),
#  (6, "Children's Age"),
#  (0, 'Five and Two Years of Age'),
#  (0, 'Start of School Year'),
#  (6, 'Child is/was in School'),
#  (6, 'Child gets Home-Time'),
#  (0, 'Started Last September'),
#  (0, 'Time to Settle'),
#  (8, 'Ongoing Illness'),
#  (5, 'Anticipated Re-Entry'),
#  (6, 'Child out on Sick Leave'),
#  (5, 'Will be fine on Return'),
#  (5, 'Settled Quickly'),
#  (5, 'Anticipated Future Stability'),
#  (1, 'No Schoolwork'),
#  (5, 'Adjusting to Stay Home'),
#  (7, 'Question'),
#  (1, 'Nice to have but not necessary'),
#  (5, 'Accept Current Conditions'),
#  (5, 'General Agreement'),
#  (9, 'N/A'),
#  (5, 'Range of Interests'),
#  (6, 'Older Child Interests'),
#  (4, 'Get Flu Shots for Kids'),
#  (1, 'Usually No Shot'),
#  (0, 'Received spray this year'),
#  (4, 'Received the Flu Vaccine'),
#  (9, 'Spray Type'),
#  (1, 'Unable to Recall'),
#  (4, 'Missed Vaccination Window'),
#  (5, 'Dissertation and Memory Loss'),
#  (5, 'Fuzzy Memory'),
#  (2, 'Do Not Have Flu Experience'),
#  (5, 'Participation Voluntary'),
#  (5, 'Withdrawal Options Always Possible'),
#  (7, 'Interviewee Understanding'),
#  (5, 'Ability to Decline'),
#  (5, 'Participant Agrees to Privacy Statement'),
#  (4, 'Negligence with Flu Vaccine'),
#  (5, 'Change of Location'),
#  (0, 'Limited Time Frame'),
#  (1, 'Did Not Attend Clinic'),
#  (5, 'Increased Effort'),
#  (8, 'Open Clinic'),
#  (5, 'Changed Event Schedule'),
#  (1, 'Unable to Make Event'),
#  (2, "Can't Comment on Experience"),
#  (9, 'N/A'),
#  (5, 'Walk-in Option Available'),
#  (6, 'Childhood similar to Adult Manifestation'),
#  (3, 'Research in Dr. Google'),
#  (2, 'General Cold/Flu Experience for Adults'),
#  (3, 'Use of Resources'),
#  (6, 'When Child is Ill'),
#  (1, 'No Problems'),
#  (9, 'At that Point'),
#  (5, 'Agreed with Expert Status'),
#  (2, 'Previous Experience with Flu'),
#  (9, 'Sugar Free Jelly'),
#  (8, 'Unknown Illness'),
#  (9, '111 was contacted'),
#  (1, 'Inability to Identify Cause'),
#  (8, 'Associated Symptom Knowledge'),
#  (5, 'Sweets Cause'),
#  (5, 'Easy Resolution'),
#  (3, 'Information Collected'),
#  (3, 'Data Access - Study Research'),
#  (8, 'Benefits Minimizing Risk of Illnesses'),
#  (1, 'Not Thought about Benefits Before'),
#  (1, 'Not Given Thought'),
#  (1, 'No Side Effects'),
#  (5, 'Low Risk'),
#  (4, 'Vaccine Protection'),
#  (8, 'Prevent Sickness'),
#  (1, 'No Thought'),
#  (3, 'Limited to Low-Risk Info'),
#  (4, 'Flu as Generally Accepted'),
#  (2, 'Flu Not Seen as Sinister'),
#  (1, 'Nothing to Add'),
#  (5, 'Reading More To Determine Risk/Benefit'),
#  (5, 'Feels Safe to Trust Decision Making'),
#  (5, 'Interest in Reading More'),
#  (1, "Experts aren't Needed"),
#  (8, 'Health Visitor Pamphlets'),
#  (3, 'NHS Website Primary Source'),
#  (5, 'Red Book Reference'),
#  (3, 'Information from Health Education'),
#  (3, 'GP as Information Source'),
#  (9, 'Parent Sent Letter'),
#  (9, 'Letter from School with Program Info'),
#  (8, 'Husband is Informed Yet Concerned'),
#  (8, 'Not Thought of Health Concern Before'),
#  (6, 'Younger Daughter in Different School'),
#  (7, 'Interview Process'),
#  (4, 'No Flu Vaccine'),
#  (1, 'No Availability: Time'),
#  (5, 'Limited by Staff and Premises'),
#  (8, 'Clinic Schedule'),
#  (5, 'Service Limitations'),
#  (9, 'Service is Good'),
#  (4, 'Yes Vaccines Given'),
#  (4, 'Standard Childhood Vaccines'),
#  (7, 'Purpose of Questions'),
#  (4, 'Nurses and Doctors Give Flu Shots'),
#  (8, 'Nurse Acknowledgement of Apprehension'),
#  (8, 'Doctor Sitting with You'),
#  (5, 'Positive Regarding Communication'),
#  (5, 'Transparency'),
#  (5, 'Willingness to Talk'),
#  (5, 'Potential Benefit of Disclosure'),
#  (7, 'Last Year Question'),
#  (4, 'Does Not Prioritize Vaccination'),
#  (0, 'Possible to get in future'),
#  (5, 'Consent to Record'),
#  (2, 'No Flu Experience'),
#  (7, 'Consent to Audio-Video Record Interview'),
#  (5, 'Knowledge mostly in Adults'),
#  (2, 'Flu Not Top of Mind'),
#  (4, 'Flu as Just Something to Face'),
#  (5, 'Complications due to Others'),
#  (4, 'Encourages Thoughts on Flu'),
#  (4, 'Want someone to say I have a flu'),
#  (5, 'Stop Recording'),
#  (1, 'No Further Information Provided'),
#  (7, 'First Answer'),
#  (7, 'Request for Findings'),
#  (5, 'Interested in Findings'),
#  (0, 'Study End Date'),
#  (5, 'Hard Copy Required'),
#  (9, 'Email only'),
#  (3, 'Contact for Additional Information'),
#  (9, 'Mailing Address Requested'),
#  (9, 'Same Email?'),
#  (0, 'Complete Now'),
#  (9, 'Email Preferred'),
#  (9, 'Same Study Document Format as Email?'),
#  (5, 'Concensus Statement Read'),
#  (7, 'Opportunity to Ask Questions'),
#  (5, 'Apologized for Repetitive Process'),
#  (7, 'Consented for Interview'),
#  (7, 'Informed Consent Interviewer'),
#  (7, 'Answering Questions'),
#  (6, 'Child 1 Age'),
#  (6, 'Parents with Two Children'),
#  (6, "Second Child of 3 Year's Old"),
#  (6, 'Younger Child will be 4 in September'),
#  (6, "Children's Ages: 9 Years Old"),
#  (6, "Youngest Child: 'Younger'"),
#  (6, '3 Girls in Household'),
#  (6, 'Girl Twins'),
#  (6, 'Gender of Children'),
#  (6, 'Children Surviving'),
#  (6, "Child's WellBeing"),
#  (8, 'Health Regressions'),
#  (5, 'Potential Regression'),
#  (9, 'Grayer'),
#  (2, 'No Grey Hair Experience'),
#  (6, 'Child Regression'),
#  (0, 'Accelerated Aging'),
#  (0, 'Greying Over Time'),
#  (2, 'No Past Illness Experience'),
#  (6, 'Younger Child'),
#  (6, 'School Nursery'),
#  (1, 'Nursery but Not Reception'),
#  (6, 'Early Entry to Nursery'),
#  (0, 'Entry to Reception in September'),
#  (0, 'She was in school nursery'),
#  (0, "She's going to be the oldest"),
#  (0, 'in school, but not in school yet'),
#  (2, 'No Kindergarten Experience'),
#  (1, 'No Kindergarten'),
#  (0, 'School Closing'),
#  (6, 'Social-Distanced Nursery'),
#  (5, 'Begging Crying'),
#  (6, 'Begging Crying Crying as Child Care Methods'),
#  (1, 'No Begging Work'),
#  (1, 'Try Nothing of Value to Influence'),
#  (1, 'Missing social aspect'),
#  (6, 'Kids not Missing the Schoolwork'),
#  (6, 'Social aspect important for kids'),
#  (1, 'Missing Friends'),
#  (6, 'Bored of Parent'),
#  (5, 'Bored of Me'),
#  (3, 'Granted Data Access'),
#  (3, 'Researcher Access'),
#  (1, 'No Concerns'),
#  (3, 'Confidence in Researcher'),
#  (8, 'Nursing Family History'),
#  (8, 'Fever, Fatigue, Muscle Aches'),
#  (4, 'Flu a Combination of Cold and Flu Symptoms'),
#  (4, 'Flu Symptoms as Illnesses'),
#  (8, 'Confidently Identified Symptoms'),
#  (5, 'Concern for the Process'),
#  (8, 'No Underlying Health Conditions'),
#  (8, 'Generally Healthy & Not Infancy'),
#  (7, 'Answer: General Statement'),
#  (8, 'Innate Immunity Age Restriction'),
#  (7, 'Implied Positive Response'),
#  (6, 'Not a small infant'),
#  (5, 'Feel safe'),
#  (0, 'Week to 10 days'),
#  (2, 'Multiple Children, No Knowledge of Flu'),
#  (8, '1 Week to 10 Days Fever Duration'),
#  (1, "No to be fair I don't actually... I'm just trying to think. No."),
#  (7, 'I agree to sharing interview'),
#  (1, 'Concerned about Unspecific Internet Accuracy'),
#  (3, 'Avoid Unverified Information Sources'),
#  (9, 'Family Facebook Group Automatic'),
#  (3, 'Incorrect Information Available'),
#  (6, 'Parenting Strategies'),
#  (6, 'Parenting as Coping Behavior'),
#  (5, 'More Like Coping Mechanisms'),
#  (1, 'Not Parenting Focused'),
#  (2, 'No Flu Treatment Experience'),
#  (8, 'Home Care Treatment Options'),
#  (2, 'No Experience with Doctors'),
#  (4, 'Shortage of Flu Vaccine'),
#  (1, 'No Private Provider'),
#  (2, 'No Flu Experience'),
#  (9, 'Should be Automatic'),
#  (4, 'Anti-Vaccine Stereotype'),
#  (1, 'Uncomfortable Conversation'),
#  (8, 'Hard to Work with Medical Professionals'),
#  (4, 'Vaccine Hesitancy Leads to Questioning'),
#  (7, 'Frequently Ask Questions to GP'),
#  (4, 'Frequent Vaccinations with Child'),
#  (8, "Don't Feel You Should Blindly Follow Medical Professionals"),
#  (7, 'Open to Questioning'),
#  (4, 'All Vaccines'),
#  (8, 'Medical Professionals are not God'),
#  (1, 'Not a Blind Follower'),
#  (2, 'Specific Experience with GP'),
#  (7, 'GP Questioning and Guidance'),
#  (5, 'Disrespectful Communication'),
#  (9, 'Great GPs'),
#  (1, 'Not Spoken to Like Adult'),
#  (5, 'Participant Agrees to Audio-Visual Recording'),
#  (4, 'Reduction of Flu Exposure'),
#  (4, 'Flu Vaccine Benefit'),
#  (5, 'Benefits of Protection'),
#  (5, 'Benefit is Significant to Me'),
#  (4, 'Confidence and Long-Term Vaccines'),
#  (2, 'Negative GP Experiences Affected Future Interactions'),
#  (8, 'Avoids Contact with GP'),
#  (4, 'GP Use for Flu'),
#  (8, 'Discourages GP Discussion'),
#  (1, 'Non-Informative Non-Fluency'),
#  (4, 'Vaccinated'),
#  (5, 'Correct Reference'),
#  (0, 'Current Year'),
#  (5, 'Permission to Use Quotes Given'),
#  (7, 'Interview Consents'),
#  (3, 'Understood Statement on Data Collection'),
#  (4, 'Vaccine Delays'),
#  (4, 'Difficulties with Vaccine Consultation'),
#  (1, 'No GP Notification'),
#  (0, 'Rescheduled to Day Off'),
#  (0, 'Within 10 Days of Receiving'),
#  (9, 'GP Appointment'),
#  (5, 'Re-booking Appointments'),
#  (4, 'Vaccine Value'),
#  (9, 'Phone Records Available'),
#  (0, 'Late Vax'),
#  (5, 'Honest Statement'),
#  (1, 'Insufficient Info'),
#  (0, 'Remembered Late Season'),
#  (5, 'Wild Guess'),
#  (2, 'Uncertainty about Flu Season'),
#  (4, 'Vaccinations Given Previously'),
#  (1, 'Not a real decision'),
#  (5, 'Must Go Private for Chickenpox'),
#  (5, 'Financial Burden'),
#  (7, 'People Have Questions'),
#  (4, 'No Open Vaccinate'),
#  (3, 'Advantage of Family Resources Available'),
#  (1, 'No Personal Assistance'),
#  (1, "Some People Don't Have History"),
#  (3, 'Some Knowledge from Parents/History'),
#  (5, 'Less Fortunate Knowledge'),
#  (3, "Online 'Experts' for Information"),
#  (5, 'Easy Access to Social Support/Experts Online'),
#  (4, 'Concerns About Vaccines'),
#  (7, 'No Questions Allowed by Parents'),
#  (8, 'Patient Gratitude'),
#  (8, 'Filling Patient Role'),
#  (8, 'Patient Power Imbalance'),
#  (5, 'Ending Recording, Open Ended'),
#  (5, 'End Conversation'),
#  (5, 'Interest'),
#  (5, 'Positive Interest in Results'),
#  (5, 'Option to Receive Results'),
#  (1, 'No Need for Hard Copy'),
#  (3, 'Study Date'),
#  (6, 'Two Children'),
#  (5, 'Intro Consent Form '),
#  (5, 'Understanding Flexibility'),
#  (1, 'No Problem Expressed'),
#  (9, 'Email Correspondence'),
#  (3, 'Unknown Timeframe for End of Research'),
#  (3, 'Unknown Date for Findings to be Shared'),
#  (0, 'Study will End August'),
#  (3, 'Study Findings to Participant Email'),
#  (5, 'Positive Outlook'),
#  (5, 'Hard Copy Preference'),
#  (1, 'No Electronic Documents'),
#  (6, 'Son Four Years Old'),
#  (5, 'Lockdown as Juggling Act'),
#  (1, 'No Major Issues'),
#  (5, 'Need Entertainment'),
#  (6, 'Managing Work and Kids'),
#  (5, 'Concerned for Other Family Members'),
#  (8, 'Concerns for Elderly/Unhealthy'),
#  (4, 'Minimize Flu Risk'),
#  (8, 'Awareness of Symptoms'),
#  (2, 'Not a 100% Flu'),
#  (2, 'No Know Flu Experience'),
#  (8, 'Public Health Reporting'),
#  (9, 'Apologies'),
#  (9, 'N/A'),
#  (3, 'NHS website Primary Source'),
#  (6, 'Family'),
#  (5, 'Community Protection'),
#  (5, 'Broader Community Impact'),
#  (4, 'Supporting Flu Shot - Benefit to Health'),
#  (5, 'All for Screening'),
#  (5, 'Quick and Straightforwards Process'),
#  (0, 'Appointment Time Early Morning'),
#  (7, 'Participant Can Decline Questions'),
#  (4, 'No Rush in Getting Vaccine'),
#  (4, 'Vaccine Timing'),
#  (4, 'Vaccine Intentions'),
#  (6, 'Role Model for Child'),
#  (4, 'Children Vaccinated'),
#  (8, 'Primary Care as Promoters'),
#  (4, 'Flu Awareness and Increased Fear of Flu'),
#  (5, 'Frequent Hand Washing'),
#  (1, 'No Information on Hand Washing Benefits'),
#  (3, 'Grant Access to Data'),
#  (5, 'Confidentiality Okay'),
#  (7, 'Interview Participant Okay'),
#  (1, 'No Concerns'),
#  (5, 'Agreement (Positive)'),
#  (3, 'Participant agrees to take part in study'),
#  (5, 'Additional Screening Team Members'),
#  (3, 'Interested in Research Report'),
#  (9, 'Would Like Contact'),
#  (5, 'Interested in Sharing Results with Others'),
#  (5, 'Relevant in my role'),
#  (5, "Other's Role in project"),
#  (3, 'Screening Information'),
#  (5, 'Poor Internet Connection'),
#  (7, 'Connection Issues'),
#  (7, 'Unclear Response'),
#  (5, 'Read Informed Consent Sheet'),
#  (5, 'Technological Complications'),
#  (5, 'Participant_ID_4'),
#  (9, 'Automatic Notification'),
#  (0, 'Date on Screen'),
#  (1, 'Not Aware of Date'),
#  (7, 'Using Technology for Answers'),
#  (7, "Question: Today's Date"),
#  (7, 'Hardest Question'),
#  (0, 'Two, Five Years Old'),
#  (4, 'Children have Flu'),
#  (6, 'Has Two Children'),
#  (0, 'In School'),
#  (0, 'Second Year of School'),
#  (4, 'No Flu Vaccine This Season'),
#  (4, '5 Year Old Previously Had Vaccine'),
#  (4, 'Vaccine Decision Made Recently'),
#  (4, 'No Vaccine History'),
#  (4, 'Not Vaccinated for Measles, Mumps, Rubella'),
#  (1, 'No Name Given (Younger)'),
#  (6, 'Younger Child'),
#  (6, 'Has an Older Child'),
#  (5, 'Interested in technology like Roblox'),
#  (5, 'Struggles with Social Isolation during COVID-19'),
#  (5, 'Discovered Roblox'),
#  (9, 'Online Gaming'),
#  (0, 'Age'),
#  (9, 'Technology and Gaming'),
#  (5, 'Social Interaction'),
#  (9, 'Follows Structure'),
#  (9, 'Nintendo Switch Gift'),
#  (5, 'Consistent Behavior'),
#  (5, 'Fighting'),
#  (7, 'Right to Decline to Answer'),
#  (7, 'Intro: Interviewer Instructions'),
#  (5, 'Free to Withdraw'),
#  (7, 'Can Decline Questions'),
#  (6, "Child's Birthday"),
#  (5, 'Hard to Control'),
#  (5, 'Proper Wrestling'),
#  (1, 'No choice in the matter'),
#  (5, 'Wine as Coping Mechanism'),
#  (8, 'Self Care Strategies'),
#  (5, 'Alcohol Use as a Primary Strategy'),
#  (5, 'Blocked out Craziness'),
#  (6, 'Kids Are Funny'),
#  (6, "Parent's Coping Strategy"),
#  (5, 'Humorous Moment'),
#  (5, "Do What's Necessary"),
#  (4, 'Single Flu Case Survey'),
#  (1, 'No Expectations'),
#  (8, 'Symptoms'),
#  (8, 'Health Observation'),
#  (9, 'Communication via Speech'),
#  (8, 'Observing their Appearance - Sick'),
#  (3, 'Research Team Access'),
#  (5, 'Willing to Share'),
#  (6, 'Child Health is Primary Benefit'),
#  (3, 'Government Website Primary Source'),
#  (4, 'Not Offered Vaccine'),
#  (1, 'No Interest in Exploring'),
#  (6, 'Child is Two Years Old'),
#  (4, 'Accepted Flu Vaccine Option If Offered'),
#  (1, 'Not Asked Yet'),
#  (4, 'Up to Date Vaccinations'),
#  (5, 'Understand Recording'),
#  (5, 'Participant OK with Quotes'),
#  (1, 'Not Identified in Transcription'),
#  (3, 'Agreement with Participating in Study'),
#  (3, 'Request for Research Findings'),
#  (3, 'Willing to Receive Information'),
#  (9, 'Already have Written Information'),
#  (9, 'Study Forms via Email'),
#  (1, 'No Document Delivery'),
#  (1, 'No Hard Copy Request'),
#  (6, 'Younger Child is Three'),
#  (6, 'Two Children, Correct Age'),
#  (6, 'Parents confirm ages of children'),
#  (0, 'Started School Reception'),
#  (0, 'School Start Date (9/7/19)'),
#  (6, 'Child is in Reception'),
#  (0, 'Within the Cut Off Date'),
#  (5, 'Social Component of Schooling'),
#  (5, 'Isolation from Social Connections'),
#  (0, 'Homeschooling is Hard'),
#  (1, 'Unrespected As Teacher'),
#  (8, 'Challenging In Home Care'),
#  (6, 'Parents Challenge'),
#  (6, 'Child Wants To Play'),
#  (0, 'Challenge More than School'),
#  (6, 'Some Child Go Back'),
#  (5, 'Limited Return'),
#  (6, 'Nursery Closed'),
#  (6, 'Adult Children'),
#  (5, 'One Side Very Challenging, Other Very Rewarding'),
#  (5, 'Accepting of Situations'),
#  (1, 'Lack of Together Time in Non-Lockdown'),
#  (5, 'Positive Experiences'),
#  (5, 'Positives COVID Restrictions'),
#  (9, 'Laugh'),
#  (5, 'Positive Silver Lining'),
#  (8, 'Positive Emotion to Illness Experience'),
#  (5, 'Positive Outcome'),
#  (4, 'Flu a Good Family Uniter'),
#  (2, 'Flu Experience More Common in Adults'),
#  (4, 'Wiped out by Flu'),
#  (2, "Child's Flu Experience"),
#  (1, 'Not Taking Seriously'),
#  (8, 'Take Illness Seriously'),
#  (5, 'Confidentiality Agreement'),
#  (8, 'Good Health'),
#  (0, 'Now He is Fine'),
#  (5, 'Recovery'),
#  (6, 'Child Fine'),
#  (1, 'No Long-term Effects'),
#  (5, 'Concerned about Severity'),
#  (4, 'Serious About Flu'),
#  (5, 'Very Seriously Taken'),
#  (5, 'Took the Situation Seriously'),
#  (8, 'Pre-Hospital Precaution'),
#  (5, 'Prior Seriousness'),
#  (1, 'No Knowledge of Real Symptoms'),
#  (2, 'No Personal Experience with Child Flu'),
#  (2, 'No One I Know who Got Sick'),
#  (2, 'No Knowledge of Flu Illness in Family or Friends'),
#  (2, 'Has Experience with Fever'),
#  (2, 'No Contact with GP on Flu'),
#  (4, 'Receiving Information on Flu via Third Parties'),
#  (1, 'No Specific Consultation'),
#  (1, 'No Guarantee'),
#  (4, 'Flu Symptoms Lowered'),
#  (4, 'Vaccine not a guarantee of prevention'),
#  (8, 'Hope for Less Severe Illness'),
#  (4, 'Vaccine Effectiveness'),
#  (5, 'Participant Agreement (Signed)'),
#  (5, 'Optimistic'),
#  (5, 'Family wide Disruption'),
#  (4, 'Working Parent Struggles with Flu'),
#  (8, 'Sick Person Passing Illness'),
#  (4, 'Flu Risk'),
#  (1, 'Not Applicable to All'),
#  (6, 'Children Rely on Family for Sicknesses'),
#  (5, 'Senior Family Members Need Safety Net'),
#  (5, 'Reliance on Family is Reduced'),
#  (5, 'Overwhelming Benefits'),
#  (5, 'COVID-19 Benefits Outweigh Downsides'),
#  (3, 'Limited Online Searches'),
#  (5, 'Online Reading Concerns'),
#  (8, 'Consult Doctor with Concerns'),
#  (9, 'usually NHS'),
#  (6, 'Information Scares Parents'),
#  (4, 'Not about Flu Vaccine'),
#  (8, 'Spoke to Practice Nurse'),
#  (4, 'Positive Explanation of Vaccine'),
#  (5, 'Informed Decision'),
#  (1, 'GP not Consulted'),
#  (3, 'Standard Information Provided'),
#  (7, 'Limited Questions'),
#  (2, 'No Live Virus'),
#  (1, 'No Side Effects'),
#  (4, 'Vaccinations Made Available on Campus'),
#  (5, 'Participant consent for Quotations'),
#  (4, 'Vaccinate Appointment'),
#  (9, 'Booked by Phone'),
#  (0, 'October-November Season'),
#  (4, 'Received Vaccinations'),
#  (4, 'Yes Has Had Other Vaccinations'),
#  (7, 'Question on MMR'),
#  (8, 'MMR Autism Concerns'),
#  (4, 'Reaction to one vaccination out of all'),
#  (4, 'Vaccine Reservations'),
#  (4, 'Flu is 4 weeks ago'),
#  (0, 'Nearly Four'),
#  (4, 'Delayed Flu Vaccination'),
#  (4, 'Flu History'),
#  (6, "Child's Illnesses Not a Concern"),
#  (2, 'Most Recent Flu Experience'),
#  (6, 'Child is Nearly Four Years Old'),
#  (6, 'Talking With Parents'),
#  (5, 'Low Risks'),
#  (4, 'Immunity'),
#  (5, 'Benefits outweigh Risks'),
#  (8, 'Measles Circulating Worry'),
#  (4, 'Vaccination-Great'),
#  (4, 'Have you had vaccine?'),
#  (9, 'Have I had it?'),
#  (4, 'Taken Vaccine at Pharmacist'),
#  (5, 'Prior Experience'),
#  (2, 'Flu Experiences'),
#  (2, 'John Never Got Flu'),
#  (5, 'More Proactive'),
#  (5, 'Personal and Family Protection'),
#  (5, 'Interesting Observation'),
#  (5, 'Self Protection'),
#  (2, 'No Flu Experience'),
#  (5, 'Personal Proactivity'),
#  (4, 'Flu Shot'),
#  (6, 'All children should receive nasal spray'),
#  (4, 'Vaccine Distribution Methods'),
#  (1, 'No Interest in Learning More'),
#  (4, 'Vaccine Delivery Method'),
#  (5, 'Government Guidelines Followed'),
#  (6, 'Nasal Spray Recommended for School Age Children'),
#  (3, 'NHS Website Primary Source'),
#  (2, 'No Flu Experience'),
#  (9, 'Blank Line'),
#  (5, 'Other'),
#  (3, 'NHS Website as Primary Source (1 instance)'),
#  (4, 'Only Curious About Difference in Vaccine Types (1 instance)'),
#  (1, 'No Further Inquiry'),
#  (9, '<BLANK>'),
#  (4, 'Vaccines'),
#  (3, 'Limited Knowledge About Types'),
#  (5, 'Curious Point'),
#  (9, '<BLANK>'),
#  (1, "Didn't Ask Doctor"),
#  (8, 'Different Instructions for the Same Illness'),
#  (7, 'Questions of Nurse'),
#  (5, 'Interested in Results'),
#  (3, 'Study Overview'),
#  (9, 'Send to Email'),
#  (9, 'Send Information about Labelling'),
#  (9, 'Survey Emails Sent at the End of August'),
#  (5, 'Participant Thanks.'),
#  (5, 'Will Return Results'),
#  (3, 'Study Completion Date'),
#  (9, 'Preference to Email'),
#  (9, 'Use of Email for Communication'),
#  (6, "Children's Names Requested"),
#  (5, 'Full Names'),
#  (7, 'Interview Terms Accepted'),
#  (6, "Child's Age"),
#  (6, 'My Child'),
#  (6, 'Other Child'),
#  (9, '2 Y'),
#  (0, '2 Years Old'),
#  (6, 'Child_Ages_2_Yrs_3_mths_5_Yrs'),
#  (2, 'No Child Flu Experience'),
#  (6, 'Child in Reception'),
#  (0, 'Year-old is Going to School'),
#  (0, '5 Year Old'),
#  (0, 'Current Grade'),
#  (1, 'No Other Comment'),
#  (5, 'Should Be in Reception'),
#  (9, 'Grey Area'),
#  (1, 'Happy with Non-Screen Time'),
#  (1, 'No Early Morning Television'),
#  (5, 'Create Universe Roleplay'),
#  (8, 'Can Be Quite Bad'),
#  (8, 'Family Members Respiratory Illnesses'),
#  (4, 'Concerned about Child Getting Flu'),
#  (2, 'No Flu Experience'),
#  (2, 'No Flu-related Illnesses in Family'),
#  (3, 'NHS Website Primary Source'),
#  (5, "I'm Antiscial Person"),
#  (4, 'Seeking Info About Flu Symptoms'),
#  (3, 'Information Source'),
#  (8, 'Health Service Preference'),
#  (7, "I don't know which response to give"),
#  (9, '111 Service Use'),
#  (4, 'Talked with Medical Professional for Flu Vaccine'),
#  (8, 'Spoke to GP for Other Health Issues'),
#  (9, 'Spoke to GP in Fall'),
#  (2, 'Not about Flu'),
#  (8, 'Severe Allergic History'),
#  (8, 'Specific Allergies to Egg and Milk'),
#  (8, 'Sons Egg Allergy'),
#  (5, "Consult Team's Professional Opinion"),
#  (5, 'Two Reasons'),
#  (6, 'Prevent Child Getting Sick and Protect Others'),
#  (5, 'Previously Thought About'),
#  (4, 'Always Vaccinated'),
#  (1, 'No Understanding of Refusals'),
#  (9, 'Audio Recording'),
#  (5, 'Remove Personal Details'),
#  (4, 'Convenience for Vaccine'),
#  (9, 'Organization'),
#  (1, 'No Cost'),
#  (4, 'Allergy form prompted vaccine inquiry'),
#  (4, 'Vaccine and Egg Allergies Connection'),
#  (9, 'GP Sent Medical Form'),
#  (9, 'Invitation from GP'),
#  (4, "Child's Flu Vaccine at School"),
#  (4, 'Current Flu Season'),
#  (0, 'Before Christmas Time'),
#  (4, 'Daughter not yet Vaccinated'),
#  (0, 'Form to Fill for School'),
#  (4, 'Vaccine Intent'),
#  (0, 'Uncertain Month'),
#  (0, 'Possible Timeline - Might Be'),
#  (1, 'No Specific Time'),
#  (0, 'Unknown Season'),
#  (0, 'Possibly Early'),
#  (0, 'Around November'),
#  (0, 'Starting School in October'),
#  (1, 'Uncertain Date'),
#  (4, 'Routine and Childhood Vaccinations'),
#  (4, 'Always Going to Vaccinate'),
#  (6, 'Child Suffering'),
#  (1, 'No Suffering'),
#  (4, 'Flu Vaccine'),
#  (7, 'Interview Understanding'),
#  (4, 'Work Offered Flu Jabs'),
#  (4, 'Vaccinations Offered at Pharmacies'),
#  (5, 'Boots Partnership'),
#  (4, 'Employer Provides Vaccine for no Cost'),
#  (7, 'Close Question'),
#  (8, 'Allergies as a Concern'),
#  (5, 'Outdated Advice'),
#  (3, 'Would Like Research Findings'),
#  (9, 'Request Written Report'),
#  (3, 'End of Study'),
#  (5, 'Final Project Report'),
#  (9, 'E-mail Preferred'),
#  (9, 'Email'),
#  (9, 'Send Documents'),
#  (9, 'Thank You'),
#  (9, 'Confirming Email as Follow-Up'),
#  (6, 'Has Two Children'),
#  (7, 'Positive Response'),
#  (3, 'Participant Agrees to Share Data'),
#  (5, 'Interested'),
#  (9, 'Allow to Email'),
#  (1, "Not Worried or Worried but don't Want"),
#  (1, 'Something not thinking about'),
#  (5, 'Desire Knowledge to Act'),
#  (4, 'Worried About the Flu'),
#  (8, 'Worry Exists but Concern Is Reasonable'),
#  (2, 'No Expectation of Flu Experience'),
#  (4, 'Common Flu Symptoms'),
#  (2, 'Flu Impact on Children vs Adults Unknown'),
#  (5, 'Concerns in Back of the Mind'),
#  (1, 'Uncertain Risk Assessment'),
#  (4, 'Conscious of Flu'),
#  (1, 'Unknown Close Social Network'),
#  (1, 'No Family or Friends Illness'),
#  (2, 'No Social Flu Experience'),
#  (2, 'No-one with Child Affected by Flu'),
#  (9, 'NHS Website'),
#  (3, 'Trusted Source Required'),
#  (8, 'Confidence in NHS Information'),
#  (3, 'Limited Info'),
#  (9, 'Only the NHS Website'),
#  (5, 'Confident in Accuracy'),
#  (2, 'No Medical Professional Contact for Flu'),
#  (2, 'Talked to GP not specifically about the Flu'),
#  (1, 'Not Spoken to Anyone Professionally'),
#  (8, 'Improves Health'),
#  (8, 'Reduces Risk of Severe Illness'),
#  (5, 'Easy Decision'),
#  (5, 'Reduces Severity'),
#  (1, 'No Concern about Others'),
#  (8, 'Health Concern Primary Motivator'),
#  (5, 'Measles Comparison as Example'),
#  (1, 'Not deeply considered by parent'),
#  (4, 'Vaccination Necessary with Seriousness'),
#  (1, 'No Address Required'),
#  (1, 'No Hard Copy Needed'),
#  (9, 'Willing to Receive Physical Mailing'),
#  (3, 'Offer Mailed Study Materials'),
#  (9, 'GP and NHS Informed Decision'),
#  (8, 'No Medical History to Justify'),
#  (4, 'NHS Advised Vaccination'),
#  (7, 'Ask GP'),
#  (8, 'Trust GP/NHS Opinion'),
#  (9, 'GP Recommendations Accepted'),
#  (1, 'No Further Research'),
#  (1, 'No Additional Information Sought'),
#  (1, 'No Active Learning'),
#  (3, 'Information Sources'),
#  (1, 'No Additional Information needed if in a schedule'),
#  (9, 'Follow GP Recommendations'),
#  (8, 'Trust In Medical Experts'),
#  (6, 'Trusting Parents'),
#  (0, 'Minimal Downtime'),
#  (1, 'No Reported Symptoms'),
#  (1, 'No After Effects'),
#  (1, 'No Further Concern'),
#  (4, 'Vaccine Advantages'),
#  (9, 'Notification through Post then Call to Book'),
#  (9, 'GP Contacted via Phone Call'),
#  (5, 'Appointment Scheduled'),
#  (5, 'Successful Process'),
#  (4, 'Requested Vaccination'),
#  (5, 'Promptly Booked'),
#  (0, 'Same Day'),
#  (5, 'Neutral'),
#  (5, 'More or Less Straight Away'),
#  (0, 'Early in Day Contact'),
#  (8, 'Faith in Medical Professionals'),
#  (6, 'Have One Child'),
#  (6, 'Number of Children'),
#  (4, 'Fully Vaccinated'),
#  (4, 'Up to Date with Vaccinations'),
#  (5, 'Foregone Decision'),
#  (5, 'Checked with Father'),
#  (4, 'Vaccinations were Routine'),
#  (4, 'Social Pressure to Vaccinate'),
#  (6, 'Recommended for Kids'),
#  (8, 'Recommended by Medical Professionals'),
#  (9, 'Go Ahead and Do It'),
#  (5, 'Social Norms'),
#  (5, 'Default Acceptance of Recommendations'),
#  (4, 'Flu Vaccination Suggested Protocol'),
#  (8, 'Scared By Needle'),
#  (4, 'Vaccine Anxiety Reassurance'),
#  (5, 'Direct Observation of Procedure'),
#  (6, 'Procedure Terrified Child'),
#  (5, 'Parent Describes Incident'),
#  (6, 'Needle in Front of Child'),
#  (5, 'Nice to be Out For Family'),
#  (4, "Child's Vaccination Information Received"),
#  (5, 'Nasal Spray'),
#  (1, 'any injections'),
#  (1, 'No preference or care'),
#  (9, 'N/A'),
#  (8, 'Could have been more Freaked Out About an Injection'),
#  (5, 'Still willing to do an Injection'),
#  (8, 'Somewhat Worse Symptoms'),
#  (8, 'Pain is Unpleasant'),
#  (5, 'Quick Recovery'),
#  (1, 'No Memory of Shot'),
#  (1, 'No Further Remarks'),
#  (8, 'Mother as Nurse'),
#  (5, 'Trust in Institution'),
#  (8, 'Nurse Experience Growing up'),
#  (1, 'No More Information'),
#  (8, 'Familiarity with Medical Institutions'),
#  (2, 'Asthma as Experience'),
#  (8, 'Response Indicating Belief in Medicine'),
#  (8, 'Informed by Nursing Parents'),
#  (8, 'Open to Medicine'),
#  (6, 'Child Name and Age'),
#  (6, 'Male Child'),
#  (0, 'Premature Birth'),
#  (1, 'No Longer Effects'),
#  (8, 'Prematurity Impact on health'),
#  (5, 'Faith'),
#  (2, 'No Experiences with No Faith'),
#  (6, 'Child at Home from Beginning of Covid'),
#  (7, 'Answer Verification'),
#  (7, 'Yes in Response to Question'),
#  (6, 'Only child'),
#  (5, 'Has Been Interesting'),
#  (5, 'Has Coped Well'),
#  (1, 'No Social Interaction'),
#  (5, 'Needs to Be Around Others'),
#  (6, "Importance of Child's Social Interaction"),
#  (6, "Younger Children's Adjustment to Change"),
#  (6, 'Parents Adapting Harder than Child'),
#  (4, 'View of the Flu - Severe Illness'),
#  (4, 'Flu Should Not Be Taken Lightly'),
#  (1, 'No Worries'),
#  (4, 'Low Flu Probability'),
#  (4, 'Flu Occurs Annually'),
#  (5, 'Read Statements'),
#  (7, 'Intro: Read Statements and Answer Yes or No'),
#  (7, 'Confirmed Interview Information'),
#  (0, 'Coming Up To Two and a Half'),
#  (0, 'Age: 2-2 ½'),
#  (6, 'Part Time Nursery'),
#  (0, 'Birth Date: January 2018'),
#  (6, 'Hours at Daycare Center'),
#  (0, 'Loves to be at school'),
#  (8, 'Limited Contact with Health Visitor'),
#  (6, 'Children Loving Day Care'),
#  (8, 'Dynamic Shift after Day Care'),
#  (6, 'Loves Other Children'),
#  (5, 'Social Interaction'),
#  (6, 'Enjoys Being Around Children'),
#  (5, 'Enjoys Others'),
#  (1, 'Not relevant to theme'),
#  (6, 'Child is Only Child'),
#  (9, "He's a"),
#  (6, "Asked child's Name"),
#  (5, 'Encouragement for Honesty'),
#  (7, 'Questioning the Answer'),
#  (5, 'High Temperature'),
#  (8, 'Crying when Sick'),
#  (5, 'Flushed Face'),
#  (5, 'Acknowledged Voluntary Participation Policy'),
#  (5, 'Visual Perception'),
#  (8, 'Reading Symptoms'),
#  (5, 'External Environment'),
#  (6, "Reading Child's Health Issues"),
#  (5, 'Observing Physical Changes'),
#  (1, 'Lack of Knowledge'),
#  (1, 'Not Considered'),
#  (2, 'No Flu Experience'),
#  (0, 'Birthday in January'),
#  (1, 'Missed the Cutoff'),
#  (4, 'Flu Shot Eligibility Unclear'),
#  (0, 'Cutoff Age'),
#  (6, 'Close to Kindergarten Cutoff'),
#  (8, 'Quick Sickness Peak'),
#  (3, 'Need Research'),
#  (2, 'No Child Flu History'),
#  (2, 'No Knowledge of Others with Flu'),
#  (3, 'Internet and NHS website as primary source'),
#  (3, 'Sometimes Other Sources Used'),
#  (3, 'Charities as Secondary Information Source'),
#  (9, 'Charities Websites'),
#  (3, 'Not All Sources of Info are Equal'),
#  (8, 'Info for Other Illness/Disease'),
#  (3, 'Online Information as Useful'),
#  (1, 'Not Contacted Doctor'),
#  (1, 'No GP Interaction'),
#  (2, 'Never Talked to a GP about the Flu'),
#  (2, 'Child Not Sick with Flu'),
#  (8, 'Reduces Chance of Illness'),
#  (5, 'Reduces Community Impact'),
#  (4, 'Protective Against Flu'),
#  (4, 'Less Likely to Get Flu'),
#  (5, 'Protective of Others'),
#  (5, 'Reduction in Transmission'),
#  (5, 'Benefits to Others'),
#  (3, 'Allow Access for Researcher'),
#  (1, 'Protective Benefit Not Thought About'),
#  (8, 'Measles Outbreak Concern'),
#  (4, 'Thought about Measles, but not Flu'),
#  (5, 'History with Measles Outbreaks'),
#  (1, 'No Scientific Evidence'),
#  (4, 'Vaccines In General'),
#  (5, 'Vacine Indifference'),
#  (5, 'Side Effects'),
#  (1, 'Fear of Inaccurate Information'),
#  (1, 'Information Not Useful'),
#  (2, "Not Impacted by Other's Experiences"),
#  (4, 'Flu Vaccine Experience'),
#  (5, 'Friends Negative Experiences'),
#  (4, 'Refused the flu vaccine this year'),
#  (8, 'Anti-tryptic Deficiency'),
#  (2, 'Previous Flu Vaccine Experience'),
#  (1, "Thinking he's Ineligible"),
#  (4, 'Not Eligible for Vaccine'),
#  (4, 'Vaccine Information Research'),
#  (5, 'National Antenatal Charity'),
#  (5, 'Shared with Others'),
#  (7, 'Yes Response to Sharing'),
#  (0, 'Same Age'),
#  (6, 'No Other Children'),
#  (0, 'First Born'),
#  (0, "Same as Current Child's Birthdate"),
#  (0, 'Born in 2018'),
#  (5, 'I Considered but Rebuffed'),
#  (1, 'Consider Not Recommended by NHS'),
#  (1, "Didn't Look it Up"),
#  (4, 'Increased Worry for Infections'),
#  (1, 'Does not Worry'),
#  (5, 'Increased Awareness of Riskiness'),
#  (8, 'Benefits of Avoiding Illnesses'),
#  (6, 'Parent Avoidance of Sick Children'),
#  (4, 'Has Child Vaccinated'),
#  (4, 'Required vaccinations'),
#  (5, 'Wonderful Technology'),
#  (1, 'Not a Conversation'),
#  (5, 'Spouse Profession'),
#  (4, 'No Disadvantage to Immunizations'),
#  (4, 'General Belief About Vaccination'),
#  (1, 'No Consequences of Unnecessary Injection'),
#  (9, "It's a Quick and Easy Process"),
#  (4, 'Flu Vaccine Positive Reason: No Harm'),
#  (4, 'Not Flu Vaccinated'),
#  (9, 'Indirect Contact'),
#  (7, 'Interview Consent'),
#  (1, 'Not on Eligibility List'),
#  (1, 'Not High Risk Status'),
#  (1, 'Not Consideration'),
#  (4, 'Not Eligible for Flu Vaccine'),
#  (4, 'Flu While Pregnant'),
#  (5, 'Personal Experience '),
#  (2, 'Participants Experienced Flu'),
#  (4, 'Used GP to get Flu Vaccine because of High-Risk Group'),
#  (9, 'Availble from GP'),
#  (1, 'Not Interested in Private Payment'),
#  (4, 'Past Employer Had Flu Shot Paid For'),
#  (1, 'Not a Personal Priority'),
#  (1, 'Costing No Concern'),
#  (1, 'Not a High Risk Illness'),
#  (1, 'No Admin Needed'),
#  (4, 'Costs to Vaccinate'),
#  (5, 'Validated Cost-Benefit Trade-Off'),
#  (5, 'Cost and Benefit'),
#  (3, 'Seek out more information'),
#  (4, 'Flu Risk Factors'),
#  (9, 'NHS website is good for start'),
#  (3, 'Used NHS to Start Research'),
#  (3, 'Quotations Can be Used in Research'),
#  (5, 'Receiving Summary'),
#  (7, 'Last Interview Question'),
#  (3, 'Research Summary Information'),
#  (5, 'Interested to Read Final Findings'),
#  (3, 'Participant Consent to Receive Research Findings'),
#  (9, 'Follow-up Email Optional'),
#  (1, 'No Paper Copy'),
#  (6, '4 children'),
#  (6, 'Number of Children Verified'),
#  (5, 'Identical Twins'),
#  (3, 'Incorrectly Inferred Info'),
#  (0, '2nd Set of Twins in Home'),
#  (5, 'Siblings Are Available'),
#  (5, 'Good for Gardens'),
#  (5, 'Large garden required'),
#  (8, 'General symptoms'),
#  (8, 'Tiredness and grumpiness'),
#  (5, 'Activity change'),
#  (8, 'Appears Sick'),
#  (1, 'Lack of Will'),
#  (8, 'Limited Concern with Symptoms'),
#  (4, 'Limited Fear of Flu'),
#  (8, 'Hospitalisation Only Major Concern'),
#  (2, 'Worried or Not Worried with Flu Illness'),
#  (1, "Majority wouldn't be serious."),
#  (8, 'Most would be 1 week of illness'),
#  (8, 'More serious could result in hospitalization'),
#  (2, 'No Flu Experience'),
#  (2, 'Do Not Know of other Children with Flu'),
#  (6, 'Has No Children'),
#  (9, 'Go to NHS UK Website'),
#  (3, 'Other Resources'),
#  (3, 'CDC Resources'),
#  (9, 'NHS - Authority'),
#  (3, 'Primary Information Source is NHS'),
#  (3, 'Check CDC Website In America'),
#  (3, 'Check WHO Website'),
#  (5, 'Participant Understands Rights'),
#  (3, 'Multiple Sources used for Knowledge'),
#  (1, 'Symptoms not Always Listed on Single Source'),
#  (8, 'Symptoms Hidden or Buried'),
#  (3, 'General Approach to Information'),
#  (3, 'More Thorough Website Searches'),
#  (8, 'List of Symptoms'),
#  (8, 'General Approach To Search For Symptoms'),
#  (8, 'Medical Professionals for Self'),
#  (2, 'Never talk about flu in children'),
#  (2, 'No Experience'),
#  (4, 'Had the Flu'),
#  (8, 'Illness'),
#  (4, 'Vaccine Low Risk'),
#  (5, 'Main Benefit'),
#  (8, 'Avoid Getting Sick'),
#  (4, 'Vaccination Benefits'),
#  ...]

# %%
ret_arr = [[] for _ in range(10)]

for sect, sent in zip(kmeans.labels_, all_codes):
    ret_arr[sect].append(sent)

# %%
i=0
for sect in ret_arr:
    print(i, sect)
    i+=1
# Out:
# 0 ['Current Residence since 1997', 'Five and Two Years of Age', 'Start of School Year', 'Started Last September', 'Time to Settle', 'Received spray this year', 'Limited Time Frame', 'Possible to get in future', 'Study End Date', 'Complete Now', 'Accelerated Aging', 'Greying Over Time', 'Entry to Reception in September', 'She was in school nursery', "She's going to be the oldest", 'in school, but not in school yet', 'School Closing', 'Week to 10 days', 'Current Year', 'Rescheduled to Day Off', 'Within 10 Days of Receiving', 'Late Vax', 'Remembered Late Season', 'Study will End August', 'Appointment Time Early Morning', 'Date on Screen', 'Two, Five Years Old', 'In School', 'Second Year of School', 'Age', 'Started School Reception', 'School Start Date (9/7/19)', 'Within the Cut Off Date', 'Homeschooling is Hard', 'Challenge More than School', 'Now He is Fine', 'October-November Season', 'Nearly Four', '2 Years Old', 'Year-old is Going to School', '5 Year Old', 'Current Grade', 'Before Christmas Time', 'Form to Fill for School', 'Uncertain Month', 'Possible Timeline - Might Be', 'Unknown Season', 'Possibly Early', 'Around November', 'Starting School in October', 'Minimal Downtime', 'Same Day', 'Early in Day Contact', 'Premature Birth', 'Coming Up To Two and a Half', 'Age: 2-2 ½', 'Birth Date: January 2018', 'Loves to be at school', 'Birthday in January', 'Cutoff Age', 'Same Age', 'First Born', "Same as Current Child's Birthdate", 'Born in 2018', '2nd Set of Twins in Home', 'Last Year', 'Back end of 2019', 'Autumn of 2019', 'Up to Date']
# 1 ['No Schoolwork', 'Nice to have but not necessary', 'Usually No Shot', 'Unable to Recall', 'Did Not Attend Clinic', 'Unable to Make Event', 'No Problems', 'Inability to Identify Cause', 'Not Thought about Benefits Before', 'Not Given Thought', 'No Side Effects', 'No Thought', 'Nothing to Add', "Experts aren't Needed", 'No Availability: Time', 'No Further Information Provided', 'Nursery but Not Reception', 'No Kindergarten', 'No Begging Work', 'Try Nothing of Value to Influence', 'Missing social aspect', 'Missing Friends', 'No Concerns', "No to be fair I don't actually... I'm just trying to think. No.", 'Concerned about Unspecific Internet Accuracy', 'Not Parenting Focused', 'No Private Provider', 'Uncomfortable Conversation', 'Not a Blind Follower', 'Not Spoken to Like Adult', 'Non-Informative Non-Fluency', 'No GP Notification', 'Insufficient Info', 'Not a real decision', 'No Personal Assistance', "Some People Don't Have History", 'No Need for Hard Copy', 'No Problem Expressed', 'No Electronic Documents', 'No Major Issues', 'No Information on Hand Washing Benefits', 'No Concerns', 'Not Aware of Date', 'No Name Given (Younger)', 'No choice in the matter', 'No Expectations', 'No Interest in Exploring', 'Not Asked Yet', 'Not Identified in Transcription', 'No Document Delivery', 'No Hard Copy Request', 'Unrespected As Teacher', 'Lack of Together Time in Non-Lockdown', 'Not Taking Seriously', 'No Long-term Effects', 'No Knowledge of Real Symptoms', 'No Specific Consultation', 'No Guarantee', 'Not Applicable to All', 'GP not Consulted', 'No Side Effects', 'No Interest in Learning More', 'No Further Inquiry', "Didn't Ask Doctor", 'No Other Comment', 'Happy with Non-Screen Time', 'No Early Morning Television', 'No Understanding of Refusals', 'No Cost', 'No Specific Time', 'Uncertain Date', 'No Suffering', "Not Worried or Worried but don't Want", 'Something not thinking about', 'Uncertain Risk Assessment', 'Unknown Close Social Network', 'No Family or Friends Illness', 'Not Spoken to Anyone Professionally', 'No Concern about Others', 'Not deeply considered by parent', 'No Address Required', 'No Hard Copy Needed', 'No Further Research', 'No Additional Information Sought', 'No Active Learning', 'No Additional Information needed if in a schedule', 'No Reported Symptoms', 'No After Effects', 'No Further Concern', 'any injections', 'No preference or care', 'No Memory of Shot', 'No Further Remarks', 'No More Information', 'No Longer Effects', 'No Social Interaction', 'No Worries', 'Not relevant to theme', 'Lack of Knowledge', 'Not Considered', 'Missed the Cutoff', 'Not Contacted Doctor', 'No GP Interaction', 'Protective Benefit Not Thought About', 'No Scientific Evidence', 'Fear of Inaccurate Information', 'Information Not Useful', "Thinking he's Ineligible", 'Consider Not Recommended by NHS', "Didn't Look it Up", 'Does not Worry', 'Not a Conversation', 'No Consequences of Unnecessary Injection', 'Not on Eligibility List', 'Not High Risk Status', 'Not Consideration', 'Not Interested in Private Payment', 'Not a Personal Priority', 'Costing No Concern', 'Not a High Risk Illness', 'No Admin Needed', 'No Paper Copy', 'Lack of Will', "Majority wouldn't be serious.", 'Symptoms not Always Listed on Single Source', 'No Downside in UK', 'Free, No Inconvenience', 'Nasal Spray Only', 'No Concerns', 'No Challenges', 'No Personal Info on Video']
# 2 ['Do Not Have Flu Experience', "Can't Comment on Experience", 'General Cold/Flu Experience for Adults', 'Previous Experience with Flu', 'Flu Not Seen as Sinister', 'No Flu Experience', 'Flu Not Top of Mind', 'No Grey Hair Experience', 'No Past Illness Experience', 'No Kindergarten Experience', 'Multiple Children, No Knowledge of Flu', 'No Flu Treatment Experience', 'No Experience with Doctors', 'No Flu Experience', 'Specific Experience with GP', 'Negative GP Experiences Affected Future Interactions', 'Uncertainty about Flu Season', 'Not a 100% Flu', 'No Know Flu Experience', 'Flu Experience More Common in Adults', "Child's Flu Experience", 'No Personal Experience with Child Flu', 'No One I Know who Got Sick', 'No Knowledge of Flu Illness in Family or Friends', 'Has Experience with Fever', 'No Contact with GP on Flu', 'No Live Virus', 'Most Recent Flu Experience', 'Flu Experiences', 'John Never Got Flu', 'No Flu Experience', 'No Flu Experience', 'No Child Flu Experience', 'No Flu Experience', 'No Flu-related Illnesses in Family', 'Not about Flu', 'No Expectation of Flu Experience', 'Flu Impact on Children vs Adults Unknown', 'No Social Flu Experience', 'No-one with Child Affected by Flu', 'No Medical Professional Contact for Flu', 'Talked to GP not specifically about the Flu', 'Asthma as Experience', 'No Experiences with No Faith', 'No Flu Experience', 'No Child Flu History', 'No Knowledge of Others with Flu', 'Never Talked to a GP about the Flu', 'Child Not Sick with Flu', "Not Impacted by Other's Experiences", 'Previous Flu Vaccine Experience', 'Participants Experienced Flu', 'Worried or Not Worried with Flu Illness', 'No Flu Experience', 'Do Not Know of other Children with Flu', 'Never talk about flu in children', 'No Experience', 'Partner at Sea When FluShot Given']
# 3 ['Research in Dr. Google', 'Use of Resources', 'Information Collected', 'Data Access - Study Research', 'Limited to Low-Risk Info', 'NHS Website Primary Source', 'Information from Health Education', 'GP as Information Source', 'Contact for Additional Information', 'Granted Data Access', 'Researcher Access', 'Confidence in Researcher', 'Avoid Unverified Information Sources', 'Incorrect Information Available', 'Understood Statement on Data Collection', 'Advantage of Family Resources Available', 'Some Knowledge from Parents/History', "Online 'Experts' for Information", 'Study Date', 'Unknown Timeframe for End of Research', 'Unknown Date for Findings to be Shared', 'Study Findings to Participant Email', 'NHS website Primary Source', 'Grant Access to Data', 'Participant agrees to take part in study', 'Interested in Research Report', 'Screening Information', 'Research Team Access', 'Government Website Primary Source', 'Agreement with Participating in Study', 'Request for Research Findings', 'Willing to Receive Information', 'Limited Online Searches', 'Standard Information Provided', 'NHS Website Primary Source', 'NHS Website as Primary Source (1 instance)', 'Limited Knowledge About Types', 'Study Overview', 'Study Completion Date', 'NHS Website Primary Source', 'Information Source', 'Would Like Research Findings', 'End of Study', 'Participant Agrees to Share Data', 'Trusted Source Required', 'Limited Info', 'Offer Mailed Study Materials', 'Information Sources', 'Need Research', 'Internet and NHS website as primary source', 'Sometimes Other Sources Used', 'Charities as Secondary Information Source', 'Not All Sources of Info are Equal', 'Online Information as Useful', 'Allow Access for Researcher', 'Seek out more information', 'Used NHS to Start Research', 'Quotations Can be Used in Research', 'Research Summary Information', 'Participant Consent to Receive Research Findings', 'Incorrectly Inferred Info', 'Other Resources', 'CDC Resources', 'Primary Information Source is NHS', 'Check CDC Website In America', 'Check WHO Website', 'Multiple Sources used for Knowledge', 'General Approach to Information', 'More Thorough Website Searches', 'WHO as Source', 'Create Own Search URL', 'Agency website as secondary resource', 'Agree Information Use', 'Background Medical Research', 'Wife is Research Scientist', "Wife's Research Trusted", 'Seeking Out Information', 'Research Scientist', 'In Study']
# 4 ["Dad's Flu Symptoms More Tolerable", 'Tried to get Flu Vaccine', 'Get Flu Shots for Kids', 'Received the Flu Vaccine', 'Missed Vaccination Window', 'Negligence with Flu Vaccine', 'Vaccine Protection', 'Flu as Generally Accepted', 'No Flu Vaccine', 'Yes Vaccines Given', 'Standard Childhood Vaccines', 'Nurses and Doctors Give Flu Shots', 'Does Not Prioritize Vaccination', 'Flu as Just Something to Face', 'Encourages Thoughts on Flu', 'Want someone to say I have a flu', 'Flu a Combination of Cold and Flu Symptoms', 'Flu Symptoms as Illnesses', 'Shortage of Flu Vaccine', 'Anti-Vaccine Stereotype', 'Vaccine Hesitancy Leads to Questioning', 'Frequent Vaccinations with Child', 'All Vaccines', 'Reduction of Flu Exposure', 'Flu Vaccine Benefit', 'Confidence and Long-Term Vaccines', 'GP Use for Flu', 'Vaccinated', 'Vaccine Delays', 'Difficulties with Vaccine Consultation', 'Vaccine Value', 'Vaccinations Given Previously', 'No Open Vaccinate', 'Concerns About Vaccines', 'Minimize Flu Risk', 'Supporting Flu Shot - Benefit to Health', 'No Rush in Getting Vaccine', 'Vaccine Timing', 'Vaccine Intentions', 'Children Vaccinated', 'Flu Awareness and Increased Fear of Flu', 'Children have Flu', 'No Flu Vaccine This Season', '5 Year Old Previously Had Vaccine', 'Vaccine Decision Made Recently', 'No Vaccine History', 'Not Vaccinated for Measles, Mumps, Rubella', 'Single Flu Case Survey', 'Not Offered Vaccine', 'Accepted Flu Vaccine Option If Offered', 'Up to Date Vaccinations', 'Flu a Good Family Uniter', 'Wiped out by Flu', 'Serious About Flu', 'Receiving Information on Flu via Third Parties', 'Flu Symptoms Lowered', 'Vaccine not a guarantee of prevention', 'Vaccine Effectiveness', 'Working Parent Struggles with Flu', 'Flu Risk', 'Not about Flu Vaccine', 'Positive Explanation of Vaccine', 'Vaccinations Made Available on Campus', 'Vaccinate Appointment', 'Received Vaccinations', 'Yes Has Had Other Vaccinations', 'Reaction to one vaccination out of all', 'Vaccine Reservations', 'Flu is 4 weeks ago', 'Delayed Flu Vaccination', 'Flu History', 'Immunity', 'Vaccination-Great', 'Have you had vaccine?', 'Taken Vaccine at Pharmacist', 'Flu Shot', 'Vaccine Distribution Methods', 'Vaccine Delivery Method', 'Only Curious About Difference in Vaccine Types (1 instance)', 'Vaccines', 'Concerned about Child Getting Flu', 'Seeking Info About Flu Symptoms', 'Talked with Medical Professional for Flu Vaccine', 'Always Vaccinated', 'Convenience for Vaccine', 'Allergy form prompted vaccine inquiry', 'Vaccine and Egg Allergies Connection', "Child's Flu Vaccine at School", 'Current Flu Season', 'Daughter not yet Vaccinated', 'Vaccine Intent', 'Routine and Childhood Vaccinations', 'Always Going to Vaccinate', 'Flu Vaccine', 'Work Offered Flu Jabs', 'Vaccinations Offered at Pharmacies', 'Employer Provides Vaccine for no Cost', 'Worried About the Flu', 'Common Flu Symptoms', 'Conscious of Flu', 'Vaccination Necessary with Seriousness', 'NHS Advised Vaccination', 'Vaccine Advantages', 'Requested Vaccination', 'Fully Vaccinated', 'Up to Date with Vaccinations', 'Vaccinations were Routine', 'Social Pressure to Vaccinate', 'Flu Vaccination Suggested Protocol', 'Vaccine Anxiety Reassurance', "Child's Vaccination Information Received", 'View of the Flu - Severe Illness', 'Flu Should Not Be Taken Lightly', 'Low Flu Probability', 'Flu Occurs Annually', 'Flu Shot Eligibility Unclear', 'Protective Against Flu', 'Less Likely to Get Flu', 'Thought about Measles, but not Flu', 'Vaccines In General', 'Flu Vaccine Experience', 'Refused the flu vaccine this year', 'Not Eligible for Vaccine', 'Vaccine Information Research', 'Increased Worry for Infections', 'Has Child Vaccinated', 'Required vaccinations', 'No Disadvantage to Immunizations', 'General Belief About Vaccination', 'Flu Vaccine Positive Reason: No Harm', 'Not Flu Vaccinated', 'Not Eligible for Flu Vaccine', 'Flu While Pregnant', 'Used GP to get Flu Vaccine because of High-Risk Group', 'Past Employer Had Flu Shot Paid For', 'C ...
# 5 ['Anticipated Re-Entry', 'Will be fine on Return', 'Settled Quickly', 'Anticipated Future Stability', 'Adjusting to Stay Home', 'Accept Current Conditions', 'General Agreement', 'Range of Interests', 'Dissertation and Memory Loss', 'Fuzzy Memory', 'Participation Voluntary', 'Withdrawal Options Always Possible', 'Ability to Decline', 'Participant Agrees to Privacy Statement', 'Change of Location', 'Increased Effort', 'Changed Event Schedule', 'Walk-in Option Available', 'Agreed with Expert Status', 'Sweets Cause', 'Easy Resolution', 'Low Risk', 'Reading More To Determine Risk/Benefit', 'Feels Safe to Trust Decision Making', 'Interest in Reading More', 'Red Book Reference', 'Limited by Staff and Premises', 'Service Limitations', 'Positive Regarding Communication', 'Transparency', 'Willingness to Talk', 'Potential Benefit of Disclosure', 'Consent to Record', 'Knowledge mostly in Adults', 'Complications due to Others', 'Stop Recording', 'Interested in Findings', 'Hard Copy Required', 'Concensus Statement Read', 'Apologized for Repetitive Process', 'Potential Regression', 'Begging Crying', 'Bored of Me', 'Concern for the Process', 'Feel safe', 'More Like Coping Mechanisms', 'Disrespectful Communication', 'Participant Agrees to Audio-Visual Recording', 'Benefits of Protection', 'Benefit is Significant to Me', 'Correct Reference', 'Permission to Use Quotes Given', 'Re-booking Appointments', 'Honest Statement', 'Wild Guess', 'Must Go Private for Chickenpox', 'Financial Burden', 'Less Fortunate Knowledge', 'Easy Access to Social Support/Experts Online', 'Ending Recording, Open Ended', 'End Conversation', 'Interest', 'Positive Interest in Results', 'Option to Receive Results', 'Intro Consent Form ', 'Understanding Flexibility', 'Positive Outlook', 'Hard Copy Preference', 'Lockdown as Juggling Act', 'Need Entertainment', 'Concerned for Other Family Members', 'Community Protection', 'Broader Community Impact', 'All for Screening', 'Quick and Straightforwards Process', 'Frequent Hand Washing', 'Confidentiality Okay', 'Agreement (Positive)', 'Additional Screening Team Members', 'Interested in Sharing Results with Others', 'Relevant in my role', "Other's Role in project", 'Poor Internet Connection', 'Read Informed Consent Sheet', 'Technological Complications', 'Participant_ID_4', 'Interested in technology like Roblox', 'Struggles with Social Isolation during COVID-19', 'Discovered Roblox', 'Social Interaction', 'Consistent Behavior', 'Fighting', 'Free to Withdraw', 'Hard to Control', 'Proper Wrestling', 'Wine as Coping Mechanism', 'Alcohol Use as a Primary Strategy', 'Blocked out Craziness', 'Humorous Moment', "Do What's Necessary", 'Willing to Share', 'Understand Recording', 'Participant OK with Quotes', 'Social Component of Schooling', 'Isolation from Social Connections', 'Limited Return', 'One Side Very Challenging, Other Very Rewarding', 'Accepting of Situations', 'Positive Experiences', 'Positives COVID Restrictions', 'Positive Silver Lining', 'Positive Outcome', 'Confidentiality Agreement', 'Recovery', 'Concerned about Severity', 'Very Seriously Taken', 'Took the Situation Seriously', 'Prior Seriousness', 'Participant Agreement (Signed)', 'Optimistic', 'Family wide Disruption', 'Senior Family Members Need Safety Net', 'Reliance on Family is Reduced', 'Overwhelming Benefits', 'COVID-19 Benefits Outweigh Downsides', 'Online Reading Concerns', 'Informed Decision', 'Participant consent for Quotations', 'Low Risks', 'Benefits outweigh Risks', 'Prior Experience', 'More Proactive', 'Personal and Family Protection', 'Interesting Observation', 'Self Protection', 'Personal Proactivity', 'Government Guidelines Followed', 'Other', 'Curious Point', 'Interested in Results', 'Participant Thanks.', 'Will Return Results', 'Full Names', 'Should Be in Reception', 'Create Universe Roleplay', "I'm Antiscial Person", "Consult Team's Professional Opinion", 'Two Reasons', 'Previously Thought About', 'Remove Personal Details', 'Boots Partnership', 'Outdated  ...
# 6 ['Number of Children in Household', 'Parent with 2 Children', '4-yr-old, 7-yr-old', "Children's Age", 'Child is/was in School', 'Child gets Home-Time', 'Child out on Sick Leave', 'Older Child Interests', 'Childhood similar to Adult Manifestation', 'When Child is Ill', 'Younger Daughter in Different School', 'Child 1 Age', 'Parents with Two Children', "Second Child of 3 Year's Old", 'Younger Child will be 4 in September', "Children's Ages: 9 Years Old", "Youngest Child: 'Younger'", '3 Girls in Household', 'Girl Twins', 'Gender of Children', 'Children Surviving', "Child's WellBeing", 'Child Regression', 'Younger Child', 'School Nursery', 'Early Entry to Nursery', 'Social-Distanced Nursery', 'Begging Crying Crying as Child Care Methods', 'Kids not Missing the Schoolwork', 'Social aspect important for kids', 'Bored of Parent', 'Not a small infant', 'Parenting Strategies', 'Parenting as Coping Behavior', 'Two Children', 'Son Four Years Old', 'Managing Work and Kids', 'Family', 'Role Model for Child', 'Has Two Children', 'Younger Child', 'Has an Older Child', "Child's Birthday", 'Kids Are Funny', "Parent's Coping Strategy", 'Child Health is Primary Benefit', 'Child is Two Years Old', 'Younger Child is Three', 'Two Children, Correct Age', 'Parents confirm ages of children', 'Child is in Reception', 'Parents Challenge', 'Child Wants To Play', 'Some Child Go Back', 'Nursery Closed', 'Adult Children', 'Child Fine', 'Children Rely on Family for Sicknesses', 'Information Scares Parents', "Child's Illnesses Not a Concern", 'Child is Nearly Four Years Old', 'Talking With Parents', 'All children should receive nasal spray', 'Nasal Spray Recommended for School Age Children', "Children's Names Requested", "Child's Age", 'My Child', 'Other Child', 'Child_Ages_2_Yrs_3_mths_5_Yrs', 'Child in Reception', 'Prevent Child Getting Sick and Protect Others', 'Child Suffering', 'Has Two Children', 'Trusting Parents', 'Have One Child', 'Number of Children', 'Recommended for Kids', 'Procedure Terrified Child', 'Needle in Front of Child', 'Child Name and Age', 'Male Child', 'Child at Home from Beginning of Covid', 'Only child', "Importance of Child's Social Interaction", "Younger Children's Adjustment to Change", 'Parents Adapting Harder than Child', 'Part Time Nursery', 'Hours at Daycare Center', 'Children Loving Day Care', 'Loves Other Children', 'Enjoys Being Around Children', 'Child is Only Child', "Asked child's Name", "Reading Child's Health Issues", 'Close to Kindergarten Cutoff', 'No Other Children', 'Parent Avoidance of Sick Children', '4 children', 'Number of Children Verified', 'Has No Children', 'Child Health First', 'Build up to adulthood', 'Importance to Parent to Keep Child Healthy']
# 7 ['Question', 'Interviewee Understanding', 'Interview Process', 'Purpose of Questions', 'Last Year Question', 'Consent to Audio-Video Record Interview', 'First Answer', 'Request for Findings', 'Opportunity to Ask Questions', 'Consented for Interview', 'Informed Consent Interviewer', 'Answering Questions', 'Answer: General Statement', 'Implied Positive Response', 'I agree to sharing interview', 'Frequently Ask Questions to GP', 'Open to Questioning', 'GP Questioning and Guidance', 'Interview Consents', 'People Have Questions', 'No Questions Allowed by Parents', 'Participant Can Decline Questions', 'Interview Participant Okay', 'Connection Issues', 'Unclear Response', 'Using Technology for Answers', "Question: Today's Date", 'Hardest Question', 'Right to Decline to Answer', 'Intro: Interviewer Instructions', 'Can Decline Questions', 'Limited Questions', 'Question on MMR', 'Questions of Nurse', 'Interview Terms Accepted', "I don't know which response to give", 'Interview Understanding', 'Close Question', 'Positive Response', 'Ask GP', 'Answer Verification', 'Yes in Response to Question', 'Intro: Read Statements and Answer Yes or No', 'Confirmed Interview Information', 'Questioning the Answer', 'Yes Response to Sharing', 'Interview Consent', 'Last Interview Question', 'Question 2', 'Interview Concludes', 'Questions Covered quickly']
# 8 ['Ongoing Illness', 'Open Clinic', 'Unknown Illness', 'Associated Symptom Knowledge', 'Benefits Minimizing Risk of Illnesses', 'Prevent Sickness', 'Health Visitor Pamphlets', 'Husband is Informed Yet Concerned', 'Not Thought of Health Concern Before', 'Clinic Schedule', 'Nurse Acknowledgement of Apprehension', 'Doctor Sitting with You', 'Health Regressions', 'Nursing Family History', 'Fever, Fatigue, Muscle Aches', 'Confidently Identified Symptoms', 'No Underlying Health Conditions', 'Generally Healthy & Not Infancy', 'Innate Immunity Age Restriction', '1 Week to 10 Days Fever Duration', 'Home Care Treatment Options', 'Hard to Work with Medical Professionals', "Don't Feel You Should Blindly Follow Medical Professionals", 'Medical Professionals are not God', 'Avoids Contact with GP', 'Discourages GP Discussion', 'Patient Gratitude', 'Filling Patient Role', 'Patient Power Imbalance', 'Concerns for Elderly/Unhealthy', 'Awareness of Symptoms', 'Public Health Reporting', 'Primary Care as Promoters', 'Self Care Strategies', 'Symptoms', 'Health Observation', 'Observing their Appearance - Sick', 'Challenging In Home Care', 'Positive Emotion to Illness Experience', 'Take Illness Seriously', 'Good Health', 'Pre-Hospital Precaution', 'Hope for Less Severe Illness', 'Sick Person Passing Illness', 'Consult Doctor with Concerns', 'Spoke to Practice Nurse', 'MMR Autism Concerns', 'Measles Circulating Worry', 'Different Instructions for the Same Illness', 'Can Be Quite Bad', 'Family Members Respiratory Illnesses', 'Health Service Preference', 'Spoke to GP for Other Health Issues', 'Severe Allergic History', 'Specific Allergies to Egg and Milk', 'Sons Egg Allergy', 'Allergies as a Concern', 'Worry Exists but Concern Is Reasonable', 'Confidence in NHS Information', 'Improves Health', 'Reduces Risk of Severe Illness', 'Health Concern Primary Motivator', 'No Medical History to Justify', 'Trust GP/NHS Opinion', 'Trust In Medical Experts', 'Faith in Medical Professionals', 'Recommended by Medical Professionals', 'Scared By Needle', 'Could have been more Freaked Out About an Injection', 'Somewhat Worse Symptoms', 'Pain is Unpleasant', 'Mother as Nurse', 'Nurse Experience Growing up', 'Familiarity with Medical Institutions', 'Response Indicating Belief in Medicine', 'Informed by Nursing Parents', 'Open to Medicine', 'Prematurity Impact on health', 'Limited Contact with Health Visitor', 'Dynamic Shift after Day Care', 'Crying when Sick', 'Reading Symptoms', 'Quick Sickness Peak', 'Info for Other Illness/Disease', 'Reduces Chance of Illness', 'Measles Outbreak Concern', 'Anti-tryptic Deficiency', 'Benefits of Avoiding Illnesses', 'General symptoms', 'Tiredness and grumpiness', 'Appears Sick', 'Limited Concern with Symptoms', 'Hospitalisation Only Major Concern', 'Most would be 1 week of illness', 'More serious could result in hospitalization', 'Symptoms Hidden or Buried', 'List of Symptoms', 'General Approach To Search For Symptoms', 'Medical Professionals for Self', 'Illness', 'Avoid Getting Sick', 'Mild Side Effects: Nasal Spray', 'Health Visitor Recommends', 'Importance of Antibodies', 'Illness Avoidance', 'Difficulty Speaking with Antivaxers']
# 9 ['N/A', 'Spray Type', 'N/A', 'At that Point', 'Sugar Free Jelly', '111 was contacted', 'Parent Sent Letter', 'Letter from School with Program Info', 'Service is Good', 'Email only', 'Mailing Address Requested', 'Same Email?', 'Email Preferred', 'Same Study Document Format as Email?', 'Grayer', 'Family Facebook Group Automatic', 'Should be Automatic', 'Great GPs', 'GP Appointment', 'Phone Records Available', 'Email Correspondence', 'Apologies', 'N/A', 'Would Like Contact', 'Automatic Notification', 'Online Gaming', 'Technology and Gaming', 'Follows Structure', 'Nintendo Switch Gift', 'Communication via Speech', 'Already have Written Information', 'Study Forms via Email', 'Laugh', 'usually NHS', 'Booked by Phone', 'Have I had it?', 'Blank Line', '<BLANK>', '<BLANK>', 'Send to Email', 'Send Information about Labelling', 'Survey Emails Sent at the End of August', 'Preference to Email', 'Use of Email for Communication', '2 Y', 'Grey Area', '111 Service Use', 'Spoke to GP in Fall', 'Audio Recording', 'Organization', 'GP Sent Medical Form', 'Invitation from GP', 'Request Written Report', 'E-mail Preferred', 'Email', 'Send Documents', 'Thank You', 'Confirming Email as Follow-Up', 'Allow to Email', 'NHS Website', 'Only the NHS Website', 'Willing to Receive Physical Mailing', 'GP and NHS Informed Decision', 'GP Recommendations Accepted', 'Follow GP Recommendations', 'Notification through Post then Call to Book', 'GP Contacted via Phone Call', 'Go Ahead and Do It', 'N/A', "He's a", 'Charities Websites', "It's a Quick and Easy Process", 'Indirect Contact', 'Availble from GP', 'NHS website is good for start', 'Follow-up Email Optional', 'Go to NHS UK Website', 'NHS - Authority', 'Cost', 'Google', 'Visit Website', 'Manufacturers Websites', 'Letter', 'Letter from NHS', 'Text Message from Doctor', 'Notifications sent to wife ', 'Ring GP', 'Went to GP Visit', 'Email as Preferred Option', 'Send to Me Anyway', 'Email for Results', 'Email Preference', 'Email Response from Parent']

# %%
import numpy as np
from sklearn.preprocessing import normalize

class KMeansCosine:
    def __init__(self, n_clusters=3, max_iter=300, tol=1e-4, random_state=None):
        self.n_clusters = n_clusters
        self.max_iter = max_iter
        self.tol = tol
        self.random_state = random_state
        self.centroids = None
        self.labels_ = None

    def _cosine_similarity(self, X, Y):
        # Cosine similarity = dot product of normalized vectors
        return np.dot(X, Y.T)

    def _initialize_centroids(self, X):
        if self.random_state:
            np.random.seed(self.random_state)
        random_idxs = np.random.permutation(X.shape[0])
        centroids = X[random_idxs[:self.n_clusters]]
        return centroids

    def fit(self, X):
        X_normalized = normalize(X)
        self.centroids = self._initialize_centroids(X_normalized)

        for _ in range(self.max_iter):
            # Compute similarity between all points and centroids
            similarity = self._cosine_similarity(X_normalized, self.centroids)
            self.labels_ = np.argmax(similarity, axis=1)

            new_centroids = np.array([
                X_normalized[self.labels_ == i].mean(axis=0) 
                for i in range(self.n_clusters)
            ])
            
            # Normalize new centroids
            new_centroids = normalize(new_centroids)

            if np.all(np.abs(self.centroids - new_centroids) < self.tol):
                break
            
            self.centroids = new_centroids

    def predict(self, X):
        X_normalized = normalize(X)
        similarity = self._cosine_similarity(X_normalized, self.centroids)
        return np.argmax(similarity, axis=1)

    def fit_predict(self, X):
        self.fit(X)
        return self.labels_
    
    
X = model.encode(all_codes)

kmeans_cosine = KMeansCosine(n_clusters=13, random_state=42)
kmeans_cosine.fit(X)
labels = kmeans_cosine.labels_

ret_arr = [[] for _ in range(13)]

for sect, sent in zip(labels, all_codes):
    ret_arr[sect].append(sent)
    
i=0
for sect in ret_arr:
    print(i, sect)
    i+=1
# Out:
# 0 ['Use of Resources', 'Limited to Low-Risk Info', 'NHS Website Primary Source', 'Information from Health Education', 'GP as Information Source', 'Avoid Unverified Information Sources', 'Advantage of Family Resources Available', "Online 'Experts' for Information", 'Easy Access to Social Support/Experts Online', 'NHS website Primary Source', 'Poor Internet Connection', 'Government Website Primary Source', 'Limited Online Searches', 'NHS Website Primary Source', 'NHS Website as Primary Source (1 instance)', 'Limited Knowledge About Types', 'NHS Website Primary Source', 'Information Source', '111 Service Use', 'NHS Website', 'Trusted Source Required', 'Limited Info', 'Only the NHS Website', 'Information Sources', 'Internet and NHS website as primary source', 'Sometimes Other Sources Used', 'Charities as Secondary Information Source', 'Charities Websites', 'Not All Sources of Info are Equal', 'Online Information as Useful', 'NHS website is good for start', 'Go to NHS UK Website', 'Other Resources', 'CDC Resources', 'Primary Information Source is NHS', 'Check CDC Website In America', 'Check WHO Website', 'Multiple Sources used for Knowledge', 'More Thorough Website Searches', 'Google', 'WHO as Source', 'Create Own Search URL', 'Visit Website', 'Agency website as secondary resource', 'Manufacturers Websites']
# 1 ['Do Not Have Flu Experience', "Can't Comment on Experience", 'General Cold/Flu Experience for Adults', 'Previous Experience with Flu', 'No Flu Experience', 'No Grey Hair Experience', 'No Past Illness Experience', 'No Kindergarten Experience', 'No Flu Treatment Experience', 'No Experience with Doctors', 'No Flu Experience', 'Negative GP Experiences Affected Future Interactions', 'No Know Flu Experience', 'Positive Experiences', 'Positive Emotion to Illness Experience', 'Flu Experience More Common in Adults', "Child's Flu Experience", 'No Personal Experience with Child Flu', 'Has Experience with Fever', 'Most Recent Flu Experience', 'Prior Experience', 'Flu Experiences', 'No Flu Experience', 'No Flu Experience', 'No Child Flu Experience', 'No Flu Experience', 'No Expectation of Flu Experience', 'No Social Flu Experience', 'Nurse Experience Growing up', 'Asthma as Experience', 'No Experiences with No Faith', 'No Flu Experience', "Not Impacted by Other's Experiences", 'Friends Negative Experiences', 'Previous Flu Vaccine Experience', 'Personal Experience ', 'Participants Experienced Flu', 'No Flu Experience', 'No Experience']
# 2 ['Ongoing Illness', 'Unknown Illness', 'Inability to Identify Cause', 'Associated Symptom Knowledge', 'Benefits Minimizing Risk of Illnesses', 'Prevent Sickness', 'Health Visitor Pamphlets', 'Husband is Informed Yet Concerned', 'Not Thought of Health Concern Before', 'Nurse Acknowledgement of Apprehension', 'Health Regressions', 'Fever, Fatigue, Muscle Aches', 'Confidently Identified Symptoms', 'Generally Healthy & Not Infancy', 'Innate Immunity Age Restriction', 'Home Care Treatment Options', 'Less Fortunate Knowledge', 'Patient Gratitude', 'Filling Patient Role', 'Patient Power Imbalance', 'Concerns for Elderly/Unhealthy', 'Awareness of Symptoms', 'Primary Care as Promoters', 'Frequent Hand Washing', 'Self Care Strategies', 'Alcohol Use as a Primary Strategy', 'Symptoms', 'Health Observation', 'Observing their Appearance - Sick', 'Challenging In Home Care', 'Take Illness Seriously', 'Good Health', 'Concerned about Severity', 'Very Seriously Taken', 'Took the Situation Seriously', 'Pre-Hospital Precaution', 'Prior Seriousness', 'No One I Know who Got Sick', 'Hope for Less Severe Illness', 'Sick Person Passing Illness', 'Online Reading Concerns', 'MMR Autism Concerns', 'Measles Circulating Worry', 'Different Instructions for the Same Illness', 'Can Be Quite Bad', 'Family Members Respiratory Illnesses', "I'm Antiscial Person", 'Health Service Preference', 'Severe Allergic History', 'Allergies as a Concern', 'Worry Exists but Concern Is Reasonable', 'Concerns in Back of the Mind', 'Improves Health', 'Reduces Risk of Severe Illness', 'Health Concern Primary Motivator', 'Scared By Needle', 'Somewhat Worse Symptoms', 'Pain is Unpleasant', 'Prematurity Impact on health', 'Dynamic Shift after Day Care', 'Crying when Sick', 'Reading Symptoms', 'Observing Physical Changes', 'Quick Sickness Peak', 'Info for Other Illness/Disease', 'Reduces Chance of Illness', 'Measles Outbreak Concern', 'History with Measles Outbreaks', 'Vacine Indifference', 'Anti-tryptic Deficiency', 'Increased Worry for Infections', 'Increased Awareness of Riskiness', 'Benefits of Avoiding Illnesses', 'General symptoms', 'Tiredness and grumpiness', 'Appears Sick', 'Limited Concern with Symptoms', 'Hospitalisation Only Major Concern', 'Most would be 1 week of illness', 'More serious could result in hospitalization', 'Symptoms Hidden or Buried', 'List of Symptoms', 'General Approach To Search For Symptoms', 'Illness', 'Avoid Getting Sick', 'Health Visitor Recommends', 'Importance of Antibodies', 'Illness Avoidance', 'Difficulty Speaking with Antivaxers']
# 3 ['Current Residence since 1997', 'Will be fine on Return', 'Anticipated Future Stability', 'Withdrawal Options Always Possible', 'Ability to Decline', 'Walk-in Option Available', 'Agreed with Expert Status', 'Feels Safe to Trust Decision Making', 'Service is Good', 'Positive Regarding Communication', 'Willingness to Talk', 'Possible to get in future', 'Potential Regression', 'Confidence in Researcher', 'Implied Positive Response', 'Feel safe', 'Concerned about Unspecific Internet Accuracy', 'Incorrect Information Available', 'Should be Automatic', 'Disrespectful Communication', 'Correct Reference', 'Honest Statement', 'Understanding Flexibility', 'Positive Outlook', 'Lockdown as Juggling Act', 'Community Protection', 'Broader Community Impact', 'Confidentiality Okay', 'Agreement (Positive)', 'Unclear Response', 'Struggles with Social Isolation during COVID-19', 'Social Interaction', 'Consistent Behavior', 'Isolation from Social Connections', 'Accepting of Situations', 'Positives COVID Restrictions', 'Positive Silver Lining', 'Positive Outcome', 'Confidentiality Agreement', 'Optimistic', 'Reliance on Family is Reduced', 'Self Protection', 'Personal Proactivity', 'Possible Timeline - Might Be', 'Boots Partnership', 'Outdated Advice', 'Positive Response', 'Desire Knowledge to Act', 'Confident in Accuracy', 'Successful Process', 'Social Norms', 'Trust in Institution', 'Faith', 'Has Coped Well', 'Social Interaction', 'Encouragement for Honesty', 'Reduces Community Impact', 'Protective of Others', 'Fear of Inaccurate Information', 'National Antenatal Charity', 'I Considered but Rebuffed', 'Spouse Profession', 'Incorrectly Inferred Info', "Wife's Research Trusted", 'Trust in Significant Other']
# 4 ['No Schoolwork', 'Nice to have but not necessary', 'Usually No Shot', 'Unable to Recall', 'Did Not Attend Clinic', 'Unable to Make Event', 'No Problems', 'Not Thought about Benefits Before', 'Not Given Thought', 'No Side Effects', 'No Thought', 'Nothing to Add', "Experts aren't Needed", 'No Availability: Time', 'No Further Information Provided', 'No Kindergarten', 'No Begging Work', 'Try Nothing of Value to Influence', 'Missing social aspect', 'Missing Friends', 'No Concerns', 'No Underlying Health Conditions', "No to be fair I don't actually... I'm just trying to think. No.", 'Not Parenting Focused', 'No Private Provider', 'Uncomfortable Conversation', 'Not a Blind Follower', 'Not Spoken to Like Adult', 'Non-Informative Non-Fluency', 'Insufficient Info', 'Not a real decision', 'No Personal Assistance', "Some People Don't Have History", 'No Questions Allowed by Parents', 'No Need for Hard Copy', 'No Problem Expressed', 'No Electronic Documents', 'No Major Issues', 'No Information on Hand Washing Benefits', 'No Concerns', 'Not Aware of Date', 'No Name Given (Younger)', 'Hard to Control', 'No choice in the matter', 'No Expectations', 'Not Asked Yet', 'Not Identified in Transcription', 'No Document Delivery', 'No Hard Copy Request', 'Unrespected As Teacher', 'Lack of Together Time in Non-Lockdown', 'Not Taking Seriously', 'No Long-term Effects', 'No Knowledge of Real Symptoms', 'No Specific Consultation', 'No Guarantee', 'Not Applicable to All', 'No Side Effects', 'No Further Inquiry', 'No Other Comment', 'Happy with Non-Screen Time', 'No Early Morning Television', "I don't know which response to give", 'No Understanding of Refusals', 'No Cost', 'Uncertain Month', 'No Specific Time', 'Unknown Season', 'Uncertain Date', 'No Suffering', "Not Worried or Worried but don't Want", 'Something not thinking about', 'Uncertain Risk Assessment', 'Unknown Close Social Network', 'No Family or Friends Illness', 'Not Spoken to Anyone Professionally', 'No Concern about Others', 'No Address Required', 'No Hard Copy Needed', 'No Further Research', 'No Additional Information Sought', 'No Active Learning', 'No Additional Information needed if in a schedule', 'No Reported Symptoms', 'No After Effects', 'No Further Concern', 'No preference or care', 'No Memory of Shot', 'No Further Remarks', 'No More Information', 'No Longer Effects', 'No Social Interaction', 'No Worries', 'Not relevant to theme', 'Lack of Knowledge', 'Not Considered', 'Protective Benefit Not Thought About', 'No Scientific Evidence', 'Information Not Useful', "Thinking he's Ineligible", "Didn't Look it Up", 'Does not Worry', 'Not a Conversation', 'No Consequences of Unnecessary Injection', 'Not on Eligibility List', 'Not High Risk Status', 'Not Consideration', 'Not a Personal Priority', 'Costing No Concern', 'Not a High Risk Illness', 'No Admin Needed', 'No Paper Copy', 'Lack of Will', "Majority wouldn't be serious.", 'Symptoms not Always Listed on Single Source', 'No Downside in UK', 'Free, No Inconvenience', 'No Concerns', 'No Challenges', 'No Personal Info on Video']
# 5 ['Range of Interests', 'Reading More To Determine Risk/Benefit', 'Interest in Reading More', 'Potential Benefit of Disclosure', 'Interested in Findings', 'Concern for the Process', 'More Like Coping Mechanisms', 'Benefits of Protection', 'Benefit is Significant to Me', 'Interest', 'Positive Interest in Results', 'Hard Copy Preference', 'Need Entertainment', 'Interested in Research Report', 'Interested in Sharing Results with Others', 'Relevant in my role', "Other's Role in project", 'Interested in technology like Roblox', 'No Interest in Exploring', 'One Side Very Challenging, Other Very Rewarding', 'Overwhelming Benefits', 'COVID-19 Benefits Outweigh Downsides', 'Benefits outweigh Risks', 'More Proactive', 'Interesting Observation', 'No Interest in Learning More', 'Curious Point', 'Interested in Results', 'Would Like Research Findings', 'Interested', 'Measles Comparison as Example', 'Has Been Interesting', 'Needs to Be Around Others', 'Enjoys Others', 'Benefits to Others', 'Not Interested in Private Payment', 'Validated Cost-Benefit Trade-Off', 'Cost and Benefit', 'Seek out more information', 'Interested to Read Final Findings', 'Main Benefit', 'Very Important', 'Private Paid for', 'Wife Also Interested']
# 6 ['Open Clinic', 'Research in Dr. Google', 'Clinic Schedule', 'Doctor Sitting with You', 'Hard to Work with Medical Professionals', 'Frequently Ask Questions to GP', "Don't Feel You Should Blindly Follow Medical Professionals", 'Medical Professionals are not God', 'Specific Experience with GP', 'GP Questioning and Guidance', 'Great GPs', 'Avoids Contact with GP', 'GP Use for Flu', 'Discourages GP Discussion', 'No GP Notification', 'GP Appointment', 'Public Health Reporting', 'No Contact with GP on Flu', 'Consult Doctor with Concerns', 'usually NHS', 'Spoke to Practice Nurse', 'GP not Consulted', "Didn't Ask Doctor", 'Questions of Nurse', 'Spoke to GP for Other Health Issues', 'Spoke to GP in Fall', "Consult Team's Professional Opinion", 'GP Sent Medical Form', 'Invitation from GP', 'Confidence in NHS Information', 'No Medical Professional Contact for Flu', 'Talked to GP not specifically about the Flu', 'GP and NHS Informed Decision', 'No Medical History to Justify', 'Ask GP', 'Trust GP/NHS Opinion', 'GP Recommendations Accepted', 'Follow GP Recommendations', 'Trust In Medical Experts', 'GP Contacted via Phone Call', 'Faith in Medical Professionals', 'Recommended by Medical Professionals', 'Familiarity with Medical Institutions', 'Response Indicating Belief in Medicine', 'Open to Medicine', 'Limited Contact with Health Visitor', 'Not Contacted Doctor', 'No GP Interaction', 'Never Talked to a GP about the Flu', 'Consider Not Recommended by NHS', 'Availble from GP', 'Used NHS to Start Research', 'NHS - Authority', 'Medical Professionals for Self', 'Background Medical Research', 'Letter from NHS', 'Ring GP', 'Went to GP Visit']
# 7 ['Started Last September', 'Time to Settle', 'Settled Quickly', 'N/A', 'Spray Type', 'Fuzzy Memory', 'Change of Location', 'Limited Time Frame', 'Increased Effort', 'N/A', 'At that Point', 'Sugar Free Jelly', 'Sweets Cause', 'Easy Resolution', 'Low Risk', 'Service Limitations', 'Transparency', 'Stop Recording', 'First Answer', 'Hard Copy Required', 'Complete Now', 'Grayer', 'Accelerated Aging', 'Greying Over Time', 'Begging Crying', 'Bored of Me', 'Week to 10 days', 'Current Year', 'Late Vax', 'Remembered Late Season', 'Wild Guess', 'Financial Burden', 'Apologies', 'N/A', 'Quick and Straightforwards Process', 'Technological Complications', 'Hardest Question', 'Discovered Roblox', 'Online Gaming', 'Technology and Gaming', 'Follows Structure', 'Nintendo Switch Gift', 'Fighting', 'Free to Withdraw', 'Proper Wrestling', 'Blocked out Craziness', 'Humorous Moment', "Do What's Necessary", 'Limited Return', 'Laugh', 'Now He is Fine', 'Recovery', 'October-November Season', 'Nearly Four', 'Low Risks', 'Have I had it?', 'Blank Line', 'Other', '<BLANK>', '<BLANK>', 'Full Names', '2 Y', 'Current Grade', 'Grey Area', 'Create Universe Roleplay', 'Two Reasons', 'Audio Recording', 'Organization', 'Before Christmas Time', 'Possibly Early', 'Around November', 'Thank You', 'Easy Decision', 'Reduces Severity', 'Minimal Downtime', 'Promptly Booked', 'Same Day', 'Neutral', 'More or Less Straight Away', 'Foregone Decision', 'Go Ahead and Do It', 'Nasal Spray', 'N/A', 'Quick Recovery', "He's a", 'High Temperature', 'Flushed Face', 'Visual Perception', 'External Environment', 'Missed the Cutoff', 'Cutoff Age', 'Reduction in Transmission', 'Side Effects', 'Wonderful Technology', "It's a Quick and Easy Process", 'Large garden required', 'Activity change', 'Cost', 'Nasal Spray Only', 'Question 2', 'Last Year', 'Back end of 2019', 'Autumn of 2019', 'Practice', 'Easy Process', 'Very Straightforward', 'Decisions are Made', 'Sought out myself']
# 8 ['Anticipated Re-Entry', 'Question', 'Accept Current Conditions', 'General Agreement', 'Dissertation and Memory Loss', 'Participation Voluntary', 'Interviewee Understanding', 'Participant Agrees to Privacy Statement', 'Changed Event Schedule', 'Information Collected', 'Data Access - Study Research', 'Red Book Reference', 'Interview Process', 'Limited by Staff and Premises', 'Purpose of Questions', 'Last Year Question', 'Consent to Record', 'Consent to Audio-Video Record Interview', 'Complications due to Others', 'Request for Findings', 'Study End Date', 'Concensus Statement Read', 'Opportunity to Ask Questions', 'Apologized for Repetitive Process', 'Consented for Interview', 'Informed Consent Interviewer', 'Answering Questions', 'Entry to Reception in September', 'Granted Data Access', 'Researcher Access', 'Answer: General Statement', 'I agree to sharing interview', 'Open to Questioning', 'Participant Agrees to Audio-Visual Recording', 'Permission to Use Quotes Given', 'Interview Consents', 'Understood Statement on Data Collection', 'Rescheduled to Day Off', 'Within 10 Days of Receiving', 'Re-booking Appointments', 'People Have Questions', 'Ending Recording, Open Ended', 'End Conversation', 'Option to Receive Results', 'Study Date', 'Intro Consent Form ', 'Unknown Timeframe for End of Research', 'Unknown Date for Findings to be Shared', 'Study will End August', 'Study Findings to Participant Email', 'All for Screening', 'Appointment Time Early Morning', 'Participant Can Decline Questions', 'Grant Access to Data', 'Interview Participant Okay', 'Participant agrees to take part in study', 'Additional Screening Team Members', 'Screening Information', 'Connection Issues', 'Read Informed Consent Sheet', 'Participant_ID_4', 'Date on Screen', 'Using Technology for Answers', "Question: Today's Date", 'Right to Decline to Answer', 'Intro: Interviewer Instructions', 'Can Decline Questions', 'Research Team Access', 'Willing to Share', 'Understand Recording', 'Participant OK with Quotes', 'Agreement with Participating in Study', 'Request for Research Findings', 'Willing to Receive Information', 'Within the Cut Off Date', 'Participant Agreement (Signed)', 'Informed Decision', 'Standard Information Provided', 'Limited Questions', 'Participant consent for Quotations', 'Question on MMR', 'Government Guidelines Followed', 'Study Overview', 'Participant Thanks.', 'Will Return Results', 'Study Completion Date', 'Interview Terms Accepted', 'Should Be in Reception', 'Previously Thought About', 'Remove Personal Details', 'Interview Understanding', 'Close Question', 'Request Written Report', 'End of Study', 'Final Project Report', 'Participant Agrees to Share Data', 'Appointment Scheduled', 'Default Acceptance of Recommendations', 'Direct Observation of Procedure', 'Answer Verification', 'Yes in Response to Question', 'Read Statements', 'Intro: Read Statements and Answer Yes or No', 'Confirmed Interview Information', 'Questioning the Answer', 'Acknowledged Voluntary Participation Policy', 'Need Research', 'Allow Access for Researcher', 'Shared with Others', 'Yes Response to Sharing', 'Interview Consent', 'Quotations Can be Used in Research', 'Receiving Summary', 'Last Interview Question', 'Research Summary Information', 'Participant Consent to Receive Research Findings', 'Participant Understands Rights', 'General Approach to Information', 'Agree Information Use', 'Wife is Research Scientist', 'Up to Date', 'Seeking Out Information', 'Seeks Out Own Training', 'Interview Concludes', 'Questions Covered quickly', 'Research Scientist', 'Direct Quotations', 'Agreement to Participate', 'In Study', 'Would Like a Copy of Report', 'Wife Part of Participant', 'Partner Informed', "Participant's Preferred Communication Method"]
# 9 ['Parent with 2 Children', '4-yr-old, 7-yr-old', "Children's Age", 'Five and Two Years of Age', 'Older Child Interests', 'When Child is Ill', 'Child 1 Age', 'Parents with Two Children', "Second Child of 3 Year's Old", 'Younger Child will be 4 in September', "Children's Ages: 9 Years Old", "Youngest Child: 'Younger'", '3 Girls in Household', 'Girl Twins', 'Gender of Children', 'Children Surviving', "Child's WellBeing", 'Younger Child', "She's going to be the oldest", 'Not a small infant', 'Two Children', 'Son Four Years Old', 'Family', 'Two, Five Years Old', 'Has Two Children', 'Second Year of School', 'Younger Child', 'Has an Older Child', 'Age', "Child's Birthday", 'Kids Are Funny', 'Child is Two Years Old', 'Younger Child is Three', 'Two Children, Correct Age', 'Adult Children', 'Child Fine', 'Child is Nearly Four Years Old', "Child's Age", 'My Child', 'Other Child', '2 Years Old', 'Child_Ages_2_Yrs_3_mths_5_Yrs', '5 Year Old', 'Has Two Children', 'Have One Child', 'Number of Children', 'Child Name and Age', 'Male Child', 'Premature Birth', 'Only child', 'Coming Up To Two and a Half', 'Age: 2-2 ½', 'Birth Date: January 2018', 'Loves Other Children', 'Child is Only Child', 'Birthday in January', 'Same Age', 'No Other Children', 'First Born', "Same as Current Child's Birthdate", 'Born in 2018', '4 children', 'Number of Children Verified', 'Identical Twins', '2nd Set of Twins in Home', 'Siblings Are Available', 'Has No Children']
# 10 ['Number of Children in Household', 'Start of School Year', 'Child is/was in School', 'Child gets Home-Time', 'Child out on Sick Leave', 'Adjusting to Stay Home', 'Childhood similar to Adult Manifestation', 'Younger Daughter in Different School', 'Knowledge mostly in Adults', 'Child Regression', 'School Nursery', 'Nursery but Not Reception', 'Early Entry to Nursery', 'She was in school nursery', 'in school, but not in school yet', 'School Closing', 'Social-Distanced Nursery', 'Begging Crying Crying as Child Care Methods', 'Kids not Missing the Schoolwork', 'Social aspect important for kids', 'Bored of Parent', 'Nursing Family History', 'Family Facebook Group Automatic', 'Parenting Strategies', 'Parenting as Coping Behavior', 'Some Knowledge from Parents/History', 'Managing Work and Kids', 'Concerned for Other Family Members', 'Role Model for Child', 'In School', "Parent's Coping Strategy", 'Child Health is Primary Benefit', 'Parents confirm ages of children', 'Started School Reception', 'School Start Date (9/7/19)', 'Child is in Reception', 'Social Component of Schooling', 'Homeschooling is Hard', 'Parents Challenge', 'Child Wants To Play', 'Challenge More than School', 'Some Child Go Back', 'Nursery Closed', 'Family wide Disruption', 'Children Rely on Family for Sicknesses', 'Senior Family Members Need Safety Net', 'Information Scares Parents', "Child's Illnesses Not a Concern", 'Talking With Parents', 'Personal and Family Protection', 'Nasal Spray Recommended for School Age Children', "Children's Names Requested", 'Child in Reception', 'Year-old is Going to School', 'Prevent Child Getting Sick and Protect Others', 'Form to Fill for School', 'Starting School in October', 'Child Suffering', 'Not deeply considered by parent', 'Trusting Parents', 'Checked with Father', 'Recommended for Kids', 'Procedure Terrified Child', 'Parent Describes Incident', 'Needle in Front of Child', 'Nice to be Out For Family', 'Mother as Nurse', 'Informed by Nursing Parents', 'Child at Home from Beginning of Covid', "Importance of Child's Social Interaction", "Younger Children's Adjustment to Change", 'Parents Adapting Harder than Child', 'Part Time Nursery', 'Hours at Daycare Center', 'Loves to be at school', 'Children Loving Day Care', 'Enjoys Being Around Children', "Asked child's Name", "Reading Child's Health Issues", 'Close to Kindergarten Cutoff', 'Parent Avoidance of Sick Children', 'Good for Gardens', 'Child Health First', 'Build up to adulthood', 'Importance to Parent to Keep Child Healthy']
# 11 ['111 was contacted', 'Parent Sent Letter', 'Letter from School with Program Info', 'Email only', 'Contact for Additional Information', 'Mailing Address Requested', 'Same Email?', 'Email Preferred', 'Same Study Document Format as Email?', 'Phone Records Available', 'Email Correspondence', 'Would Like Contact', 'Automatic Notification', 'Communication via Speech', 'Already have Written Information', 'Study Forms via Email', 'Booked by Phone', 'Send to Email', 'Send Information about Labelling', 'Survey Emails Sent at the End of August', 'Preference to Email', 'Use of Email for Communication', 'E-mail Preferred', 'Email', 'Send Documents', 'Confirming Email as Follow-Up', 'Allow to Email', 'Willing to Receive Physical Mailing', 'Offer Mailed Study Materials', 'Notification through Post then Call to Book', 'Early in Day Contact', 'Indirect Contact', 'Follow-up Email Optional', 'Letter', 'Text Message from Doctor', 'Notifications sent to wife ', 'Email as Preferred Option', 'Send to Me Anyway', 'Email for Results', 'Email Preference', 'Email Response from Parent']
# 12 ["Dad's Flu Symptoms More Tolerable", 'Tried to get Flu Vaccine', 'Get Flu Shots for Kids', 'Received spray this year', 'Received the Flu Vaccine', 'Missed Vaccination Window', 'Negligence with Flu Vaccine', 'Vaccine Protection', 'Flu as Generally Accepted', 'Flu Not Seen as Sinister', 'No Flu Vaccine', 'Yes Vaccines Given', 'Standard Childhood Vaccines', 'Nurses and Doctors Give Flu Shots', 'Does Not Prioritize Vaccination', 'Flu Not Top of Mind', 'Flu as Just Something to Face', 'Encourages Thoughts on Flu', 'Want someone to say I have a flu', 'Flu a Combination of Cold and Flu Symptoms', 'Flu Symptoms as Illnesses', 'Multiple Children, No Knowledge of Flu', '1 Week to 10 Days Fever Duration', 'Shortage of Flu Vaccine', 'Anti-Vaccine Stereotype', 'Vaccine Hesitancy Leads to Questioning', 'Frequent Vaccinations with Child', 'All Vaccines', 'Reduction of Flu Exposure', 'Flu Vaccine Benefit', 'Confidence and Long-Term Vaccines', 'Vaccinated', 'Vaccine Delays', 'Difficulties with Vaccine Consultation', 'Vaccine Value', 'Uncertainty about Flu Season', 'Vaccinations Given Previously', 'Must Go Private for Chickenpox', 'No Open Vaccinate', 'Concerns About Vaccines', 'Minimize Flu Risk', 'Not a 100% Flu', 'Supporting Flu Shot - Benefit to Health', 'No Rush in Getting Vaccine', 'Vaccine Timing', 'Vaccine Intentions', 'Children Vaccinated', 'Flu Awareness and Increased Fear of Flu', 'Children have Flu', 'No Flu Vaccine This Season', '5 Year Old Previously Had Vaccine', 'Vaccine Decision Made Recently', 'No Vaccine History', 'Not Vaccinated for Measles, Mumps, Rubella', 'Wine as Coping Mechanism', 'Single Flu Case Survey', 'Not Offered Vaccine', 'Accepted Flu Vaccine Option If Offered', 'Up to Date Vaccinations', 'Flu a Good Family Uniter', 'Wiped out by Flu', 'Serious About Flu', 'No Knowledge of Flu Illness in Family or Friends', 'Receiving Information on Flu via Third Parties', 'Flu Symptoms Lowered', 'Vaccine not a guarantee of prevention', 'Vaccine Effectiveness', 'Working Parent Struggles with Flu', 'Flu Risk', 'Not about Flu Vaccine', 'Positive Explanation of Vaccine', 'No Live Virus', 'Vaccinations Made Available on Campus', 'Vaccinate Appointment', 'Received Vaccinations', 'Yes Has Had Other Vaccinations', 'Reaction to one vaccination out of all', 'Vaccine Reservations', 'Flu is 4 weeks ago', 'Delayed Flu Vaccination', 'Flu History', 'Immunity', 'Vaccination-Great', 'Have you had vaccine?', 'Taken Vaccine at Pharmacist', 'John Never Got Flu', 'Flu Shot', 'All children should receive nasal spray', 'Vaccine Distribution Methods', 'Vaccine Delivery Method', 'Only Curious About Difference in Vaccine Types (1 instance)', 'Vaccines', 'Concerned about Child Getting Flu', 'No Flu-related Illnesses in Family', 'Seeking Info About Flu Symptoms', 'Talked with Medical Professional for Flu Vaccine', 'Not about Flu', 'Specific Allergies to Egg and Milk', 'Sons Egg Allergy', 'Always Vaccinated', 'Convenience for Vaccine', 'Allergy form prompted vaccine inquiry', 'Vaccine and Egg Allergies Connection', "Child's Flu Vaccine at School", 'Current Flu Season', 'Daughter not yet Vaccinated', 'Vaccine Intent', 'Routine and Childhood Vaccinations', 'Always Going to Vaccinate', 'Flu Vaccine', 'Work Offered Flu Jabs', 'Vaccinations Offered at Pharmacies', 'Employer Provides Vaccine for no Cost', 'Worried About the Flu', 'Common Flu Symptoms', 'Flu Impact on Children vs Adults Unknown', 'Conscious of Flu', 'No-one with Child Affected by Flu', 'Vaccination Necessary with Seriousness', 'NHS Advised Vaccination', 'Vaccine Advantages', 'Requested Vaccination', 'Fully Vaccinated', 'Up to Date with Vaccinations', 'Vaccinations were Routine', 'Social Pressure to Vaccinate', 'Flu Vaccination Suggested Protocol', 'Vaccine Anxiety Reassurance', "Child's Vaccination Information Received", 'any injections', 'Could have been more Freaked Out About an Injection', 'Still willing to do an Injection', 'View of the Flu - Severe Illness', 'Flu Should Not Be Taken Ligh ...

# %%
# from sklearn.metrics import silhouette_samples, silhouette_score
# import matplotlib.cm as cm
# import matplotlib.pyplot as plt
# 
# X = model.encode(all_codes)
# 
# range_n_clusters = [9, 10, 11, 12, 13, 14, 15]
# 
# for n_clusters in range_n_clusters:
#     # Create a subplot with 1 row and 2 columns
#     fig, (ax1, ax2) = plt.subplots(1, 2)
#     fig.set_size_inches(18, 7)
# 
#     # The 1st subplot is the silhouette plot
#     # The silhouette coefficient can range from -1, 1 but in this example all
#     # lie within [-0.1, 1]
#     ax1.set_xlim([-0.1, 1])
#     # The (n_clusters+1)*10 is for inserting blank space between silhouette
#     # plots of individual clusters, to demarcate them clearly.
#     ax1.set_ylim([0, len(X) + (n_clusters + 1) * 10])
# 
#     # Initialize the clusterer with n_clusters value and a random generator
#     # seed of 10 for reproducibility.
#     clusterer = KMeans(n_clusters=n_clusters, random_state=10)
#     cluster_labels = clusterer.fit_predict(X)
# 
#     # The silhouette_score gives the average value for all the samples.
#     # This gives a perspective into the density and separation of the formed
#     # clusters
#     silhouette_avg = silhouette_score(X, cluster_labels)
#     print(
#         "For n_clusters =",
#         n_clusters,
#         "The average silhouette_score is :",
#         silhouette_avg,
#     )
# 
#     # Compute the silhouette scores for each sample
#     sample_silhouette_values = silhouette_samples(X, cluster_labels)
# 
#     y_lower = 10
#     for i in range(n_clusters):
#         # Aggregate the silhouette scores for samples belonging to
#         # cluster i, and sort them
#         ith_cluster_silhouette_values = sample_silhouette_values[cluster_labels == i]
# 
#         ith_cluster_silhouette_values.sort()
# 
#         size_cluster_i = ith_cluster_silhouette_values.shape[0]
#         y_upper = y_lower + size_cluster_i
# 
#         color = cm.nipy_spectral(float(i) / n_clusters)
#         ax1.fill_betweenx(
#             np.arange(y_lower, y_upper),
#             0,
#             ith_cluster_silhouette_values,
#             facecolor=color,
#             edgecolor=color,
#             alpha=0.7,
#         )
# 
#         # Label the silhouette plots with their cluster numbers at the middle
#         ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))
# 
#         # Compute the new y_lower for next plot
#         y_lower = y_upper + 10  # 10 for the 0 samples
# 
#     ax1.set_title("The silhouette plot for the various clusters.")
#     ax1.set_xlabel("The silhouette coefficient values")
#     ax1.set_ylabel("Cluster label")
# 
#     # The vertical line for average silhouette score of all the values
#     ax1.axvline(x=silhouette_avg, color="red", linestyle="--")
# 
#     ax1.set_yticks([])  # Clear the yaxis labels / ticks
#     ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])
# 
#     # 2nd Plot showing the actual clusters formed
#     colors = cm.nipy_spectral(cluster_labels.astype(float) / n_clusters)
#     ax2.scatter(
#         X[:, 0], X[:, 1], marker=".", s=30, lw=0, alpha=0.7, c=colors, edgecolor="k"
#     )
# 
#     # Labeling the clusters
#     centers = clusterer.cluster_centers_
#     # Draw white circles at cluster centers
#     ax2.scatter(
#         centers[:, 0],
#         centers[:, 1],
#         marker="o",
#         c="white",
#         alpha=1,
#         s=200,
#         edgecolor="k",
#     )
# 
#     for i, c in enumerate(centers):
#         ax2.scatter(c[0], c[1], marker="$%d$" % i, alpha=1, s=50, edgecolor="k")
# 
#     ax2.set_title("The visualization of the clustered data.")
#     ax2.set_xlabel("Feature space for the 1st feature")
#     ax2.set_ylabel("Feature space for the 2nd feature")
# 
#     plt.suptitle(
#         "Silhouette analysis for KMeans clustering on sample data with n_clusters = %d"
#         % n_clusters,
#         fontsize=14,
#         fontweight="bold",
#     )
# 
# plt.show()

# %%
import pandas as pd
df3 = pd.read_csv('sensitive/health_interviews.csv', header=None)
df3.columns = df3.iloc[0] + '_' + df3.iloc[1]
df3 = df3.drop([0, 1, 2])
threshold = len(df3.columns) - 2 
df3 = df3.dropna(thresh=threshold).reset_index(drop=True)
df3.head(30)
# Out:
#              Q2_Utah Small Area       Q3_Health Problem  Q5_Sex  \
# 0                        Payson  Obesity and Overweight    Male
# 1                        Payson  Obesity and Overweight  Female
# 2        Provo East City Center      Obesity/Overweight  Female
# 3                  Spanish Fork              Depression  Female
# 4         Pleasant Grove/Lindon      Obesity/overweight  Female
# 5         Pleasant Grove/Lindon      Obesity/Overweight    Male
# 6        Provo East City Center      Obesity/Overweight    Male
# 7                 American Fork              Depression  Female
# 8                 American Fork              Depression  Female
# 9        Provo West City Center  Obesity and overweight    Male
# 10                       Payson                 obesity  Female
# 11  Eagle Mountain/Cedar Valley                 Obesity  Female
# 12  Eagle Mountain/Cedar Valley                 Obesity  Female
# 13                       Payson                 obesity    Male
# 14                       Payson  overweight and obesity  Female
# 15                       Payson      overweight/obesity  Female
# 16                American Fork              Depression  Female
# 17  Eagle Mountain/Cedar Valley                 Obesity  Female
# 18  Eagle Mountain/Cedar Valley                 Obesity  Female
# 19                 Spanish Fork              Depression  Female
# 20                         Lehi              Depression    Male
# 21                         Lehi              Depression  Female
# 22                 Spanish Fork              Depression  Female
# 23                    Orem West                 Obesity  Female
# 24       Provo East City Center                 Obesity  Female
# 25                    Orem West                 Obesity    Male
# 26       Provo East City Center                 Obesity    Male
# 27        Pleasant Grove/Lindon                 Obesity    Male
# 28       Provo East City Center      Overweight/Obesity    Male
# 29                    Orem West                 Obesity    Male
#
#           Q6_Race/Ethnicity - Selected Choice Q7_Age Group  \
# 0                             White/Caucasian        45-54
# 1                             White/Caucasian        18-24
# 2                             White/Caucasian        18-24
# 3                             White/Caucasian        45-54
# 4                      Hispanic/Latino/LatinX        25-34
# 5   Native Hawaiian or other Pacific Islander        18-24
# 6                             White/Caucasian        45-54
# 7                             White/Caucasian        35-44
# 8                             White/Caucasian        25-34
# 9                     Asian or Asian American        35-44
# 10                            White/Caucasian        65-74
# 11                            White/Caucasian        45-54
# 12    Asian or Asian American,White/Caucasian        25-34
# 13                            White/Caucasian        18-24
# 14                            White/Caucasian        18-24
# 15                            White/Caucasian        45-54
# 16                            White/Caucasian        45-54
# 17                            White/Caucasian        45-54
# 18                            White/Caucasian        45-54
# 19                            White/Caucasian        55-64
# 20    Asian or Asian American,White/Caucasian        18-24
# 21                            White/Caucasian        45-54
# 22                            White/Caucasian        45-54
# 23                            White/Caucasian        25-34
# 24                            White/Caucasian        18-24
# 25     Hispanic/Latino/LatinX,White/Caucasian        18-24
# 26                    Asian or Asian American        18-24
# 27                            White/Caucasian        35-44
# 28                            White/Caucasian        55-64
# 29                            White/Caucasian        55-64
#
#                                        Q8_Affiliation  \
# 0      Resident, Operations Manager for Family Search
# 1                                     College student
# 2   Community Member (and volunteer for Volunteer ...
# 3                                    Community member
# 4                                    Community Member
# 5                                   Community Member
# 6   Works directly with community members as pedia...
# 7   Communities that Care American Fork, Polaris H...
# 8                          The Family Therapy Clinic
# 9                               Asian Market employee
# 10                           retired community member
# 11     Community Development Administrative Assistant
# 12                           Grew up in the community
# 13  community member, university student, behavior...
# 14                         life-long community member
# 15                     homeowner and community member
# 16                        Community member, therapist
# 17                 Eagle Mountain City Council Member
# 18                                   Community Member
# 19                              Behavioral Specialist
# 20             Community Member, News Writer for ABC4
# 21                             Lehi City Councilwoman
# 22                            Family Medicine Manager
# 23                                   Community Member
# 24                                   Community Member
# 25                                   Community member
# 26                                   Community Member
# 27                                   Community Member
# 28  Executive Director at Food and Care Coalition ...
# 29                      Organizational Representative
#
#                                     Q10_Health Impact  \
# 0   Impacts some of our poorest residents harder. ...
# 1   Not many extracurricular activities outside of...
# 2   With the care clinic, you have to be below the...
# 3   I guess when you first brought it up, I though...
# 4   I don't know or interact with many people in m...
# 5   I grew up playing sports and was surrounded by...
# 6   In my experience working with hospitalized chi...
# 7   Well, we can see it with the drug use rates. W...
# 8   I would say we see it a lot in like a general ...
# 9   You know, I'm a father with three kids because...
# 10   Unfortunately, I see it as people don't recog...
# 11  I am unsure of the statistics on obesity in Ea...
# 12  I think for the most part the community was ve...
# 13  I don't see as a huge problem, just at a glanc...
# 14  People don’t do the outside things when they’r...
# 15  Living by the canyon. If you’re not healthy yo...
# 16  \nI would say there's a lot of depression goin...
# 17  The interesting thing is obesity is a symptom ...
# 18  I think it affects everybody and most communit...
# 19  It does have an impact on some. It seems that ...
# 20  Personally, let’s see. That is a really good q...
# 21  I mean, you're probably gonna hear this a lot....
# 22  Depression makes all health problems that the ...
# 23  "I don't see a lot of obese people here."\n"I ...
# 24  -\tFeels like it could affect the children bec...
# 25  I think it's very much, like, prevalent. Like,...
# 26  -\tDoesn’t perceive super high rates of obesit...
# 27  He sees obesity more in the older people. He s...
# 28  Okay, I would say generally that the populatio...
# 29  “I, you know, like I look at the UVU populatio...
#
#                               Q11_At-Risk Populations  \
# 0                                         Black Women
# 1                                     40-60 year olds
# 2   Definitely people in poverty, low income. I do...
# 3   I’d probably say like teenagers like in high s...
# 4   Any low-income neighborhood like neighborhoods...
# 5   I noticed, at least in high school, there were...
# 6   There are certainly populations that have high...
# 7   In wellness rooms I'm seeing a higher populati...
# 8   Really the majority of the clients I see are w...
# 9   For example the lunch people don't have that m...
# 10  Preteens into early teens. And also the elderl...
# 11  I believe pretty much everyone is at risk for ...
# 12  Oh, I don’t know um, this kind of sounds awful...
# 13  I mean,I would say probably that I find more m...
# 14                             Older people, retired.
# 15  Young obesity; bad socioeconomic , kids babysa...
# 16  I would say teens probably the most. And I mea...
# 17  We have such a mix in the community like refug...
# 18  Kids, even all school aged kids. Kids on their...
# 19  It seems that people who have a disability and...
# 20  Probably students. College or high school. Spe...
# 21  I think teenagers  anywhere from middle school...
# 22  The elderly population is strongly impacted an...
# 23  "I would say those struggling with severe ment...
# 24  \n-\tKids, since they see adults setting the e...
# 25  I think I would say, like, an older working cl...
# 26  -\tMarried individuals (relationship weight)\n...
# 27  Elderly/middle aged. Lower income because of t...
# 28                                                NaN
# 29  “Since my students are like less at risk, I wo...
#
#                                      Q12_Risk Factors  \
# 0   Childhood trauma, getting food that is addicti...
# 1   Not many outside activities for adults\n\nLots...
# 2   Unhealthy lifestyle I guess. Like very sedenta...
# 3   COVID implications, social media, social life ...
# 4   Lack of walkable community, grocery stores (Sm...
# 5   Lots of food chains around town; also I feel l...
# 6   I think that a lot of people these days aren't...
# 7   Well, I think family situations, I see there's...
# 8   I think in the American Fork, we probably see ...
# 9   Less movement, you know, they don't spend too ...
# 10  Every time we see a building being built, it's...
# 11  Some risk factors we have here are that most o...
# 12  I think it could be a lot of like…I mean most ...
# 13  Yes. I mean, there are a lot of fast food rest...
# 14  Park with pickleball courts; playgrounds open ...
# 15  Individual drive. Safety; not great lighting, ...
# 16  Social media. Loneliness, isolation. I think i...
# 17  One of the things I think that puts us at grea...
# 18  Education is key! \nBuying groceries and healt...
# 19  The risk factors that I see in the schools for...
# 20  If I had to guess, I would say probably the we...
# 21  I think you know, isolation, a lack of engagem...
# 22  COVID-19 pandemic was a major kickstarter beca...
# 23  "I would say something that would impact it is...
# 24  -\tThere are a lot of fast food places really ...
# 25  I think it's very easy to just be very sedenta...
# 26  -\tUtah is snowy, might make people not want t...
# 27  Some of the risk factors he mentioned were -Se...
# 28  in the Bridges Out of Poverty curriculum,  the...
# 29  “you know, the one thing I could think of woul...
#
#                                        Q13_Root Cause  \
# 0   Most people struggle to know what foods are be...
# 1   In rural parts, there are fewer educated peopl...
# 2   I feel like it all stems from poverty because ...
# 3   There is a disparity and more so in my little ...
# 4            Attitudes of being complacent in habits
# 5   In junior high we watched the documentary of M...
# 6   I think economic factors play a big part. And ...
# 7   Lack of Sleep, So this survey goes from sixth,...
# 8   I think in the American Fork, we probably see ...
# 9   Okay, this is easier for people to get food. E...
# 10  I think it's faster and cheaper if they build ...
# 11  I am not sure why fast food places seem to com...
# 12  The kids live in a society where everything is...
# 13  I would say, all over the country of America i...
# 14  It’s easier to reach those in schools. Educati...
# 15  Knowledge; time and effort; what is healthy, w...
# 16  Um, well, I think isolation is big, right? Lik...
# 17  The overall stress on families and what they a...
# 18  Needing to be educated on healthy eating. Fami...
# 19  I believe that in this area too often people u...
# 20  Probably the change in environments for colleg...
# 21  \nCovid the prevalence of social media engagem...
# 22  There is a lack of a sense of community, peopl...
# 23  “for mental health, I would say, loneliness. W...
# 24  \n-\tPeople tend to focus on the cheapest opti...
# 25  So I'm actually taking a class right now calle...
# 26  -\tLack of infrastructure: no heated sidewalks...
# 27  One of the primary reasons for these risk fact...
# 28  I would say there are cultural factors, right?...
# 29  \n“I think it’s probably like I said one is ed...
#
#                               Q14_Community Strengths  \
# 0   Good friends, finances, outdoor community/comm...
# 1   Church with finance classes and self-reliance,...
# 2   For free health service like the volunteer car...
# 3   [For her and her family] Life coaches, acupunc...
# 4    Pleasant Grove has a decent REC center; acces...
# 5   There was a rec center we would go to and ther...
# 6   In general, Utah has a lot of people who value...
# 7   Well, our number one thing right now is the we...
# 8   Well, obviously the family therapy clinic that...
# 9   Okay, you know, we can have more events.\nkind...
# 10  Payson Canyon does have some hiking trails tha...
# 11  Some of the greatest strengths we have in Eagl...
# 12  I know a lot of school systems try to do the M...
# 13  In general, the community is pretty strong. Th...
# 14  Canyon in close proximity, pool, tracks; 2 gym...
# 15  Canyon 1.5 miles from home, lots of opportunit...
# 16  Well, it seems like a lot of the schools in th...
# 17  Eagle mountain doesn't have a rec center, but ...
# 18  They have lots of parks, like parks with tenni...
# 19  There is a system through the prominent religi...
# 20  If I had to guess there are probably some. Oh,...
# 21  This will be probably a crazy answer right off...
# 22  Gathering locations. PHQ-9 screening within th...
# 23  “I feel like vineyard in specific is really go...
# 24  -\tThey have a community garden\n-\tBike walk ...
# 25  I feel like there's quite a few gyms here, and...
# 26          -\tAccess to hiking trails\n-\tBike lanes
# 27  He said that Pleasant Grove is lucky because o...
# 28  you know, I think, you know, one, having acces...
# 29  “So at UVU…we have a pantry like a food pantry...
#
#                                         Q15_Resources  \
# 0   Community resources at the hospital that have ...
# 1   Church with finance classes and self-reliance,...
# 2   Public transportation is a huge perk. Like I f...
# 3                                                 NaN
# 4              Sidewalks aren't always up to standard
# 5                                                 N/A
# 6              I don't know of any in the Provo area.
# 7   Service: So every Thursday we have an organiza...
# 8   Well, obviously the family therapy clinic that...
# 9   Probably have more young people because of the...
# 10  I haven’t seen a community rec center. There's...
# 11  Some of things we have that address obesity ar...
# 12  Basically the same thing, trails and parks tha...
# 13                                                NaN
# 14  Weekly dinner groups held to help learn how to...
# 15  Summer triathlon for free; holiday 5K events; ...
# 16  Well, it seems like a lot of the schools in th...
# 17  The parks and greenspaces, as well as the mast...
# 18               Outdoor parks, green spaces, trails.
# 19  There are several medical doctors who are very...
# 20  I actually am not aware of any other ones. I’v...
# 21  The challenges we're facing are, there's such ...
# 22  Therapy/mental health professionals, however, ...
# 23  “I do not see anything specific to that…I can’...
# 24                    -\tOnly the things stated above
# 25                                               none
# 26  \n-\tHealth Clinics\n-\tNothing specific reall...
# 27  There are nutrition meal prep classes that he ...
# 28  Well, we've got the health department, you kno...
# 29  “You know, I honestly don’t know… I guess, I w...
#
#                                         Q16_Solutions  \
# 0   Financial assistance and classes (getting the ...
# 1   Having more availability of knowledge and help...
# 2   If there was a way to help people get healthy ...
# 3   (for kids/teens) [Programs that] taught them t...
# 4            Infrastructural changes to the sidewalks
# 5   Build a VASA in PG; Publicize the after school...
# 6   I think there are lots of things that could be...
# 7   I feel like raising awareness. I think that if...
# 8   I think having other resources or supplying ma...
# 9   I know I'm almost 40. After 40, if you have th...
# 10  A place for kids to go to play a couple of hou...
# 11  I definitely feel there are more things we can...
# 12  I feel like just having it be an open topic th...
# 13  Get the community involved. If they're involve...
# 14  City and school wrestling, waived fees?\n4H af...
# 15  Education -- teaching people how to eat; prepa...
# 16  I feel like there has been a good shift in the...
# 17  Following the strategic plan that was made. Be...
# 18  Schools and education in general at any level....
# 19  It needs to be more affordable and school teac...
# 20  That's a good question. I feel like this can a...
# 21  Awareness. I think, in just about every commun...
# 22  There is a lack of mental health professionals...
# 23  “Honestly the only thing that I can think of i...
# 24  -\tMore parks\n-\tCreate group sports to use t...
# 25  There is always more that can be done. I think...
# 26  \n-\tIt needs to be talked about more.\n-\tDis...
# 27  He said that maybe a heavy soda tax could help...
# 28  Well, I think with anything communication, you...
# 29  “I think awareness is a big thing. And so firs...
#
#                                    Q17_Other Thoughts
# 0   It is a real bedroom community—if people are s...
# 1   In general, she believes that people are healt...
# 2                                                 NaN
# 3   Spanish Fork is really good at like the Harves...
# 4   Amazing sense of community, small town feel be...
# 5   Being apart of athletics got me into wanting t...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9   You know, for example, for the parks, you know...
# 10  I think Payson is set up very well. I really d...
# 11  I would truly like to see our Community do bet...
# 12  I don’t know, um, yeah I guess just talk about...
# 13                                                NaN
# 14                                                NaN
# 15  Payson is a good place to live if you live in ...
# 16  No, I think it's great that you all are talkin...
# 17  Just that eagle mountain is aware of the issue...
# 18            I can’t think of anything else to add.
# 19                                                NaN
# 20  Yes, I think there should be fewer crumble coo...
# 21  One of the things that I like most about it is...
# 22  A lot of the affected population is adolescent...
# 23  “That’s it. I don't. I don't know. I don’t rea...
# 24                                                  X
# 25                                               none
# 26  \n\n-\tHealth is pretty good, but its skewed b...
# 27  He said that air pollution is a problem. This ...
# 28  I would say let's keep doing the good things w...
# 29  “I teach a class, an upper division class here...

# %%
import pandas as pd
import numpy as np
import uuid

def generate_id(index, area, sex):
    # Combine index, first 3 letters of area, and first letter of sex
    # print('hi', index, area, sex)
    return f"{index}_{area[:3].upper()}_{sex[0].upper()}"

def update_id(id, prompt):
    return f'{id}_{prompt[:3].upper()}'

# Assuming df3 is your original dataframe
# Split df3 into id_info (first 6 columns) and questions (remaining 8 columns)
id_info = df3.iloc[:, :6]
questions = df3.iloc[:, 6:]

# Generate an 'id' for each row in id_info
id_info['id'] = id_info.apply(lambda row: generate_id(row.name, row['Q2_Utah Small Area'], row['Q5_Sex']), axis=1)

# Create a new dataframe with the id_info and the questions split into rows
df_expanded = pd.melt(questions.reset_index(), id_vars=['index'], var_name='prompt', value_name='answer')
df_expanded['id'] = df_expanded['index'].map(id_info.set_index(id_info.index)['id'])
df_expanded['id'] = df_expanded.apply(lambda row: update_id(row['id'], row['prompt']), axis=1)
df_expanded = df_expanded[['id', 'prompt', 'answer']]

# Create the second dataframe with the original id_info and the generated 'id'
# df_id_info = id_info.copy()

# Now df_expanded has columns: id, question, answer
# And df_id_info has columns: id_info and id

# Optionally, reset the index and drop the 'index' column
# df_expanded = df_expanded.drop(columns='index').reset_index(drop=True)
df_expanded
# Out:
# /var/folders/q1/pgrzstr943q_x468qzzms0x00000gn/T/ipykernel_8255/3569657419.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   id_info['id'] = id_info.apply(lambda row: generate_id(row.name, row['Q2_Utah Small Area'], row['Q5_Sex']), axis=1)
#                id              prompt  \
# 0     0_PAY_M_Q10   Q10_Health Impact
# 1     1_PAY_F_Q10   Q10_Health Impact
# 2     2_PRO_F_Q10   Q10_Health Impact
# 3     3_SPA_F_Q10   Q10_Health Impact
# 4     4_PLE_F_Q10   Q10_Health Impact
# ..            ...                 ...
# 483  56_PAY_F_Q17  Q17_Other Thoughts
# 484  57_LEH_F_Q17  Q17_Other Thoughts
# 485  58_LEH_M_Q17  Q17_Other Thoughts
# 486  59_LEH_M_Q17  Q17_Other Thoughts
# 487  60_LEH_M_Q17  Q17_Other Thoughts
#
#                                                 answer
# 0    Impacts some of our poorest residents harder. ...
# 1    Not many extracurricular activities outside of...
# 2    With the care clinic, you have to be below the...
# 3    I guess when you first brought it up, I though...
# 4    I don't know or interact with many people in m...
# ..                                                 ...
# 483  Use of delivery systems for walmart and or smi...
# 484  Overall, I feel like Lehi is doing a great job...
# 485  No, I feel like Lehi is doing a good job overall!
# 486  I think the affordability of the city is a con...
# 487  I would love to see Lehi City invest more in i...
#
# [488 rows x 3 columns]

# %%
# df_id_info.head()
# Out:
#        Q2_Utah Small Area       Q3_Health Problem  Q5_Sex  \
# 0                  Payson  Obesity and Overweight    Male
# 1                  Payson  Obesity and Overweight  Female
# 2  Provo East City Center      Obesity/Overweight  Female
# 3            Spanish Fork              Depression  Female
# 4   Pleasant Grove/Lindon      Obesity/overweight  Female
#
#   Q6_Race/Ethnicity - Selected Choice Q7_Age Group  \
# 0                     White/Caucasian        45-54
# 1                     White/Caucasian        18-24
# 2                     White/Caucasian        18-24
# 3                     White/Caucasian        45-54
# 4              Hispanic/Latino/LatinX        25-34
#
#                                       Q8_Affiliation       id
# 0     Resident, Operations Manager for Family Search  0_PAY_M
# 1                                    College student  1_PAY_F
# 2  Community Member (and volunteer for Volunteer ...  2_PRO_F
# 3                                   Community member  3_SPA_F
# 4                                   Community Member  4_PLE_F

# %%
# df_id_info.to_csv('id_info.csv', index=False)

# %%
# df_expanded.head(100)
# Out:
#     index                   prompt  \
# 0       0        Q10_Health Impact
# 1       1        Q10_Health Impact
# 2       2        Q10_Health Impact
# 3       3        Q10_Health Impact
# 4       4        Q10_Health Impact
# ..    ...                      ...
# 95     34  Q11_At-Risk Populations
# 96     35  Q11_At-Risk Populations
# 97     36  Q11_At-Risk Populations
# 98     37  Q11_At-Risk Populations
# 99     38  Q11_At-Risk Populations
#
#                                                answer        id
# 0   Impacts some of our poorest residents harder. ...   0_PAY_M
# 1   Not many extracurricular activities outside of...   1_PAY_F
# 2   With the care clinic, you have to be below the...   2_PRO_F
# 3   I guess when you first brought it up, I though...   3_SPA_F
# 4   I don't know or interact with many people in m...   4_PLE_F
# ..                                                ...       ...
# 95  I  would definitely say there is  a large comm...  34_PRO_F
# 96   I wonder if I could like find a trend about l...  35_AME_F
# 97  \nWell you said most at risk, and I think most...  36_SPA_M
# 98  I think young adults; specifically either have...  37_SPA_M
# 99  I think our youth 12-18. I think they don't kn...  38_PLE_M
#
# [100 rows x 4 columns]

# %%
df_expanded.to_csv('health_interviews_proc.csv', index=False)
